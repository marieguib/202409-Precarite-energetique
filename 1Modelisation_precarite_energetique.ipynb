# %% [markdown]
# # I. Modélisation statistique

# %%
# !pip install s3fs
# !pip install pandas
# !pip install scikit-learn==1.2.2
# !pip install imbalanced-learn
# Out:
# Requirement already satisfied: s3fs in c:\users\asus\anaconda3\lib\site-packages (2023.4.0)
# Requirement already satisfied: aiobotocore~=2.5.0 in c:\users\asus\anaconda3\lib\site-packages (from s3fs) (2.5.0)
# Requirement already satisfied: fsspec==2023.4.0 in c:\users\asus\anaconda3\lib\site-packages (from s3fs) (2023.4.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in c:\users\asus\anaconda3\lib\site-packages (from s3fs) (3.8.5)
# Requirement already satisfied: botocore<1.29.77,>=1.29.76 in c:\users\asus\anaconda3\lib\site-packages (from aiobotocore~=2.5.0->s3fs) (1.29.76)
# Requirement already satisfied: wrapt>=1.10.10 in c:\users\asus\anaconda3\lib\site-packages (from aiobotocore~=2.5.0->s3fs) (1.14.1)
# Requirement already satisfied: aioitertools>=0.5.1 in c:\users\asus\anaconda3\lib\site-packages (from aiobotocore~=2.5.0->s3fs) (0.7.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\asus\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (22.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in c:\users\asus\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (2.0.4)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\asus\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (6.0.2)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in c:\users\asus\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\asus\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (1.8.1)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\asus\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (1.3.3)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\asus\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (1.2.0)
# Requirement already satisfied: typing_extensions>=3.7 in c:\users\asus\anaconda3\lib\site-packages (from aioitertools>=0.5.1->aiobotocore~=2.5.0->s3fs) (4.7.1)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in c:\users\asus\anaconda3\lib\site-packages (from botocore<1.29.77,>=1.29.76->aiobotocore~=2.5.0->s3fs) (0.10.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in c:\users\asus\appdata\roaming\python\python311\site-packages (from botocore<1.29.77,>=1.29.76->aiobotocore~=2.5.0->s3fs) (2.8.2)
# Requirement already satisfied: urllib3<1.27,>=1.25.4 in c:\users\asus\anaconda3\lib\site-packages (from botocore<1.29.77,>=1.29.76->aiobotocore~=2.5.0->s3fs) (1.26.16)
# Requirement already satisfied: idna>=2.0 in c:\users\asus\anaconda3\lib\site-packages (from yarl<2.0,>=1.0->aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (3.4)
# Requirement already satisfied: six>=1.5 in c:\users\asus\appdata\roaming\python\python311\site-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.29.77,>=1.29.76->aiobotocore~=2.5.0->s3fs) (1.16.0)
# Requirement already satisfied: pandas in c:\users\asus\anaconda3\lib\site-packages (2.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\asus\appdata\roaming\python\python311\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\asus\anaconda3\lib\site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\asus\anaconda3\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\asus\anaconda3\lib\site-packages (from pandas) (1.24.3)
# Requirement already satisfied: six>=1.5 in c:\users\asus\appdata\roaming\python\python311\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Collecting scikit-learn==1.2.2
#   Obtaining dependency information for scikit-learn==1.2.2 from https://files.pythonhosted.org/packages/db/98/169b46a84b48f92df2b5e163fce75d471f4df933f8b3d925a61133210776/scikit_learn-1.2.2-cp311-cp311-win_amd64.whl.metadata
#   Using cached scikit_learn-1.2.2-cp311-cp311-win_amd64.whl.metadata (11 kB)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\asus\anaconda3\lib\site-packages (from scikit-learn==1.2.2) (1.24.3)
# Requirement already satisfied: scipy>=1.3.2 in c:\users\asus\anaconda3\lib\site-packages (from scikit-learn==1.2.2) (1.11.1)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\asus\anaconda3\lib\site-packages (from scikit-learn==1.2.2) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\asus\anaconda3\lib\site-packages (from scikit-learn==1.2.2) (2.2.0)
# Using cached scikit_learn-1.2.2-cp311-cp311-win_amd64.whl (8.3 MB)
# Installing collected packages: scikit-learn
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.4.2
#     Uninstalling scikit-learn-1.4.2:
#       Successfully uninstalled scikit-learn-1.4.2
#   Rolling back uninstall of scikit-learn
#   Moving to c:\users\asus\anaconda3\lib\site-packages\scikit_learn-1.4.2.dist-info\
#    from C:\Users\ASUS\anaconda3\Lib\site-packages\~cikit_learn-1.4.2.dist-info
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\__check_build\__init__.py
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-km3hn3j8\__init__.py
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\__check_build\__pycache__\
#    from C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\__check_build\~_pycache__
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\__check_build\_check_build.cp311-win_amd64.pyd
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-km3hn3j8\_check_build.cp311-win_amd64.pyd
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\__init__.py
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\__init__.py
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\__pycache__\
#    from C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\~_pycache__
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\_build_utils\
#    from C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\~build_utils
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\_config.py
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\_config.py
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\_distributor_init.py
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\_distributor_init.py
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\_isotonic.cp311-win_amd64.pyd
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\_isotonic.cp311-win_amd64.pyd
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\_loss\__init__.py
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\_loss\__init__.py
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\_loss\__pycache__\
#    from C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\_loss\~_pycache__
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\_loss\_loss.cp311-win_amd64.pyd
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\_loss\_loss.cp311-win_amd64.pyd
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\_loss\_loss.pxd
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\_loss\_loss.pxd
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\_loss\link.py
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\_loss\link.py
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\_loss\loss.py
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\_loss\loss.py
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\_loss\tests\
#    from C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\_loss\~ests
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\_min_dependencies.py
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\_min_dependencies.py
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\base.py
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\base.py
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\calibration.py
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\calibration.py
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\cluster\__init__.py
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\cluster\__init__.py
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\cluster\__pycache__\
#    from C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\cluster\~_pycache__
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\cluster\_affinity_propagation.py
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\cluster\_affinity_propagation.py
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\cluster\_agglomerative.py
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\cluster\_agglomerative.py
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\cluster\_bicluster.py
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\cluster\_bicluster.py
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\cluster\_birch.py
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\cluster\_birch.py
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\cluster\_bisect_k_means.py
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\cluster\_bisect_k_means.py
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\cluster\_dbscan.py
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\cluster\_dbscan.py
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\cluster\_dbscan_inner.cp311-win_amd64.pyd
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\cluster\_dbscan_inner.cp311-win_amd64.pyd
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\cluster\_feature_agglomeration.py
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\cluster\_feature_agglomeration.py
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\cluster\_hdbscan\__init__.py
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\cluster\_hdbscan\__init__.py
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\cluster\_hdbscan\__pycache__\
#    from C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\cluster\_hdbscan\~_pycache__
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\cluster\_hdbscan\_linkage.cp311-win_amd64.pyd
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\cluster\_hdbscan\_linkage.cp311-win_amd64.pyd
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\cluster\_hdbscan\_reachability.cp311-win_amd64.pyd
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\cluster\_hdbscan\_reachability.cp311-win_amd64.pyd
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\cluster\_hdbscan\_tree.cp311-win_amd64.pyd
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\cluster\_hdbscan\_tree.cp311-win_amd64.pyd
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\cluster\_hdbscan\_tree.pxd
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\cluster\_hdbscan\_tree.pxd
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\cluster\_hdbscan\hdbscan.py
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\cluster\_hdbscan\hdbscan.py
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\cluster\_hdbscan\tests\
#    from C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\cluster\_hdbscan\~ests
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\cluster\_hierarchical_fast.cp311-win_amd64.pyd
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\cluster\_hierarchical_fast.cp311-win_amd64.pyd
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\cluster\_hierarchical_fast.pxd
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\cluster\_hierarchical_fast.pxd
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\cluster\_k_means_common.cp311-win_amd64.pyd
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\cluster\_k_means_common.cp311-win_amd64.pyd
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\cluster\_k_means_common.pxd
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\cluster\_k_means_common.pxd
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\cluster\_k_means_elkan.cp311-win_amd64.pyd
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\cluster\_k_means_elkan.cp311-win_amd64.pyd
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\cluster\_k_means_lloyd.cp311-win_amd64.pyd
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\cluster\_k_means_lloyd.cp311-win_amd64.pyd
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\cluster\_k_means_minibatch.cp311-win_amd64.pyd
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\cluster\_k_means_minibatch.cp311-win_amd64.pyd
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\cluster\_kmeans.py
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\cluster\_mean_shift.py
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\cluster\_mean_shift.py
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\cluster\_optics.py
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\cluster\_optics.py
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\cluster\_spectral.py
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\cluster\_spectral.py
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\cluster\tests\
#    from C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\cluster\~ests
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\compose\
#    from C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\~ompose
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\conftest.py
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\conftest.py
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\covariance\
#    from C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\~ovariance
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\cross_decomposition\
#    from C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\~ross_decomposition
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\datasets\
#    from C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\~atasets
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\decomposition\__init__.py
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\decomposition\__init__.py
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\decomposition\__pycache__\
#    from C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\decomposition\~_pycache__
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\decomposition\_base.py
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\decomposition\_base.py
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\decomposition\_cdnmf_fast.cp311-win_amd64.pyd
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\decomposition\_cdnmf_fast.cp311-win_amd64.pyd
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\decomposition\_dict_learning.py
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\decomposition\_dict_learning.py
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\decomposition\_factor_analysis.py
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\decomposition\_factor_analysis.py
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\decomposition\_fastica.py
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\decomposition\_fastica.py
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\decomposition\_incremental_pca.py
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\decomposition\_incremental_pca.py
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\decomposition\_kernel_pca.py
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\decomposition\_kernel_pca.py
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\decomposition\_lda.py
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\decomposition\_lda.py
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\decomposition\_nmf.py
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\decomposition\_online_lda_fast.cp311-win_amd64.pyd
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\decomposition\_online_lda_fast.cp311-win_amd64.pyd
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\decomposition\_pca.py
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\decomposition\_pca.py
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\decomposition\_sparse_pca.py
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\decomposition\_sparse_pca.py
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\decomposition\_truncated_svd.py
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\decomposition\_truncated_svd.py
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\decomposition\tests\
#    from C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\decomposition\~ests
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\discriminant_analysis.py
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\discriminant_analysis.py
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\dummy.py
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\dummy.py
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\ensemble\__init__.py
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\ensemble\__init__.py
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\ensemble\__pycache__\
#    from C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\ensemble\~_pycache__
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\ensemble\_bagging.py
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\ensemble\_bagging.py
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\ensemble\_base.py
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\ensemble\_base.py
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\ensemble\_forest.py
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\ensemble\_gb.py
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\ensemble\_gb.py
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\ensemble\_gradient_boosting.cp311-win_amd64.pyd
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\ensemble\_gradient_boosting.cp311-win_amd64.pyd
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\ensemble\_hist_gradient_boosting\__init__.py
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\ensemble\_hist_gradient_boosting\__init__.py
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\ensemble\_hist_gradient_boosting\__pycache__\
#    from C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\ensemble\_hist_gradient_boosting\~_pycache__
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\ensemble\_hist_gradient_boosting\_binning.cp311-win_amd64.pyd
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\ensemble\_hist_gradient_boosting\_binning.cp311-win_amd64.pyd
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\ensemble\_hist_gradient_boosting\_bitset.cp311-win_amd64.pyd
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\ensemble\_hist_gradient_boosting\_bitset.cp311-win_amd64.pyd
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\ensemble\_hist_gradient_boosting\_bitset.pxd
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\ensemble\_hist_gradient_boosting\_bitset.pxd
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\ensemble\_hist_gradient_boosting\_gradient_boosting.cp311-win_amd64.pyd
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\ensemble\_hist_gradient_boosting\_gradient_boosting.cp311-win_amd64.pyd
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\ensemble\_hist_gradient_boosting\_predictor.cp311-win_amd64.pyd
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\ensemble\_hist_gradient_boosting\_predictor.cp311-win_amd64.pyd
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\ensemble\_hist_gradient_boosting\binning.py
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\ensemble\_hist_gradient_boosting\binning.py
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\ensemble\_hist_gradient_boosting\common.cp311-win_amd64.pyd
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\ensemble\_hist_gradient_boosting\common.cp311-win_amd64.pyd
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\ensemble\_hist_gradient_boosting\common.pxd
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\ensemble\_hist_gradient_boosting\common.pxd
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\ensemble\_hist_gradient_boosting\gradient_boosting.py
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\ensemble\_hist_gradient_boosting\gradient_boosting.py
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\ensemble\_hist_gradient_boosting\grower.py
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\ensemble\_hist_gradient_boosting\grower.py
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\ensemble\_hist_gradient_boosting\histogram.cp311-win_amd64.pyd
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\ensemble\_hist_gradient_boosting\histogram.cp311-win_amd64.pyd
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\ensemble\_hist_gradient_boosting\predictor.py
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\ensemble\_hist_gradient_boosting\predictor.py
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\ensemble\_hist_gradient_boosting\splitting.cp311-win_amd64.pyd
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\ensemble\_hist_gradient_boosting\splitting.cp311-win_amd64.pyd
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\ensemble\_hist_gradient_boosting\tests\
#    from C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\ensemble\_hist_gradient_boosting\~ests
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\ensemble\_hist_gradient_boosting\utils.cp311-win_amd64.pyd
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\ensemble\_hist_gradient_boosting\utils.cp311-win_amd64.pyd
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\ensemble\_iforest.py
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\ensemble\_iforest.py
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\ensemble\_stacking.py
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\ensemble\_stacking.py
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\ensemble\_voting.py
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\ensemble\_voting.py
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\ensemble\_weight_boosting.py
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\ensemble\_weight_boosting.py
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\ensemble\tests\
#    from C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\ensemble\~ests
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\exceptions.py
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\exceptions.py
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\experimental\
#    from C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\~xperimental
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\externals\
#    from C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\~xternals
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\feature_extraction\__init__.py
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\feature_extraction\__init__.py
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\feature_extraction\__pycache__\
#    from C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\feature_extraction\~_pycache__
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\feature_extraction\_dict_vectorizer.py
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\feature_extraction\_dict_vectorizer.py
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\feature_extraction\_hash.py
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\feature_extraction\_hash.py
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\feature_extraction\_hashing_fast.cp311-win_amd64.pyd
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\feature_extraction\_hashing_fast.cp311-win_amd64.pyd
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\feature_extraction\_stop_words.py
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\feature_extraction\_stop_words.py
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\feature_extraction\image.py
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\feature_extraction\image.py
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\feature_extraction\tests\
#    from C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\feature_extraction\~ests
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\feature_extraction\text.py
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\feature_extraction\text.py
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\feature_selection\
#    from C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\~eature_selection
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\gaussian_process\
#    from C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\~aussian_process
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\impute\
#    from C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\~mpute
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\inspection\
#    from C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\~nspection
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\isotonic.py
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\isotonic.py
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\kernel_approximation.py
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\kernel_approximation.py
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\kernel_ridge.py
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\kernel_ridge.py
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\linear_model\__init__.py
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\linear_model\__init__.py
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\linear_model\__pycache__\
#    from C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\linear_model\~_pycache__
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\linear_model\_base.py
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\linear_model\_base.py
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\linear_model\_bayes.py
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\linear_model\_bayes.py
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\linear_model\_cd_fast.cp311-win_amd64.pyd
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\linear_model\_cd_fast.cp311-win_amd64.pyd
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\linear_model\_coordinate_descent.py
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\linear_model\_glm\
#    from C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\linear_model\~glm
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\linear_model\_huber.py
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\linear_model\_huber.py
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\linear_model\_least_angle.py
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\linear_model\_least_angle.py
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\linear_model\_linear_loss.py
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\linear_model\_linear_loss.py
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\linear_model\_logistic.py
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\linear_model\_omp.py
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\linear_model\_omp.py
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\linear_model\_passive_aggressive.py
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\linear_model\_passive_aggressive.py
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\linear_model\_perceptron.py
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\linear_model\_perceptron.py
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\linear_model\_quantile.py
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\linear_model\_quantile.py
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\linear_model\_ransac.py
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\linear_model\_ransac.py
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\linear_model\_ridge.py
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\linear_model\_sag.py
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\linear_model\_sag_fast.cp311-win_amd64.pyd
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\linear_model\_sag_fast.cp311-win_amd64.pyd
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\linear_model\_sgd_fast.cp311-win_amd64.pyd
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\linear_model\_sgd_fast.cp311-win_amd64.pyd
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\linear_model\_sgd_fast.pxd
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\linear_model\_sgd_fast.pxd
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\linear_model\_stochastic_gradient.py
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\linear_model\_stochastic_gradient.py
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\linear_model\_theil_sen.py
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\linear_model\_theil_sen.py
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\linear_model\tests\
#    from C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\linear_model\~ests
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\manifold\__init__.py
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\manifold\__init__.py
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\manifold\__pycache__\
#    from C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\manifold\~_pycache__
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\manifold\_barnes_hut_tsne.cp311-win_amd64.pyd
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\manifold\_barnes_hut_tsne.cp311-win_amd64.pyd
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\manifold\_isomap.py
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\manifold\_isomap.py
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\manifold\_locally_linear.py
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\manifold\_locally_linear.py
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\manifold\_mds.py
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\manifold\_mds.py
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\manifold\_spectral_embedding.py
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\manifold\_spectral_embedding.py
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\manifold\_t_sne.py
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\manifold\_utils.cp311-win_amd64.pyd
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\manifold\_utils.cp311-win_amd64.pyd
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\manifold\tests\
#    from C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\manifold\~ests
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\metrics\__init__.py
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\metrics\__init__.py
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\metrics\__pycache__\
#    from C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\metrics\~_pycache__
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\metrics\_base.py
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\metrics\_base.py
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\metrics\_classification.py
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\metrics\_classification.py
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\metrics\_dist_metrics.cp311-win_amd64.pyd
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\metrics\_dist_metrics.cp311-win_amd64.pyd
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\metrics\_dist_metrics.pxd
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\metrics\_dist_metrics.pxd
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\metrics\_pairwise_distances_reduction\__init__.py
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\metrics\_pairwise_distances_reduction\__init__.py
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\metrics\_pairwise_distances_reduction\__pycache__\
#    from C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\metrics\_pairwise_distances_reduction\~_pycache__
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\metrics\_pairwise_distances_reduction\_argkmin.cp311-win_amd64.pyd
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\metrics\_pairwise_distances_reduction\_argkmin.cp311-win_amd64.pyd
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\metrics\_pairwise_distances_reduction\_argkmin.pxd
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\metrics\_pairwise_distances_reduction\_argkmin.pxd
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\metrics\_pairwise_distances_reduction\_argkmin_classmode.cp311-win_amd64.pyd
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\metrics\_pairwise_distances_reduction\_argkmin_classmode.cp311-win_amd64.pyd
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\metrics\_pairwise_distances_reduction\_base.cp311-win_amd64.pyd
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\metrics\_pairwise_distances_reduction\_base.cp311-win_amd64.pyd
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\metrics\_pairwise_distances_reduction\_base.pxd
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\metrics\_pairwise_distances_reduction\_base.pxd
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\metrics\_pairwise_distances_reduction\_classmode.pxd
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\metrics\_pairwise_distances_reduction\_classmode.pxd
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\metrics\_pairwise_distances_reduction\_datasets_pair.cp311-win_amd64.pyd
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\metrics\_pairwise_distances_reduction\_datasets_pair.cp311-win_amd64.pyd
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\metrics\_pairwise_distances_reduction\_datasets_pair.pxd
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\metrics\_pairwise_distances_reduction\_datasets_pair.pxd
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\metrics\_pairwise_distances_reduction\_dispatcher.py
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\metrics\_pairwise_distances_reduction\_dispatcher.py
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\metrics\_pairwise_distances_reduction\_middle_term_computer.cp311-win_amd64.pyd
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\metrics\_pairwise_distances_reduction\_middle_term_computer.cp311-win_amd64.pyd
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\metrics\_pairwise_distances_reduction\_middle_term_computer.pxd
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\metrics\_pairwise_distances_reduction\_middle_term_computer.pxd
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\metrics\_pairwise_distances_reduction\_radius_neighbors.cp311-win_amd64.pyd
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\metrics\_pairwise_distances_reduction\_radius_neighbors.cp311-win_amd64.pyd
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\metrics\_pairwise_distances_reduction\_radius_neighbors.pxd
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\metrics\_pairwise_distances_reduction\_radius_neighbors.pxd
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\metrics\_pairwise_distances_reduction\_radius_neighbors_classmode.cp311-win_amd64.pyd
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\metrics\_pairwise_distances_reduction\_radius_neighbors_classmode.cp311-win_amd64.pyd
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\metrics\_pairwise_fast.cp311-win_amd64.pyd
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\metrics\_pairwise_fast.cp311-win_amd64.pyd
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\metrics\_plot\
#    from C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\metrics\~plot
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\metrics\_ranking.py
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\metrics\_ranking.py
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\metrics\_regression.py
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\metrics\_regression.py
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\metrics\_scorer.py
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\metrics\cluster\__init__.py
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\metrics\cluster\__init__.py
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\metrics\cluster\__pycache__\
#    from C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\metrics\cluster\~_pycache__
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\metrics\cluster\_bicluster.py
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\metrics\cluster\_bicluster.py
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\metrics\cluster\_expected_mutual_info_fast.cp311-win_amd64.pyd
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\metrics\cluster\_expected_mutual_info_fast.cp311-win_amd64.pyd
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\metrics\cluster\_supervised.py
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\metrics\cluster\_unsupervised.py
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\metrics\cluster\_unsupervised.py
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\metrics\cluster\tests\
#    from C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\metrics\cluster\~ests
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\metrics\pairwise.py
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\metrics\pairwise.py
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\metrics\tests\
#    from C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\metrics\~ests
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\mixture\
#    from C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\~ixture
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\model_selection\
#    from C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\~odel_selection
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\multiclass.py
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\multiclass.py
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\multioutput.py
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\multioutput.py
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\naive_bayes.py
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\naive_bayes.py
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\neighbors\__init__.py
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\neighbors\__init__.py
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\neighbors\__pycache__\
#    from C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\neighbors\~_pycache__
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\neighbors\_ball_tree.cp311-win_amd64.pyd
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\neighbors\_ball_tree.cp311-win_amd64.pyd
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\neighbors\_base.py
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\neighbors\_base.py
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\neighbors\_classification.py
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\neighbors\_graph.py
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\neighbors\_graph.py
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\neighbors\_kd_tree.cp311-win_amd64.pyd
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\neighbors\_kd_tree.cp311-win_amd64.pyd
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\neighbors\_kde.py
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\neighbors\_kde.py
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\neighbors\_lof.py
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\neighbors\_lof.py
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\neighbors\_nca.py
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\neighbors\_nca.py
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\neighbors\_nearest_centroid.py
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\neighbors\_nearest_centroid.py
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\neighbors\_partition_nodes.cp311-win_amd64.pyd
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\neighbors\_partition_nodes.cp311-win_amd64.pyd
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\neighbors\_partition_nodes.pxd
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\neighbors\_partition_nodes.pxd
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\neighbors\_quad_tree.cp311-win_amd64.pyd
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\neighbors\_quad_tree.cp311-win_amd64.pyd
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\neighbors\_quad_tree.pxd
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\neighbors\_quad_tree.pxd
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\neighbors\_regression.py
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\neighbors\_regression.py
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\neighbors\_unsupervised.py
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\neighbors\_unsupervised.py
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\neighbors\tests\
#    from C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\neighbors\~ests
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\neural_network\
#    from C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\~eural_network
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\pipeline.py
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\pipeline.py
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\preprocessing\__init__.py
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\preprocessing\__init__.py
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\preprocessing\__pycache__\
#    from C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\preprocessing\~_pycache__
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\preprocessing\_csr_polynomial_expansion.cp311-win_amd64.pyd
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\preprocessing\_csr_polynomial_expansion.cp311-win_amd64.pyd
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\preprocessing\_data.py
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\preprocessing\_data.py
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\preprocessing\_discretization.py
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\preprocessing\_discretization.py
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\preprocessing\_encoders.py
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\preprocessing\_encoders.py
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\preprocessing\_function_transformer.py
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\preprocessing\_function_transformer.py
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\preprocessing\_label.py
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\preprocessing\_label.py
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\preprocessing\_polynomial.py
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\preprocessing\_polynomial.py
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\preprocessing\_target_encoder.py
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\preprocessing\_target_encoder.py
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\preprocessing\_target_encoder_fast.cp311-win_amd64.pyd
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\preprocessing\_target_encoder_fast.cp311-win_amd64.pyd
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\preprocessing\tests\
#    from C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\preprocessing\~ests
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\random_projection.py
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\random_projection.py
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\semi_supervised\
#    from C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\~emi_supervised
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\svm\__init__.py
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\svm\__init__.py
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\svm\__pycache__\
#    from C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\svm\~_pycache__
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\svm\_base.py
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\svm\_base.py
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\svm\_bounds.py
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\svm\_bounds.py
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\svm\_classes.py
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\svm\_classes.py
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\svm\_liblinear.cp311-win_amd64.pyd
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\svm\_liblinear.cp311-win_amd64.pyd
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\svm\_libsvm.cp311-win_amd64.pyd
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\svm\_libsvm.cp311-win_amd64.pyd
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\svm\_libsvm_sparse.cp311-win_amd64.pyd
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\svm\_libsvm_sparse.cp311-win_amd64.pyd
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\svm\_newrand.cp311-win_amd64.pyd
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\svm\_newrand.cp311-win_amd64.pyd
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\svm\tests\
#    from C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\svm\~ests
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\tests\
#    from C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\~ests
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\tree\__init__.py
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\tree\__init__.py
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\tree\__pycache__\
#    from C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\tree\~_pycache__
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\tree\_classes.py
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\tree\_classes.py
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\tree\_criterion.cp311-win_amd64.pyd
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\tree\_criterion.cp311-win_amd64.pyd
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\tree\_criterion.pxd
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\tree\_criterion.pxd
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\tree\_export.py
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\tree\_export.py
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\tree\_reingold_tilford.py
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\tree\_reingold_tilford.py
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\tree\_splitter.cp311-win_amd64.pyd
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\tree\_splitter.cp311-win_amd64.pyd
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\tree\_splitter.pxd
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\tree\_splitter.pxd
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\tree\_tree.cp311-win_amd64.pyd
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\tree\_tree.cp311-win_amd64.pyd
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\tree\_tree.pxd
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\tree\_tree.pxd
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\tree\_utils.cp311-win_amd64.pyd
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\tree\_utils.cp311-win_amd64.pyd
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\tree\_utils.pxd
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\tree\_utils.pxd
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\tree\tests\
#    from C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\tree\~ests
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\utils\__init__.py
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\utils\__init__.py
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\utils\__pycache__\
#    from C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\utils\~_pycache__
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\utils\_arpack.py
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\utils\_arpack.py
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\utils\_array_api.py
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\utils\_array_api.py
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\utils\_available_if.py
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\utils\_available_if.py
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\utils\_bunch.py
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\utils\_bunch.py
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\utils\_cython_blas.cp311-win_amd64.pyd
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\utils\_cython_blas.cp311-win_amd64.pyd
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\utils\_cython_blas.pxd
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\utils\_cython_blas.pxd
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\utils\_encode.py
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\utils\_encode.py
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\utils\_estimator_html_repr.css
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\utils\_estimator_html_repr.css
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\utils\_estimator_html_repr.py
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\utils\_estimator_html_repr.py
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\utils\_fast_dict.cp311-win_amd64.pyd
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\utils\_fast_dict.cp311-win_amd64.pyd
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\utils\_fast_dict.pxd
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\utils\_fast_dict.pxd
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\utils\_heap.cp311-win_amd64.pyd
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\utils\_heap.cp311-win_amd64.pyd
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\utils\_heap.pxd
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\utils\_heap.pxd
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\utils\_isfinite.cp311-win_amd64.pyd
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\utils\_isfinite.cp311-win_amd64.pyd
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\utils\_joblib.py
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\utils\_joblib.py
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\utils\_mask.py
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\utils\_mask.py
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\utils\_metadata_requests.py
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\utils\_metadata_requests.py
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\utils\_mocking.py
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\utils\_mocking.py
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\utils\_openmp_helpers.cp311-win_amd64.pyd
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\utils\_openmp_helpers.cp311-win_amd64.pyd
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\utils\_openmp_helpers.pxd
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\utils\_openmp_helpers.pxd
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\utils\_param_validation.py
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\utils\_param_validation.py
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\utils\_plotting.py
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\utils\_plotting.py
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\utils\_pprint.py
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\utils\_pprint.py
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\utils\_random.cp311-win_amd64.pyd
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\utils\_random.cp311-win_amd64.pyd
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\utils\_random.pxd
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\utils\_random.pxd
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\utils\_response.py
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\utils\_response.py
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\utils\_seq_dataset.cp311-win_amd64.pyd
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\utils\_seq_dataset.cp311-win_amd64.pyd
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\utils\_seq_dataset.pxd
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\utils\_seq_dataset.pxd
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\utils\_set_output.py
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\utils\_set_output.py
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\utils\_show_versions.py
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\utils\_show_versions.py
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\utils\_sorting.cp311-win_amd64.pyd
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\utils\_sorting.cp311-win_amd64.pyd
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\utils\_sorting.pxd
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\utils\_sorting.pxd
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\utils\_tags.py
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\utils\_tags.py
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\utils\_testing.py
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\utils\_testing.py
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\utils\_typedefs.cp311-win_amd64.pyd
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\utils\_typedefs.cp311-win_amd64.pyd
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\utils\_typedefs.pxd
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\utils\_typedefs.pxd
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\utils\_vector_sentinel.cp311-win_amd64.pyd
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\utils\_vector_sentinel.cp311-win_amd64.pyd
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\utils\_vector_sentinel.pxd
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\utils\_vector_sentinel.pxd
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\utils\_weight_vector.cp311-win_amd64.pyd
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\utils\_weight_vector.cp311-win_amd64.pyd
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\utils\_weight_vector.pxd
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\utils\_weight_vector.pxd
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\utils\arrayfuncs.cp311-win_amd64.pyd
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\utils\arrayfuncs.cp311-win_amd64.pyd
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\utils\class_weight.py
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\utils\class_weight.py
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\utils\deprecation.py
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\utils\deprecation.py
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\utils\discovery.py
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\utils\discovery.py
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\utils\estimator_checks.py
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\utils\estimator_checks.py
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\utils\extmath.py
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\utils\extmath.py
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\utils\fixes.py
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\utils\fixes.py
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\utils\graph.py
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\utils\graph.py
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\utils\metadata_routing.py
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\utils\metadata_routing.py
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\utils\metaestimators.py
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\utils\metaestimators.py
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\utils\multiclass.py
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\utils\multiclass.py
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\utils\murmurhash.cp311-win_amd64.pyd
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\utils\murmurhash.cp311-win_amd64.pyd
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\utils\murmurhash.pxd
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\utils\murmurhash.pxd
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\utils\optimize.py
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\utils\optimize.py
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\utils\parallel.py
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\utils\parallel.py
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\utils\random.py
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\utils\random.py
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\utils\sparsefuncs.py
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\utils\sparsefuncs.py
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\utils\sparsefuncs_fast.cp311-win_amd64.pyd
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\utils\sparsefuncs_fast.cp311-win_amd64.pyd
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\utils\stats.py
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\utils\stats.py
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\utils\tests\
#    from C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\utils\~ests
#   Moving to c:\users\asus\anaconda3\lib\site-packages\sklearn\utils\validation.py
#    from C:\Users\ASUS\AppData\Local\Temp\pip-uninstall-yq6zh29r\utils\validation.py
# ERROR: Could not install packages due to an OSError: [WinError 5] Accès refusé: 'C:\\Users\\ASUS\\anaconda3\\Lib\\site-packages\\sklearn\\.libs\\msvcp140.dll'
# Consider using the `--user` option or check the permissions.
# Requirement already satisfied: imbalanced-learn in c:\users\asus\anaconda3\lib\site-packages (0.11.0)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\asus\anaconda3\lib\site-packages (from imbalanced-learn) (1.24.3)
# Requirement already satisfied: scipy>=1.5.0 in c:\users\asus\anaconda3\lib\site-packages (from imbalanced-learn) (1.11.1)
# Requirement already satisfied: scikit-learn>=1.0.2 in c:\users\asus\anaconda3\lib\site-packages (from imbalanced-learn) (1.4.2)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\asus\anaconda3\lib\site-packages (from imbalanced-learn) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\asus\anaconda3\lib\site-packages (from imbalanced-learn) (2.2.0)

# %%
# !pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\asus\anaconda3\lib\site-packages (3.7.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\asus\anaconda3\lib\site-packages (from matplotlib) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\asus\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\asus\anaconda3\lib\site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\asus\anaconda3\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: numpy>=1.20 in c:\users\asus\anaconda3\lib\site-packages (from matplotlib) (1.24.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\asus\appdata\roaming\python\python311\site-packages (from matplotlib) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\asus\anaconda3\lib\site-packages (from matplotlib) (10.0.1)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in c:\users\asus\anaconda3\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\asus\appdata\roaming\python\python311\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\asus\appdata\roaming\python\python311\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %% [markdown]
# ## I.1. Chargement et préparation des données

# %% [markdown]
# ### A) Importation des données

# %%
import pandas as pd

# Importation des données avec code_insee en index
donnees = pd.read_csv("bdd_finale.csv", sep=',', encoding='utf-8', index_col=0)
donnees.head()
# Out:
#             beneficiaire_trans_eco  moyenne_conso_agri_hab  \
# code_insee
# 22001                            0                2.994071
# 22002                            0                1.283886
# 22003                            0                0.000000
# 22004                            0                0.200325
# 22005                            0                0.121358
#
#             moyenne_conso_indus_hab  moyenne_conso_tertiaire_hab  \
# code_insee
# 22001                      0.000503                     0.631181
# 22002                      0.032120                     0.173206
# 22003                      0.000000                     0.524098
# 22004                      0.675332                     1.267791
# 22005                      0.082905                     1.151104
#
#             moyenne_conso_residentiel_hab  moyenne_conso_totale_hab  \
# code_insee
# 22001                            3.688905                  7.378017
# 22002                            3.248865                  4.775226
# 22003                            2.908468                  3.472740
# 22004                            3.034877                  5.203150
# 22005                            3.532942                  4.926877
#
#             emissions_ges  nb_actes_france_renov  friche  ecoquartiers  ...  \
# code_insee                                                              ...
# 22001               14871                     86       2             0  ...
# 22002                8621                     35       0             0  ...
# 22003                3028                     47       0             0  ...
# 22004               29130                     46       6             0  ...
# 22005                4136                     10       3             0  ...
#
#             CSP_maire  com_variation_encours_dette_ha_pct part_inactifs  \
# code_insee
# 22001              12                                18.9     12.751678
# 22002              54                               -39.3     11.062718
# 22003              56                                99.8     14.239130
# 22004              33                               -34.1     17.234927
# 22005              77                               -14.5     14.188533
#
#             part_actifs  dependance_eco  abstention_municipales  \
# code_insee
# 22001         47.147651             107                    17.4
# 22002         50.522648              96                    53.8
# 22003         48.804348             113                    53.7
# 22004         40.540541             126                    44.8
# 22005         42.371234             140                    22.9
#
#             taux_creation_ent  total_entreprises  part_licencies_sportifs  \
# code_insee
# 22001                    15.0                 20                23.825503
# 22002                    12.1                 33                30.836237
# 22003                    36.7                 30                35.760870
# 22004                    12.6                238                24.282744
# 22005                    18.8                 64                27.891156
#
#             part_jeunes_sans_diplome
# code_insee
# 22001                            9.1
# 22002                            4.0
# 22003                            0.0
# 22004                           12.4
# 22005                            2.6
#
# [5 rows x 30 columns]

# %% [markdown]
# ### B) Formatage des données

# %% [markdown]
# Nous allons pouvoir observer le type des données que nous avons. Cela va nous permettre de déterminer si on a besoin de modifier certaines variables pour qu'elles soient bien en variables catégorielles.

# %%
donnees.dtypes
# Out:
# beneficiaire_trans_eco                  int64
# moyenne_conso_agri_hab                float64
# moyenne_conso_indus_hab               float64
# moyenne_conso_tertiaire_hab           float64
# moyenne_conso_residentiel_hab         float64
# moyenne_conso_totale_hab              float64
# emissions_ges                           int64
# nb_actes_france_renov                   int64
# friche                                  int64
# ecoquartiers                            int64
# part_residences_secondaires           float64
# beneficiaire_prog                       int64
# climat                                 object
# gridens7                                int64
# superf_choro                          float64
# departement                             int64
# gare_tgv                                int64
# part_trajets_voiture                  float64
# med_disp                                int64
# p_pop                                   int64
# CSP_maire                               int64
# com_variation_encours_dette_ha_pct    float64
# part_inactifs                         float64
# part_actifs                           float64
# dependance_eco                          int64
# abstention_municipales                float64
# taux_creation_ent                     float64
# total_entreprises                       int64
# part_licencies_sportifs               float64
# part_jeunes_sans_diplome              float64
# dtype: object

# %%
# Conversion des variables en variables catégorielles
donnees["beneficiaire_trans_eco"] = donnees["beneficiaire_trans_eco"].astype('category')
donnees["ecoquartiers"] = donnees["ecoquartiers"].astype('category')
donnees["beneficiaire_prog"] = donnees["beneficiaire_prog"].astype('category')
donnees["gridens7"] = donnees["gridens7"].astype('category')
donnees["departement"] = donnees["departement"].astype('category')
donnees["gare_tgv"] = donnees["gare_tgv"].astype('category')
donnees["CSP_maire"] = donnees["CSP_maire"].astype('category')


# Cas de la variable climat 
donnees = pd.get_dummies(donnees, columns = ["climat"]) # On crée des variables binaires pour la variable climat car on a des chaînes de caractères

# %%
donnees.dtypes
# Out:
# beneficiaire_trans_eco                category
# moyenne_conso_agri_hab                 float64
# moyenne_conso_indus_hab                float64
# moyenne_conso_tertiaire_hab            float64
# moyenne_conso_residentiel_hab          float64
# moyenne_conso_totale_hab               float64
# emissions_ges                            int64
# nb_actes_france_renov                    int64
# friche                                   int64
# ecoquartiers                          category
# part_residences_secondaires            float64
# beneficiaire_prog                     category
# gridens7                              category
# superf_choro                           float64
# departement                           category
# gare_tgv                              category
# part_trajets_voiture                   float64
# med_disp                                 int64
# p_pop                                    int64
# CSP_maire                             category
# com_variation_encours_dette_ha_pct     float64
# part_inactifs                          float64
# part_actifs                            float64
# dependance_eco                           int64
# abstention_municipales                 float64
# taux_creation_ent                      float64
# total_entreprises                        int64
# part_licencies_sportifs                float64
# part_jeunes_sans_diplome               float64
# climat_Autre                              bool
# climat_Estuaire                           bool
# climat_Mer                                bool
# dtype: object

# %% [markdown]
# Nous allons observer si on a des données manquantes dans notre jeu de données.

# %%
donnees.isna().sum()
# Out:
# beneficiaire_trans_eco                0
# moyenne_conso_agri_hab                0
# moyenne_conso_indus_hab               0
# moyenne_conso_tertiaire_hab           0
# moyenne_conso_residentiel_hab         0
# moyenne_conso_totale_hab              0
# emissions_ges                         0
# nb_actes_france_renov                 0
# friche                                0
# ecoquartiers                          0
# part_residences_secondaires           0
# beneficiaire_prog                     0
# gridens7                              0
# superf_choro                          0
# departement                           0
# gare_tgv                              0
# part_trajets_voiture                  0
# med_disp                              0
# p_pop                                 0
# CSP_maire                             0
# com_variation_encours_dette_ha_pct    0
# part_inactifs                         0
# part_actifs                           0
# dependance_eco                        0
# abstention_municipales                0
# taux_creation_ent                     0
# total_entreprises                     0
# part_licencies_sportifs               0
# part_jeunes_sans_diplome              0
# climat_Autre                          0
# climat_Estuaire                       0
# climat_Mer                            0
# dtype: int64

# %% [markdown]
# ### C) Séparation de la variable à expliquer et des variables explicatives

# %%
# Définir X et y pour avoir les variables explicatives et la variable à expliquer beneficiaire_trans_eco
X = donnees.drop(columns=['beneficiaire_trans_eco'])

# Variable à expliquer : beneficiaire_trans_eco
y = donnees["beneficiaire_trans_eco"]

# %%
import numpy as np

# Convertir les listes en tableaux numpy
X = np.array(X)
y = np.array(y)

# %%
print("Dimensions de X:", X.shape)
print("Dimensions de y:", y.shape)
# Out:
# Dimensions de X: (1189, 31)
# Dimensions de y: (1189,)

# %%
np.unique(y)
# Out:
# array([0, 1], dtype=int64)

# %% [markdown]
# ## I.2. Modélisation

# %% [markdown]
# ### A) Comparaison de modèles à l'aide de PyCaret

# %%
# !pip install pycaret
# Out:
# Requirement already satisfied: pycaret in c:\users\asus\anaconda3\lib\site-packages (3.3.2)
# Requirement already satisfied: ipython>=5.5.0 in c:\users\asus\appdata\roaming\python\python311\site-packages (from pycaret) (8.16.1)
# Requirement already satisfied: ipywidgets>=7.6.5 in c:\users\asus\anaconda3\lib\site-packages (from pycaret) (8.0.4)
# Requirement already satisfied: tqdm>=4.62.0 in c:\users\asus\anaconda3\lib\site-packages (from pycaret) (4.65.0)
# Requirement already satisfied: numpy<1.27,>=1.21 in c:\users\asus\anaconda3\lib\site-packages (from pycaret) (1.24.3)
# Requirement already satisfied: pandas<2.2.0 in c:\users\asus\anaconda3\lib\site-packages (from pycaret) (2.0.3)
# Requirement already satisfied: jinja2>=3 in c:\users\asus\anaconda3\lib\site-packages (from pycaret) (3.1.2)
# Requirement already satisfied: scipy<=1.11.4,>=1.6.1 in c:\users\asus\anaconda3\lib\site-packages (from pycaret) (1.11.1)
# Requirement already satisfied: joblib<1.4,>=1.2.0 in c:\users\asus\anaconda3\lib\site-packages (from pycaret) (1.2.0)
# Requirement already satisfied: scikit-learn>1.4.0 in c:\users\asus\anaconda3\lib\site-packages (from pycaret) (1.4.2)
# Requirement already satisfied: pyod>=1.1.3 in c:\users\asus\anaconda3\lib\site-packages (from pycaret) (1.1.3)
# Collecting imbalanced-learn>=0.12.0 (from pycaret)
#   Obtaining dependency information for imbalanced-learn>=0.12.0 from https://files.pythonhosted.org/packages/5a/fa/267de06c95210580f4b82b45cec1ce1e9ce1f21a01a684367db89e7da70d/imbalanced_learn-0.12.3-py3-none-any.whl.metadata
#   Downloading imbalanced_learn-0.12.3-py3-none-any.whl.metadata (8.3 kB)
# Requirement already satisfied: category-encoders>=2.4.0 in c:\users\asus\anaconda3\lib\site-packages (from pycaret) (2.6.3)
# Requirement already satisfied: lightgbm>=3.0.0 in c:\users\asus\anaconda3\lib\site-packages (from pycaret) (4.3.0)
# Requirement already satisfied: numba>=0.55.0 in c:\users\asus\anaconda3\lib\site-packages (from pycaret) (0.57.1)
# Requirement already satisfied: requests>=2.27.1 in c:\users\asus\anaconda3\lib\site-packages (from pycaret) (2.31.0)
# Requirement already satisfied: psutil>=5.9.0 in c:\users\asus\appdata\roaming\python\python311\site-packages (from pycaret) (5.9.6)
# Requirement already satisfied: markupsafe>=2.0.1 in c:\users\asus\anaconda3\lib\site-packages (from pycaret) (2.1.1)
# Requirement already satisfied: importlib-metadata>=4.12.0 in c:\users\asus\anaconda3\lib\site-packages (from pycaret) (6.0.0)
# Requirement already satisfied: nbformat>=4.2.0 in c:\users\asus\anaconda3\lib\site-packages (from pycaret) (5.9.2)
# Requirement already satisfied: cloudpickle in c:\users\asus\anaconda3\lib\site-packages (from pycaret) (2.2.1)
# Requirement already satisfied: deprecation>=2.1.0 in c:\users\asus\anaconda3\lib\site-packages (from pycaret) (2.1.0)
# Requirement already satisfied: xxhash in c:\users\asus\anaconda3\lib\site-packages (from pycaret) (2.0.2)
# Requirement already satisfied: matplotlib<3.8.0 in c:\users\asus\anaconda3\lib\site-packages (from pycaret) (3.7.2)
# Requirement already satisfied: scikit-plot>=0.3.7 in c:\users\asus\anaconda3\lib\site-packages (from pycaret) (0.3.7)
# Requirement already satisfied: yellowbrick>=1.4 in c:\users\asus\anaconda3\lib\site-packages (from pycaret) (1.5)
# Requirement already satisfied: plotly>=5.14.0 in c:\users\asus\anaconda3\lib\site-packages (from pycaret) (5.19.0)
# Requirement already satisfied: kaleido>=0.2.1 in c:\users\asus\anaconda3\lib\site-packages (from pycaret) (0.2.1)
# Requirement already satisfied: schemdraw==0.15 in c:\users\asus\anaconda3\lib\site-packages (from pycaret) (0.15)
# Requirement already satisfied: plotly-resampler>=0.8.3.1 in c:\users\asus\anaconda3\lib\site-packages (from pycaret) (0.10.0)
# Requirement already satisfied: statsmodels>=0.12.1 in c:\users\asus\anaconda3\lib\site-packages (from pycaret) (0.14.0)
# Requirement already satisfied: sktime==0.26.0 in c:\users\asus\anaconda3\lib\site-packages (from pycaret) (0.26.0)
# Requirement already satisfied: tbats>=1.1.3 in c:\users\asus\anaconda3\lib\site-packages (from pycaret) (1.1.3)
# Requirement already satisfied: pmdarima>=2.0.4 in c:\users\asus\anaconda3\lib\site-packages (from pycaret) (2.0.4)
# Requirement already satisfied: packaging in c:\users\asus\appdata\roaming\python\python311\site-packages (from sktime==0.26.0->pycaret) (23.2)
# Requirement already satisfied: scikit-base<0.8.0 in c:\users\asus\anaconda3\lib\site-packages (from sktime==0.26.0->pycaret) (0.7.8)
# Requirement already satisfied: patsy>=0.5.1 in c:\users\asus\anaconda3\lib\site-packages (from category-encoders>=2.4.0->pycaret) (0.5.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\asus\anaconda3\lib\site-packages (from imbalanced-learn>=0.12.0->pycaret) (2.2.0)
# Requirement already satisfied: zipp>=0.5 in c:\users\asus\anaconda3\lib\site-packages (from importlib-metadata>=4.12.0->pycaret) (3.11.0)
# Requirement already satisfied: backcall in c:\users\asus\appdata\roaming\python\python311\site-packages (from ipython>=5.5.0->pycaret) (0.2.0)
# Requirement already satisfied: decorator in c:\users\asus\appdata\roaming\python\python311\site-packages (from ipython>=5.5.0->pycaret) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\asus\appdata\roaming\python\python311\site-packages (from ipython>=5.5.0->pycaret) (0.19.1)
# Requirement already satisfied: matplotlib-inline in c:\users\asus\appdata\roaming\python\python311\site-packages (from ipython>=5.5.0->pycaret) (0.1.6)
# Requirement already satisfied: pickleshare in c:\users\asus\appdata\roaming\python\python311\site-packages (from ipython>=5.5.0->pycaret) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in c:\users\asus\appdata\roaming\python\python311\site-packages (from ipython>=5.5.0->pycaret) (3.0.39)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\asus\appdata\roaming\python\python311\site-packages (from ipython>=5.5.0->pycaret) (2.16.1)
# Requirement already satisfied: stack-data in c:\users\asus\appdata\roaming\python\python311\site-packages (from ipython>=5.5.0->pycaret) (0.6.3)
# Requirement already satisfied: traitlets>=5 in c:\users\asus\anaconda3\lib\site-packages (from ipython>=5.5.0->pycaret) (5.7.1)
# Requirement already satisfied: colorama in c:\users\asus\appdata\roaming\python\python311\site-packages (from ipython>=5.5.0->pycaret) (0.4.6)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\users\asus\appdata\roaming\python\python311\site-packages (from ipywidgets>=7.6.5->pycaret) (6.25.2)
# Requirement already satisfied: widgetsnbextension~=4.0 in c:\users\asus\anaconda3\lib\site-packages (from ipywidgets>=7.6.5->pycaret) (4.0.5)
# Requirement already satisfied: jupyterlab-widgets~=3.0 in c:\users\asus\anaconda3\lib\site-packages (from ipywidgets>=7.6.5->pycaret) (3.0.5)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\asus\anaconda3\lib\site-packages (from matplotlib<3.8.0->pycaret) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\asus\anaconda3\lib\site-packages (from matplotlib<3.8.0->pycaret) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\asus\anaconda3\lib\site-packages (from matplotlib<3.8.0->pycaret) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\asus\anaconda3\lib\site-packages (from matplotlib<3.8.0->pycaret) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\asus\anaconda3\lib\site-packages (from matplotlib<3.8.0->pycaret) (10.0.1)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in c:\users\asus\anaconda3\lib\site-packages (from matplotlib<3.8.0->pycaret) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\asus\appdata\roaming\python\python311\site-packages (from matplotlib<3.8.0->pycaret) (2.8.2)
# Requirement already satisfied: fastjsonschema in c:\users\asus\anaconda3\lib\site-packages (from nbformat>=4.2.0->pycaret) (2.16.2)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\asus\anaconda3\lib\site-packages (from nbformat>=4.2.0->pycaret) (4.17.3)
# Requirement already satisfied: jupyter-core in c:\users\asus\appdata\roaming\python\python311\site-packages (from nbformat>=4.2.0->pycaret) (5.4.0)
# Requirement already satisfied: llvmlite<0.41,>=0.40.0dev0 in c:\users\asus\anaconda3\lib\site-packages (from numba>=0.55.0->pycaret) (0.40.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\asus\anaconda3\lib\site-packages (from pandas<2.2.0->pycaret) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\asus\anaconda3\lib\site-packages (from pandas<2.2.0->pycaret) (2023.3)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\asus\anaconda3\lib\site-packages (from plotly>=5.14.0->pycaret) (8.2.2)
# Requirement already satisfied: dash>=2.9.0 in c:\users\asus\anaconda3\lib\site-packages (from plotly-resampler>=0.8.3.1->pycaret) (2.17.0)
# Requirement already satisfied: orjson<4.0.0,>=3.8.0 in c:\users\asus\anaconda3\lib\site-packages (from plotly-resampler>=0.8.3.1->pycaret) (3.10.3)
# Requirement already satisfied: tsdownsample>=0.1.3 in c:\users\asus\anaconda3\lib\site-packages (from plotly-resampler>=0.8.3.1->pycaret) (0.1.3)
# Requirement already satisfied: Cython!=0.29.18,!=0.29.31,>=0.29 in c:\users\asus\anaconda3\lib\site-packages (from pmdarima>=2.0.4->pycaret) (3.0.10)
# Requirement already satisfied: urllib3 in c:\users\asus\anaconda3\lib\site-packages (from pmdarima>=2.0.4->pycaret) (1.26.16)
# Requirement already satisfied: setuptools!=50.0.0,>=38.6.0 in c:\users\asus\anaconda3\lib\site-packages (from pmdarima>=2.0.4->pycaret) (68.0.0)
# Requirement already satisfied: six in c:\users\asus\appdata\roaming\python\python311\site-packages (from pyod>=1.1.3->pycaret) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\asus\anaconda3\lib\site-packages (from requests>=2.27.1->pycaret) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\asus\anaconda3\lib\site-packages (from requests>=2.27.1->pycaret) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\asus\anaconda3\lib\site-packages (from requests>=2.27.1->pycaret) (2024.2.2)
# Requirement already satisfied: Flask<3.1,>=1.0.4 in c:\users\asus\anaconda3\lib\site-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (2.2.2)
# Requirement already satisfied: Werkzeug<3.1 in c:\users\asus\anaconda3\lib\site-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (2.2.3)
# Requirement already satisfied: dash-html-components==2.0.0 in c:\users\asus\anaconda3\lib\site-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (2.0.0)
# Requirement already satisfied: dash-core-components==2.0.0 in c:\users\asus\anaconda3\lib\site-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (2.0.0)
# Requirement already satisfied: dash-table==5.0.0 in c:\users\asus\anaconda3\lib\site-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (5.0.0)
# Requirement already satisfied: typing-extensions>=4.1.1 in c:\users\asus\anaconda3\lib\site-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (4.7.1)
# Requirement already satisfied: retrying in c:\users\asus\anaconda3\lib\site-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (1.3.4)
# Requirement already satisfied: nest-asyncio in c:\users\asus\appdata\roaming\python\python311\site-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (1.5.8)
# Requirement already satisfied: comm>=0.1.1 in c:\users\asus\appdata\roaming\python\python311\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret) (0.1.4)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\asus\appdata\roaming\python\python311\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret) (1.8.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\asus\appdata\roaming\python\python311\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret) (8.4.0)
# Requirement already satisfied: pyzmq>=20 in c:\users\asus\appdata\roaming\python\python311\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret) (25.1.1)
# Requirement already satisfied: tornado>=6.1 in c:\users\asus\appdata\roaming\python\python311\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret) (6.3.3)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in c:\users\asus\appdata\roaming\python\python311\site-packages (from jedi>=0.16->ipython>=5.5.0->pycaret) (0.8.3)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\asus\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret) (22.1.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\asus\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret) (0.18.0)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\asus\appdata\roaming\python\python311\site-packages (from jupyter-core->nbformat>=4.2.0->pycaret) (3.11.0)
# Requirement already satisfied: pywin32>=300 in c:\users\asus\appdata\roaming\python\python311\site-packages (from jupyter-core->nbformat>=4.2.0->pycaret) (306)
# Requirement already satisfied: wcwidth in c:\users\asus\appdata\roaming\python\python311\site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=5.5.0->pycaret) (0.2.8)
# Requirement already satisfied: executing>=1.2.0 in c:\users\asus\appdata\roaming\python\python311\site-packages (from stack-data->ipython>=5.5.0->pycaret) (2.0.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\asus\appdata\roaming\python\python311\site-packages (from stack-data->ipython>=5.5.0->pycaret) (2.4.0)
# Requirement already satisfied: pure-eval in c:\users\asus\appdata\roaming\python\python311\site-packages (from stack-data->ipython>=5.5.0->pycaret) (0.2.2)
# Requirement already satisfied: itsdangerous>=2.0 in c:\users\asus\anaconda3\lib\site-packages (from Flask<3.1,>=1.0.4->dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (2.0.1)
# Requirement already satisfied: click>=8.0 in c:\users\asus\anaconda3\lib\site-packages (from Flask<3.1,>=1.0.4->dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (8.0.4)
# Downloading imbalanced_learn-0.12.3-py3-none-any.whl (258 kB)
#    ---------------------------------------- 0.0/258.3 kB ? eta -:--:--
#    ---- ---------------------------------- 30.7/258.3 kB 435.7 kB/s eta 0:00:01
#    ------------- ------------------------- 92.2/258.3 kB 655.4 kB/s eta 0:00:01
#    ------------- ------------------------- 92.2/258.3 kB 655.4 kB/s eta 0:00:01
#    ------------- ------------------------- 92.2/258.3 kB 655.4 kB/s eta 0:00:01
#    ------------- ------------------------- 92.2/258.3 kB 655.4 kB/s eta 0:00:01
#    ---------------- --------------------- 112.6/258.3 kB 297.7 kB/s eta 0:00:01
#    ------------------ ------------------- 122.9/258.3 kB 300.4 kB/s eta 0:00:01
#    --------------------- ---------------- 143.4/258.3 kB 293.9 kB/s eta 0:00:01
#    --------------------- ---------------- 143.4/258.3 kB 293.9 kB/s eta 0:00:01
#    ---------------------- --------------- 153.6/258.3 kB 277.8 kB/s eta 0:00:01
#    ---------------------------- --------- 194.6/258.3 kB 310.3 kB/s eta 0:00:01
#    ------------------------------ ------- 204.8/258.3 kB 303.5 kB/s eta 0:00:01
#    --------------------------------- ---- 225.3/258.3 kB 312.6 kB/s eta 0:00:01
#    --------------------------------- ---- 225.3/258.3 kB 312.6 kB/s eta 0:00:01
#    --------------------------------- ---- 225.3/258.3 kB 312.6 kB/s eta 0:00:01
#    --------------------------------- ---- 225.3/258.3 kB 312.6 kB/s eta 0:00:01
#    --------------------------------- ---- 225.3/258.3 kB 312.6 kB/s eta 0:00:01
#    -------------------------------------  256.0/258.3 kB 266.6 kB/s eta 0:00:01
#    -------------------------------------- 258.3/258.3 kB 260.3 kB/s eta 0:00:00
# Installing collected packages: imbalanced-learn
#   Attempting uninstall: imbalanced-learn
#     Found existing installation: imbalanced-learn 0.11.0
#     Uninstalling imbalanced-learn-0.11.0:
#       Successfully uninstalled imbalanced-learn-0.11.0
# Successfully installed imbalanced-learn-0.12.2

# %%
# On place la variable à expliquer en dernier
# Liste des noms de colonnes dans l'ordre souhaité
noms_colonnes = list(donnees.columns)
noms_colonnes.remove("beneficiaire_trans_eco")
noms_colonnes.append("beneficiaire_trans_eco")

# Réindexer le DataFrame avec les nouvelles colonnes
donnees = donnees.reindex(columns=noms_colonnes)
donnees.head()
# Out:
#             moyenne_conso_agri_hab  moyenne_conso_indus_hab  \
# code_insee
# 22001                     2.994071                 0.000503
# 22002                     1.283886                 0.032120
# 22003                     0.000000                 0.000000
# 22004                     0.200325                 0.675332
# 22005                     0.121358                 0.082905
#
#             moyenne_conso_tertiaire_hab  moyenne_conso_residentiel_hab  \
# code_insee
# 22001                          0.631181                       3.688905
# 22002                          0.173206                       3.248865
# 22003                          0.524098                       2.908468
# 22004                          1.267791                       3.034877
# 22005                          1.151104                       3.532942
#
#             moyenne_conso_totale_hab  emissions_ges  nb_actes_france_renov  \
# code_insee
# 22001                       7.378017          14871                     86
# 22002                       4.775226           8621                     35
# 22003                       3.472740           3028                     47
# 22004                       5.203150          29130                     46
# 22005                       4.926877           4136                     10
#
#             friche ecoquartiers  part_residences_secondaires  ...  \
# code_insee                                                    ...
# 22001            2            0                         12.0  ...
# 22002            0            0                          2.0  ...
# 22003            0            0                          3.4  ...
# 22004            6            0                          5.5  ...
# 22005            3            0                         16.8  ...
#
#            dependance_eco abstention_municipales  taux_creation_ent  \
# code_insee
# 22001                 107                   17.4               15.0
# 22002                  96                   53.8               12.1
# 22003                 113                   53.7               36.7
# 22004                 126                   44.8               12.6
# 22005                 140                   22.9               18.8
#
#            total_entreprises part_licencies_sportifs  \
# code_insee
# 22001                     20               23.825503
# 22002                     33               30.836237
# 22003                     30               35.760870
# 22004                    238               24.282744
# 22005                     64               27.891156
#
#             part_jeunes_sans_diplome  climat_Autre  climat_Estuaire  \
# code_insee
# 22001                            9.1          True            False
# 22002                            4.0          True            False
# 22003                            0.0          True            False
# 22004                           12.4          True            False
# 22005                            2.6          True            False
#
#            climat_Mer  beneficiaire_trans_eco
# code_insee
# 22001           False                       0
# 22002           False                       0
# 22003           False                       0
# 22004           False                       0
# 22005           False                       0
#
# [5 rows x 32 columns]

# %%
# !pip install pycaret scikit-learn==0.23.2
# Out:
# Requirement already satisfied: pycaret in c:\users\asus\anaconda3\lib\site-packages (3.3.2)
# Collecting scikit-learn==0.23.2
#   Using cached scikit-learn-0.23.2.tar.gz (7.2 MB)
#   Installing build dependencies: started
#   Installing build dependencies: still running...
#   Installing build dependencies: finished with status 'error'
#   error: subprocess-exited-with-error
#
#   × pip subprocess to install build dependencies did not run successfully.
#   │ exit code: 1
#   ╰─> [119 lines of output]
#       Ignoring numpy: markers 'python_version == "3.6" and platform_system != "AIX" and platform_python_implementation == "CPython"' don't match your environment
#       Ignoring numpy: markers 'python_version == "3.6" and platform_system != "AIX" and platform_python_implementation != "CPython"' don't match your environment
#       Ignoring numpy: markers 'python_version == "3.7" and platform_system != "AIX"' don't match your environment
#       Ignoring numpy: markers 'python_version == "3.6" and platform_system == "AIX"' don't match your environment
#       Ignoring numpy: markers 'python_version == "3.7" and platform_system == "AIX"' don't match your environment
#       Ignoring numpy: markers 'python_version >= "3.8" and platform_system == "AIX"' don't match your environment
#       Collecting setuptools
#         Obtaining dependency information for setuptools from https://files.pythonhosted.org/packages/de/88/70c5767a0e43eb4451c2200f07d042a4bcd7639276003a9c54a68cfcc1f8/setuptools-70.0.0-py3-none-any.whl.metadata
#         Using cached setuptools-70.0.0-py3-none-any.whl.metadata (5.9 kB)
#       Collecting wheel
#         Obtaining dependency information for wheel from https://files.pythonhosted.org/packages/7d/cd/d7460c9a869b16c3dd4e1e403cce337df165368c71d6af229a74699622ce/wheel-0.43.0-py3-none-any.whl.metadata
#         Using cached wheel-0.43.0-py3-none-any.whl.metadata (2.2 kB)
#       Collecting Cython>=0.28.5
#         Obtaining dependency information for Cython>=0.28.5 from https://files.pythonhosted.org/packages/18/ec/f47a721071d084d6c2b6783eb8d058b964b1450cb708d920d0d792f42001/Cython-3.0.10-cp311-cp311-win_amd64.whl.metadata
#         Using cached Cython-3.0.10-cp311-cp311-win_amd64.whl.metadata (3.2 kB)
#       Collecting numpy==1.17.3
#         Using cached numpy-1.17.3.zip (6.4 MB)
#         Preparing metadata (setup.py): started
#         Preparing metadata (setup.py): finished with status 'done'
#       Collecting scipy>=0.19.1
#         Obtaining dependency information for scipy>=0.19.1 from https://files.pythonhosted.org/packages/4a/48/4513a1a5623a23e95f94abd675ed91cfb19989c58e9f6f7d03990f6caf3d/scipy-1.13.1-cp311-cp311-win_amd64.whl.metadata
#         Using cached scipy-1.13.1-cp311-cp311-win_amd64.whl.metadata (60 kB)
#       INFO: pip is looking at multiple versions of scipy to determine which version is compatible with other requirements. This could take a while.
#         Obtaining dependency information for scipy>=0.19.1 from https://files.pythonhosted.org/packages/d4/a1/d4adf25b6d2bef8d0ad1682829dcfcba97f3f96bb5b6f137bc3e41003cc7/scipy-1.13.0-cp311-cp311-win_amd64.whl.metadata
#         Using cached scipy-1.13.0-cp311-cp311-win_amd64.whl.metadata (60 kB)
#         Obtaining dependency information for scipy>=0.19.1 from https://files.pythonhosted.org/packages/9a/25/5b30cb3efc9566f0ebeaeca1976150316353c17031ad7868ef46de5ab8dc/scipy-1.12.0-cp311-cp311-win_amd64.whl.metadata
#         Using cached scipy-1.12.0-cp311-cp311-win_amd64.whl.metadata (60 kB)
#         Obtaining dependency information for scipy>=0.19.1 from https://files.pythonhosted.org/packages/43/d0/f3cd75b62e1b90f48dbf091261b2fc7ceec14a700e308c50f6a69c83d337/scipy-1.11.4-cp311-cp311-win_amd64.whl.metadata
#         Using cached scipy-1.11.4-cp311-cp311-win_amd64.whl.metadata (60 kB)
#         Obtaining dependency information for scipy>=0.19.1 from https://files.pythonhosted.org/packages/81/d7/d2537d51efb692d0c411e64267ba349e7668d40f5bc73cefe78ccd650dcd/scipy-1.11.3-cp311-cp311-win_amd64.whl.metadata
#         Using cached scipy-1.11.3-cp311-cp311-win_amd64.whl.metadata (60 kB)
#         Obtaining dependency information for scipy>=0.19.1 from https://files.pythonhosted.org/packages/06/15/e73734f9170b66c6a84a0bd7e03586e87e77404e2eb8e34749fc49fa43f7/scipy-1.11.2-cp311-cp311-win_amd64.whl.metadata
#         Using cached scipy-1.11.2-cp311-cp311-win_amd64.whl.metadata (59 kB)
#         Obtaining dependency information for scipy>=0.19.1 from https://files.pythonhosted.org/packages/04/b8/947f40706ee2e316fd1a191688f690c4c2b351c2d043fe9deb9b7940e36e/scipy-1.11.1-cp311-cp311-win_amd64.whl.metadata
#         Using cached scipy-1.11.1-cp311-cp311-win_amd64.whl.metadata (59 kB)
#         Obtaining dependency information for scipy>=0.19.1 from https://files.pythonhosted.org/packages/65/76/903324159e4a3566e518c558aeb21571d642f781d842d8dd0fd9c6b0645a/scipy-1.10.1-cp311-cp311-win_amd64.whl.metadata
#         Using cached scipy-1.10.1-cp311-cp311-win_amd64.whl.metadata (58 kB)
#       INFO: pip is still looking at multiple versions of scipy to determine which version is compatible with other requirements. This could take a while.
#         Obtaining dependency information for scipy>=0.19.1 from https://files.pythonhosted.org/packages/c3/c4/8efe05b8ee86c7276448ef54f71ddb194416b881bc7a0d3c353279eea6aa/scipy-1.10.0-cp311-cp311-win_amd64.whl.metadata
#         Using cached scipy-1.10.0-cp311-cp311-win_amd64.whl.metadata (58 kB)
#         Obtaining dependency information for scipy>=0.19.1 from https://files.pythonhosted.org/packages/42/81/0a64d2204c3b261380ac96c6d61f018528108b62c0e21e6153a58cebf4f6/scipy-1.9.3-cp311-cp311-win_amd64.whl.metadata
#         Using cached scipy-1.9.3-cp311-cp311-win_amd64.whl.metadata (58 kB)
#         Obtaining dependency information for scipy>=0.19.1 from https://files.pythonhosted.org/packages/3c/86/1fa36885e5e69bba07e284429a2b4eed020426792b5ea9edcd0feeee73d7/scipy-1.9.2-cp311-cp311-win_amd64.whl.metadata
#         Using cached scipy-1.9.2-cp311-cp311-win_amd64.whl.metadata (58 kB)
#         Using cached scipy-1.9.1.tar.gz (42.0 MB)
#         Installing build dependencies: started
#         Installing build dependencies: finished with status 'done'
#         Getting requirements to build wheel: started
#         Getting requirements to build wheel: finished with status 'error'
#         error: subprocess-exited-with-error
#
#         × Getting requirements to build wheel did not run successfully.
#         │ exit code: 1
#         ╰─> [55 lines of output]
#             + meson setup --native-file=C:\Users\ASUS\AppData\Local\Temp\pip-install-1nflsgz6\scipy_59c114d2397e4b249542234f7e9e66cb\.mesonpy-native-file.ini -Ddebug=false -Doptimization=2 --prefix=C:\Users\ASUS\anaconda3 C:\Users\ASUS\AppData\Local\Temp\pip-install-1nflsgz6\scipy_59c114d2397e4b249542234f7e9e66cb C:\Users\ASUS\AppData\Local\Temp\pip-install-1nflsgz6\scipy_59c114d2397e4b249542234f7e9e66cb\.mesonpy-_p9oqthy\build
#             The Meson build system
#             Version: 0.62.2
#             Source dir: C:\Users\ASUS\AppData\Local\Temp\pip-install-1nflsgz6\scipy_59c114d2397e4b249542234f7e9e66cb
#             Build dir: C:\Users\ASUS\AppData\Local\Temp\pip-install-1nflsgz6\scipy_59c114d2397e4b249542234f7e9e66cb\.mesonpy-_p9oqthy\build
#             Build type: native build
#             Project name: SciPy
#             Project version: 1.9.1
#             WARNING: Failed to activate VS environment: Could not find C:\Program Files (x86)\Microsoft Visual Studio\Installer\vswhere.exe
#
#             ..\..\meson.build:1:0: ERROR: Unknown compiler(s): [['icl'], ['cl'], ['cc'], ['gcc'], ['clang'], ['clang-cl'], ['pgcc']]
#             The following exception(s) were encountered:
#             Running "icl " gave "[WinError 2] Le fichier spécifié est introuvable"
#             Running "cl /?" gave "[WinError 2] Le fichier spécifié est introuvable"
#             Running "cc --version" gave "[WinError 2] Le fichier spécifié est introuvable"
#             Running "gcc --version" gave "[WinError 2] Le fichier spécifié est introuvable"
#             Running "clang --version" gave "[WinError 2] Le fichier spécifié est introuvable"
#             Running "clang-cl /?" gave "[WinError 2] Le fichier spécifié est introuvable"
#             Running "pgcc --version" gave "[WinError 2] Le fichier spécifié est introuvable"
#
#             A full log can be found at C:\Users\ASUS\AppData\Local\Temp\pip-install-1nflsgz6\scipy_59c114d2397e4b249542234f7e9e66cb\.mesonpy-_p9oqthy\build\meson-logs\meson-log.txt
#             Traceback (most recent call last):
#               File "C:\Users\ASUS\anaconda3\Lib\site-packages\pip\_vendor\pyproject_hooks\_in_process\_in_process.py", line 353, in <module>
#                 main()
#               File "C:\Users\ASUS\anaconda3\Lib\site-packages\pip\_vendor\pyproject_hooks\_in_process\_in_process.py", line 335, in main
#                 json_out['return_val'] = hook(**hook_input['kwargs'])
#                                          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#               File "C:\Users\ASUS\anaconda3\Lib\site-packages\pip\_vendor\pyproject_hooks\_in_process\_in_process.py", line 118, in get_requires_for_build_wheel
#                 return hook(config_settings)
#                        ^^^^^^^^^^^^^^^^^^^^^
#               File "C:\Users\ASUS\AppData\Local\Temp\pip-build-env-hixq36ni\overlay\Lib\site-packages\mesonpy\__init__.py", line 969, in get_requires_for_build_wheel
#                 with _project(config_settings) as project:
#               File "C:\Users\ASUS\anaconda3\Lib\contextlib.py", line 137, in __enter__
#                 return next(self.gen)
#                        ^^^^^^^^^^^^^^
#               File "C:\Users\ASUS\AppData\Local\Temp\pip-build-env-hixq36ni\overlay\Lib\site-packages\mesonpy\__init__.py", line 948, in _project
#                 with Project.with_temp_working_dir(
#               File "C:\Users\ASUS\anaconda3\Lib\contextlib.py", line 137, in __enter__
#                 return next(self.gen)
#                        ^^^^^^^^^^^^^^
#               File "C:\Users\ASUS\AppData\Local\Temp\pip-build-env-hixq36ni\overlay\Lib\site-packages\mesonpy\__init__.py", line 777, in with_temp_working_dir
#                 yield cls(source_dir, tmpdir, build_dir)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#               File "C:\Users\ASUS\AppData\Local\Temp\pip-build-env-hixq36ni\overlay\Lib\site-packages\mesonpy\__init__.py", line 682, in __init__
#                 self._configure(reconfigure=bool(build_dir) and not native_file_mismatch)
#               File "C:\Users\ASUS\AppData\Local\Temp\pip-build-env-hixq36ni\overlay\Lib\site-packages\mesonpy\__init__.py", line 713, in _configure
#                 self._meson(
#               File "C:\Users\ASUS\AppData\Local\Temp\pip-build-env-hixq36ni\overlay\Lib\site-packages\mesonpy\__init__.py", line 696, in _meson
#                 return self._proc('meson', *args)
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^
#               File "C:\Users\ASUS\AppData\Local\Temp\pip-build-env-hixq36ni\overlay\Lib\site-packages\mesonpy\__init__.py", line 691, in _proc
#                 subprocess.check_call(list(args))
#               File "C:\Users\ASUS\anaconda3\Lib\subprocess.py", line 413, in check_call
#                 raise CalledProcessError(retcode, cmd)
#             subprocess.CalledProcessError: Command '['meson', 'setup', '--native-file=C:\\Users\\ASUS\\AppData\\Local\\Temp\\pip-install-1nflsgz6\\scipy_59c114d2397e4b249542234f7e9e66cb\\.mesonpy-native-file.ini', '-Ddebug=false', '-Doptimization=2', '--prefix=C:\\Users\\ASUS\\anaconda3', 'C:\\Users\\ASUS\\AppData\\Local\\Temp\\pip-install-1nflsgz6\\scipy_59c114d2397e4b249542234f7e9e66cb', 'C:\\Users\\ASUS\\AppData\\Local\\Temp\\pip-install-1nflsgz6\\scipy_59c114d2397e4b249542234f7e9e66cb\\.mesonpy-_p9oqthy\\build']' returned non-zero exit status 1.
#             [end of output]
#
#         note: This error originates from a subprocess, and is likely not a problem with pip.
#       error: subprocess-exited-with-error
#
#       × Getting requirements to build wheel did not run successfully.
#       │ exit code: 1
#       ╰─> See above for output.
#
#       note: This error originates from a subprocess, and is likely not a problem with pip.
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: subprocess-exited-with-error
#
# × pip subprocess to install build dependencies did not run successfully.
# │ exit code: 1
# ╰─> See above for output.
#
# note: This error originates from a subprocess, and is likely not a problem with pip.

# %%
from pycaret.classification import *
import mlflow

# Conversion des variables catégorielles en string
for col in donnees.select_dtypes(['category']).columns:
    donnees[col] = donnees[col].astype(str)


# Initialisation de l'environnement PyCaret
clf = setup(data = donnees, 
            target = "beneficiaire_trans_eco", 
            session_id=123,   
            fix_imbalance=True, 
            fix_imbalance_method='smote') # fix_imbalance_method='smote' pour la sur-échantillonnage des données
# Out:
# <style type="text/css">
# #T_8d48d_row10_col1, #T_8d48d_row16_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_8d48d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8d48d_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_8d48d_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8d48d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_8d48d_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_8d48d_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_8d48d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_8d48d_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_8d48d_row1_col1" class="data row1 col1" >beneficiaire_trans_eco</td>
#     </tr>
#     <tr>
#       <th id="T_8d48d_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_8d48d_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_8d48d_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_8d48d_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_8d48d_row3_col0" class="data row3 col0" >Target mapping</td>
#       <td id="T_8d48d_row3_col1" class="data row3 col1" >0: 0, 1: 1</td>
#     </tr>
#     <tr>
#       <th id="T_8d48d_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_8d48d_row4_col0" class="data row4 col0" >Original data shape</td>
#       <td id="T_8d48d_row4_col1" class="data row4 col1" >(1189, 32)</td>
#     </tr>
#     <tr>
#       <th id="T_8d48d_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_8d48d_row5_col0" class="data row5 col0" >Transformed data shape</td>
#       <td id="T_8d48d_row5_col1" class="data row5 col1" >(1739, 41)</td>
#     </tr>
#     <tr>
#       <th id="T_8d48d_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_8d48d_row6_col0" class="data row6 col0" >Transformed train set shape</td>
#       <td id="T_8d48d_row6_col1" class="data row6 col1" >(1382, 41)</td>
#     </tr>
#     <tr>
#       <th id="T_8d48d_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_8d48d_row7_col0" class="data row7 col0" >Transformed test set shape</td>
#       <td id="T_8d48d_row7_col1" class="data row7 col1" >(357, 41)</td>
#     </tr>
#     <tr>
#       <th id="T_8d48d_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_8d48d_row8_col0" class="data row8 col0" >Numeric features</td>
#       <td id="T_8d48d_row8_col1" class="data row8 col1" >22</td>
#     </tr>
#     <tr>
#       <th id="T_8d48d_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_8d48d_row9_col0" class="data row9 col0" >Categorical features</td>
#       <td id="T_8d48d_row9_col1" class="data row9 col1" >6</td>
#     </tr>
#     <tr>
#       <th id="T_8d48d_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_8d48d_row10_col0" class="data row10 col0" >Preprocess</td>
#       <td id="T_8d48d_row10_col1" class="data row10 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_8d48d_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_8d48d_row11_col0" class="data row11 col0" >Imputation type</td>
#       <td id="T_8d48d_row11_col1" class="data row11 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_8d48d_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_8d48d_row12_col0" class="data row12 col0" >Numeric imputation</td>
#       <td id="T_8d48d_row12_col1" class="data row12 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_8d48d_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_8d48d_row13_col0" class="data row13 col0" >Categorical imputation</td>
#       <td id="T_8d48d_row13_col1" class="data row13 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_8d48d_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_8d48d_row14_col0" class="data row14 col0" >Maximum one-hot encoding</td>
#       <td id="T_8d48d_row14_col1" class="data row14 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_8d48d_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_8d48d_row15_col0" class="data row15 col0" >Encoding method</td>
#       <td id="T_8d48d_row15_col1" class="data row15 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_8d48d_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_8d48d_row16_col0" class="data row16 col0" >Fix imbalance</td>
#       <td id="T_8d48d_row16_col1" class="data row16 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_8d48d_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_8d48d_row17_col0" class="data row17 col0" >Fix imbalance method</td>
#       <td id="T_8d48d_row17_col1" class="data row17 col1" >smote</td>
#     </tr>
#     <tr>
#       <th id="T_8d48d_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_8d48d_row18_col0" class="data row18 col0" >Fold Generator</td>
#       <td id="T_8d48d_row18_col1" class="data row18 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_8d48d_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_8d48d_row19_col0" class="data row19 col0" >Fold Number</td>
#       <td id="T_8d48d_row19_col1" class="data row19 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_8d48d_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_8d48d_row20_col0" class="data row20 col0" >CPU Jobs</td>
#       <td id="T_8d48d_row20_col1" class="data row20 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_8d48d_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_8d48d_row21_col0" class="data row21 col0" >Use GPU</td>
#       <td id="T_8d48d_row21_col1" class="data row21 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_8d48d_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_8d48d_row22_col0" class="data row22 col0" >Log Experiment</td>
#       <td id="T_8d48d_row22_col1" class="data row22 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_8d48d_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_8d48d_row23_col0" class="data row23 col0" >Experiment Name</td>
#       <td id="T_8d48d_row23_col1" class="data row23 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_8d48d_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_8d48d_row24_col0" class="data row24 col0" >USI</td>
#       <td id="T_8d48d_row24_col1" class="data row24 col1" >34c7</td>
#     </tr>
#   </tbody>
# </table>

# %%
best_model = compare_models()# Comparaison des modèles
# Out:
# <style type="text/css">
# #T_b3b47 th {
#   text-align: left;
# }
# #T_b3b47_row0_col0, #T_b3b47_row0_col2, #T_b3b47_row0_col4, #T_b3b47_row0_col5, #T_b3b47_row0_col6, #T_b3b47_row0_col7, #T_b3b47_row1_col0, #T_b3b47_row1_col1, #T_b3b47_row1_col2, #T_b3b47_row1_col3, #T_b3b47_row1_col4, #T_b3b47_row1_col5, #T_b3b47_row1_col6, #T_b3b47_row1_col7, #T_b3b47_row2_col0, #T_b3b47_row2_col1, #T_b3b47_row2_col3, #T_b3b47_row3_col0, #T_b3b47_row3_col1, #T_b3b47_row3_col2, #T_b3b47_row3_col3, #T_b3b47_row3_col4, #T_b3b47_row3_col5, #T_b3b47_row3_col6, #T_b3b47_row3_col7, #T_b3b47_row4_col0, #T_b3b47_row4_col1, #T_b3b47_row4_col2, #T_b3b47_row4_col3, #T_b3b47_row4_col4, #T_b3b47_row4_col5, #T_b3b47_row4_col6, #T_b3b47_row4_col7, #T_b3b47_row5_col0, #T_b3b47_row5_col1, #T_b3b47_row5_col2, #T_b3b47_row5_col3, #T_b3b47_row5_col4, #T_b3b47_row5_col5, #T_b3b47_row5_col6, #T_b3b47_row5_col7, #T_b3b47_row6_col0, #T_b3b47_row6_col1, #T_b3b47_row6_col2, #T_b3b47_row6_col3, #T_b3b47_row6_col4, #T_b3b47_row6_col5, #T_b3b47_row6_col6, #T_b3b47_row6_col7, #T_b3b47_row7_col0, #T_b3b47_row7_col1, #T_b3b47_row7_col2, #T_b3b47_row7_col3, #T_b3b47_row7_col4, #T_b3b47_row7_col5, #T_b3b47_row7_col6, #T_b3b47_row7_col7, #T_b3b47_row8_col0, #T_b3b47_row8_col1, #T_b3b47_row8_col2, #T_b3b47_row8_col3, #T_b3b47_row8_col4, #T_b3b47_row8_col5, #T_b3b47_row8_col6, #T_b3b47_row8_col7, #T_b3b47_row9_col0, #T_b3b47_row9_col1, #T_b3b47_row9_col2, #T_b3b47_row9_col3, #T_b3b47_row9_col4, #T_b3b47_row9_col5, #T_b3b47_row9_col6, #T_b3b47_row9_col7, #T_b3b47_row10_col0, #T_b3b47_row10_col1, #T_b3b47_row10_col2, #T_b3b47_row10_col3, #T_b3b47_row10_col4, #T_b3b47_row10_col5, #T_b3b47_row10_col6, #T_b3b47_row10_col7, #T_b3b47_row11_col0, #T_b3b47_row11_col1, #T_b3b47_row11_col2, #T_b3b47_row11_col3, #T_b3b47_row11_col4, #T_b3b47_row11_col5, #T_b3b47_row11_col6, #T_b3b47_row11_col7, #T_b3b47_row12_col0, #T_b3b47_row12_col1, #T_b3b47_row12_col2, #T_b3b47_row12_col3, #T_b3b47_row12_col4, #T_b3b47_row12_col5, #T_b3b47_row12_col6, #T_b3b47_row12_col7, #T_b3b47_row13_col0, #T_b3b47_row13_col1, #T_b3b47_row13_col2, #T_b3b47_row13_col3, #T_b3b47_row13_col4, #T_b3b47_row13_col5, #T_b3b47_row13_col6, #T_b3b47_row13_col7 {
#   text-align: left;
# }
# #T_b3b47_row0_col1, #T_b3b47_row0_col3, #T_b3b47_row2_col2, #T_b3b47_row2_col4, #T_b3b47_row2_col5, #T_b3b47_row2_col6, #T_b3b47_row2_col7 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_b3b47_row0_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# #T_b3b47_row1_col8, #T_b3b47_row2_col8, #T_b3b47_row3_col8, #T_b3b47_row4_col8, #T_b3b47_row5_col8, #T_b3b47_row6_col8, #T_b3b47_row7_col8, #T_b3b47_row8_col8, #T_b3b47_row9_col8, #T_b3b47_row10_col8, #T_b3b47_row11_col8, #T_b3b47_row12_col8, #T_b3b47_row13_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_b3b47">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b3b47_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_b3b47_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_b3b47_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_b3b47_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_b3b47_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_b3b47_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_b3b47_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_b3b47_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_b3b47_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b3b47_level0_row0" class="row_heading level0 row0" >dummy</th>
#       <td id="T_b3b47_row0_col0" class="data row0 col0" >Dummy Classifier</td>
#       <td id="T_b3b47_row0_col1" class="data row0 col1" >0.8305</td>
#       <td id="T_b3b47_row0_col2" class="data row0 col2" >0.5000</td>
#       <td id="T_b3b47_row0_col3" class="data row0 col3" >0.8305</td>
#       <td id="T_b3b47_row0_col4" class="data row0 col4" >0.6898</td>
#       <td id="T_b3b47_row0_col5" class="data row0 col5" >0.7537</td>
#       <td id="T_b3b47_row0_col6" class="data row0 col6" >0.0000</td>
#       <td id="T_b3b47_row0_col7" class="data row0 col7" >0.0000</td>
#       <td id="T_b3b47_row0_col8" class="data row0 col8" >0.1210</td>
#     </tr>
#     <tr>
#       <th id="T_b3b47_level0_row1" class="row_heading level0 row1" >et</th>
#       <td id="T_b3b47_row1_col0" class="data row1 col0" >Extra Trees Classifier</td>
#       <td id="T_b3b47_row1_col1" class="data row1 col1" >0.8197</td>
#       <td id="T_b3b47_row1_col2" class="data row1 col2" >0.7031</td>
#       <td id="T_b3b47_row1_col3" class="data row1 col3" >0.8197</td>
#       <td id="T_b3b47_row1_col4" class="data row1 col4" >0.7828</td>
#       <td id="T_b3b47_row1_col5" class="data row1 col5" >0.7923</td>
#       <td id="T_b3b47_row1_col6" class="data row1 col6" >0.1930</td>
#       <td id="T_b3b47_row1_col7" class="data row1 col7" >0.2100</td>
#       <td id="T_b3b47_row1_col8" class="data row1 col8" >0.2790</td>
#     </tr>
#     <tr>
#       <th id="T_b3b47_level0_row2" class="row_heading level0 row2" >rf</th>
#       <td id="T_b3b47_row2_col0" class="data row2 col0" >Random Forest Classifier</td>
#       <td id="T_b3b47_row2_col1" class="data row2 col1" >0.8126</td>
#       <td id="T_b3b47_row2_col2" class="data row2 col2" >0.7133</td>
#       <td id="T_b3b47_row2_col3" class="data row2 col3" >0.8126</td>
#       <td id="T_b3b47_row2_col4" class="data row2 col4" >0.7885</td>
#       <td id="T_b3b47_row2_col5" class="data row2 col5" >0.7956</td>
#       <td id="T_b3b47_row2_col6" class="data row2 col6" >0.2267</td>
#       <td id="T_b3b47_row2_col7" class="data row2 col7" >0.2373</td>
#       <td id="T_b3b47_row2_col8" class="data row2 col8" >0.3690</td>
#     </tr>
#     <tr>
#       <th id="T_b3b47_level0_row3" class="row_heading level0 row3" >qda</th>
#       <td id="T_b3b47_row3_col0" class="data row3 col0" >Quadratic Discriminant Analysis</td>
#       <td id="T_b3b47_row3_col1" class="data row3 col1" >0.8125</td>
#       <td id="T_b3b47_row3_col2" class="data row3 col2" >0.6267</td>
#       <td id="T_b3b47_row3_col3" class="data row3 col3" >0.8125</td>
#       <td id="T_b3b47_row3_col4" class="data row3 col4" >0.7203</td>
#       <td id="T_b3b47_row3_col5" class="data row3 col5" >0.7515</td>
#       <td id="T_b3b47_row3_col6" class="data row3 col6" >0.0156</td>
#       <td id="T_b3b47_row3_col7" class="data row3 col7" >0.0292</td>
#       <td id="T_b3b47_row3_col8" class="data row3 col8" >0.1300</td>
#     </tr>
#     <tr>
#       <th id="T_b3b47_level0_row4" class="row_heading level0 row4" >lightgbm</th>
#       <td id="T_b3b47_row4_col0" class="data row4 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_b3b47_row4_col1" class="data row4 col1" >0.8089</td>
#       <td id="T_b3b47_row4_col2" class="data row4 col2" >0.7054</td>
#       <td id="T_b3b47_row4_col3" class="data row4 col3" >0.8089</td>
#       <td id="T_b3b47_row4_col4" class="data row4 col4" >0.7816</td>
#       <td id="T_b3b47_row4_col5" class="data row4 col5" >0.7885</td>
#       <td id="T_b3b47_row4_col6" class="data row4 col6" >0.1952</td>
#       <td id="T_b3b47_row4_col7" class="data row4 col7" >0.2085</td>
#       <td id="T_b3b47_row4_col8" class="data row4 col8" >0.5010</td>
#     </tr>
#     <tr>
#       <th id="T_b3b47_level0_row5" class="row_heading level0 row5" >gbc</th>
#       <td id="T_b3b47_row5_col0" class="data row5 col0" >Gradient Boosting Classifier</td>
#       <td id="T_b3b47_row5_col1" class="data row5 col1" >0.7861</td>
#       <td id="T_b3b47_row5_col2" class="data row5 col2" >0.6864</td>
#       <td id="T_b3b47_row5_col3" class="data row5 col3" >0.7861</td>
#       <td id="T_b3b47_row5_col4" class="data row5 col4" >0.7688</td>
#       <td id="T_b3b47_row5_col5" class="data row5 col5" >0.7747</td>
#       <td id="T_b3b47_row5_col6" class="data row5 col6" >0.1691</td>
#       <td id="T_b3b47_row5_col7" class="data row5 col7" >0.1735<

# %% [markdown]
# ### B) Création du modèle

# %%
# Création du modèle afin de prédire une probabilité de succès

model_rf = create_model('rf') # Création du modèle RandomForest

# %%
# Création modèle gradient boosting

model_gbc = create_model('gbc') # Création du modèle Gradient Boosting
# Out:
#
#
# Initiated  . . . . . . . . . . . . . . . . . .              15:26:36
# Status     . . . . . . . . . . . . . . . . . .  Loading Dependencies
# Estimator  . . . . . . . . . . . . . . . . . .     Compiling Library
# <style type="text/css">
# #T_11df4_row10_col0, #T_11df4_row10_col1, #T_11df4_row10_col2, #T_11df4_row10_col3, #T_11df4_row10_col4, #T_11df4_row10_col5, #T_11df4_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_11df4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_11df4_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_11df4_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_11df4_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_11df4_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_11df4_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_11df4_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_11df4_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_11df4_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_11df4_row0_col0" class="data row0 col0" >0.7500</td>
#       <td id="T_11df4_row0_col1" class="data row0 col1" >0.6214</td>
#       <td id="T_11df4_row0_col2" class="data row0 col2" >0.7500</td>
#       <td id="T_11df4_row0_col3" class="data row0 col3" >0.7267</td>
#       <td id="T_11df4_row0_col4" class="data row0 col4" >0.7376</td>
#       <td id="T_11df4_row0_col5" class="data row0 col5" >0.0156</td>
#       <td id="T_11df4_row0_col6" class="data row0 col6" >0.0158</td>
#     </tr>
#     <tr>
#       <th id="T_11df4_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_11df4_row1_col0" class="data row1 col0" >0.7976</td>
#       <td id="T_11df4_row1_col1" class="data row1 col1" >0.6763</td>
#       <td id="T_11df4_row1_col2" class="data row1 col2" >0.7976</td>
#       <td id="T_11df4_row1_col3" class="data row1 col3" >0.7708</td>
#       <td id="T_11df4_row1_col4" class="data row1 col4" >0.7809</td>
#       <td id="T_11df4_row1_col5" class="data row1 col5" >0.2067</td>
#       <td id="T_11df4_row1_col6" class="data row1 col6" >0.2125</td>
#     </tr>
#     <tr>
#       <th id="T_11df4_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_11df4_row2_col0" class="data row2 col0" >0.8072</td>
#       <td id="T_11df4_row2_col1" class="data row2 col1" >0.6936</td>
#       <td id="T_11df4_row2_col2" class="data row2 col2" >0.8072</td>
#       <td id="T_11df4_row2_col3" class="data row2 col3" >0.7580</td>
#       <td id="T_11df4_row2_col4" class="data row2 col4" >0.7740</td>
#       <td id="T_11df4_row2_col5" class="data row2 col5" >0.1099</td>
#       <td id="T_11df4_row2_col6" class="data row2 col6" >0.1227</td>
#     </tr>
#     <tr>
#       <th id="T_11df4_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_11df4_row3_col0" class="data row3 col0" >0.7349</td>
#       <td id="T_11df4_row3_col1" class="data row3 col1" >0.6863</td>
#       <td id="T_11df4_row3_col2" class="data row3 col2" >0.7349</td>
#       <td id="T_11df4_row3_col3" class="data row3 col3" >0.7631</td>
#       <td id="T_11df4_row3_col4" class="data row3 col4" >0.7475</td>
#       <td id="T_11df4_row3_col5" class="data row3 col5" >0.1515</td>
#       <td id="T_11df4_row3_col6" class="data row3 col6" >0.1533</td>
#     </tr>
#     <tr>
#       <th id="T_11df4_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_11df4_row4_col0" class="data row4 col0" >0.7952</td>
#       <td id="T_11df4_row4_col1" class="data row4 col1" >0.7288</td>
#       <td id="T_11df4_row4_col2" class="data row4 col2" >0.7952</td>
#       <td id="T_11df4_row4_col3" class="data row4 col3" >0.7483</td>
#       <td id="T_11df4_row4_col4" class="data row4 col4" >0.7660</td>
#       <td id="T_11df4_row4_col5" class="data row4 col5" >0.0879</td>
#       <td id="T_11df4_row4_col6" class="data row4 col6" >0.0949</td>
#     </tr>
#     <tr>
#       <th id="T_11df4_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_11df4_row5_col0" class="data row5 col0" >0.8072</td>
#       <td id="T_11df4_row5_col1" class="data row5 col1" >0.6936</td>
#       <td id="T_11df4_row5_col2" class="data row5 col2" >0.8072</td>
#       <td id="T_11df4_row5_col3" class="data row5 col3" >0.7849</td>
#       <td id="T_11df4_row5_col4" class="data row5 col4" >0.7939</td>
#       <td id="T_11df4_row5_col5" class="data row5 col5" >0.2243</td>
#       <td id="T_11df4_row5_col6" class="data row5 col6" >0.2286</td>
#     </tr>
#     <tr>
#       <th id="T_11df4_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_11df4_row6_col0" class="data row6 col0" >0.7229</td>
#       <td id="T_11df4_row6_col1" class="data row6 col1" >0.5735</td>
#       <td id="T_11df4_row6_col2" class="data row6 col2" >0.7229</td>
#       <td id="T_11df4_row6_col3" class="data row6 col3" >0.7148</td>
#       <td id="T_11df4_row6_col4" class="data row6 col4" >0.7188</td>
#       <td id="T_11df4_row6_col5" class="data row6 col5" >-0.0170</td>
#       <td id="T_11df4_row6_col6" class="data row6 col6" >-0.0171</td>
#     </tr>
#     <tr>
#       <th id="T_11df4_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_11df4_row7_col0" class="data row7 col0" >0.8434</td>
#       <td id="T_11df4_row7_col1" class="data row7 col1" >0.8219</td>
#       <td id="T_11df4_row7_col2" class="data row7 col2" >0.8434</td>
#       <td id="T_11df4_row7_col3" class="data row7 col3" >0.8239</td>
#       <td id="T_11df4_row7_col4" class="data row7 col4" >0.8291</td>
#       <td id="T_11df4_row7_col5" class="data row7 col5" >0.3488</td>
#       <td id="T_11df4_row7_col6" class="data row7 col6" >0.3603</td>
#     </tr>
#     <tr>
#       <th id="T_11df4_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_11df4_row8_col0" class="data row8 col0" >0.8193</td>
#       <td id="T_11df4_row8_col1" class="data row8 col1" >0.7133</td>
#       <td id="T_11df4_row8_col2" class="data row8 col2" >0.8193</td>
#       <td id="T_11df4_row8_col3" class="data row8 col3" >0.8142</td>
#       <td id="T_11df4_row8_col4" class="data row8 col4" >0.8166</td>
#       <td id="T_11df4_row8_col5" class="data row8 col5" >0.3367</td>
#       <td id="T_11df4_row8_col6" class="data row8 col6" >0.3370</td>
#     </tr>
#     <tr>
#       <th id="T_11df4_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_11df4_row9_col0" class="data row9 col0" >0.7831</td>
#       <td id="T_11df4_row9_col1" class="data row9 col1" >0.6553</td>
#       <td id="T_11df4_row9_col2" class="data row9 col2" >0.7831</td>
#       <td id="T_11df4_row9_col3" class="data row9 col3" >0.7831</td>
#       <td id="T_11df4_row9_col4" class="data row9 col4" >0.7831</td>
#       <td id="T_11df4_row9_col5" class="data row9 col5" >0.2267</td>
#       <td id="T_11df4_row9_col6" class="data row9 col6" >0.2267</td>
#     </tr>
#     <tr>
#       <th id="T_11df4_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_11df4_row10_col0" class="data row10 col0" >0.7861</td>
#       <td id="T_11df4_row10_col1" class="data row10 col1" >0.6864</td>
#       <td id="T_11df4_row10_col2" class="data row10 col2" >0.7861</td>
#       <td id="T_11df4_row10_col3" class="data row10 col3" >0.7688</td>
#       <td id="T_11df4_row10_col4" class="data row10 col4" >0.7747</td>
#       <td id="T_11df4_row10_col5" class="data row10 col5" >0.1691</td>
#       <td id="T_11df4_row10_col6" class="data row10 col6" >0.1735</td>
#     </tr>
#     <tr>
#       <th id="T_11df4_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_11df4_row11_col0" class="data row11 col0" >0.0366</td>
#       <td id="T_11df4_row11_col1" class="data row11 col1" >0.0625</td>
#       <td id="T_11df4_row11_col2" class="data row11 col2" >0.0366</td>
#       <td id="T_11df4_row11_col3" class="data row11 col3" >0.0329</td>
#       <td id="T_11df4_row11_co

# %%
# Création modèle ada boosting

model_ada = create_model('ada') # Création du modèle Ada Boosting
# Out:
#
#
# Initiated  . . . . . . . . . . . . . . . . . .              15:26:48
# Status     . . . . . . . . . . . . . . . . . .  Loading Dependencies
# Estimator  . . . . . . . . . . . . . . . . . .     Compiling Library
# <style type="text/css">
# #T_60e8d_row10_col0, #T_60e8d_row10_col1, #T_60e8d_row10_col2, #T_60e8d_row10_col3, #T_60e8d_row10_col4, #T_60e8d_row10_col5, #T_60e8d_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_60e8d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_60e8d_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_60e8d_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_60e8d_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_60e8d_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_60e8d_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_60e8d_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_60e8d_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_60e8d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_60e8d_row0_col0" class="data row0 col0" >0.6786</td>
#       <td id="T_60e8d_row0_col1" class="data row0 col1" >0.5490</td>
#       <td id="T_60e8d_row0_col2" class="data row0 col2" >0.6786</td>
#       <td id="T_60e8d_row0_col3" class="data row0 col3" >0.7186</td>
#       <td id="T_60e8d_row0_col4" class="data row0 col4" >0.6970</td>
#       <td id="T_60e8d_row0_col5" class="data row0 col5" >-0.0125</td>
#       <td id="T_60e8d_row0_col6" class="data row0 col6" >-0.0127</td>
#     </tr>
#     <tr>
#       <th id="T_60e8d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_60e8d_row1_col0" class="data row1 col0" >0.7857</td>
#       <td id="T_60e8d_row1_col1" class="data row1 col1" >0.6667</td>
#       <td id="T_60e8d_row1_col2" class="data row1 col2" >0.7857</td>
#       <td id="T_60e8d_row1_col3" class="data row1 col3" >0.7338</td>
#       <td id="T_60e8d_row1_col4" class="data row1 col4" >0.7526</td>
#       <td id="T_60e8d_row1_col5" class="data row1 col5" >0.0769</td>
#       <td id="T_60e8d_row1_col6" class="data row1 col6" >0.0843</td>
#     </tr>
#     <tr>
#       <th id="T_60e8d_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_60e8d_row2_col0" class="data row2 col0" >0.8072</td>
#       <td id="T_60e8d_row2_col1" class="data row2 col1" >0.6946</td>
#       <td id="T_60e8d_row2_col2" class="data row2 col2" >0.8072</td>
#       <td id="T_60e8d_row2_col3" class="data row2 col3" >0.7962</td>
#       <td id="T_60e8d_row2_col4" class="data row2 col4" >0.8012</td>
#       <td id="T_60e8d_row2_col5" class="data row2 col5" >0.2711</td>
#       <td id="T_60e8d_row2_col6" class="data row2 col6" >0.2723</td>
#     </tr>
#     <tr>
#       <th id="T_60e8d_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_60e8d_row3_col0" class="data row3 col0" >0.6747</td>
#       <td id="T_60e8d_row3_col1" class="data row3 col1" >0.6139</td>
#       <td id="T_60e8d_row3_col2" class="data row3 col2" >0.6747</td>
#       <td id="T_60e8d_row3_col3" class="data row3 col3" >0.7294</td>
#       <td id="T_60e8d_row3_col4" class="data row3 col4" >0.6985</td>
#       <td id="T_60e8d_row3_col5" class="data row3 col5" >0.0328</td>
#       <td id="T_60e8d_row3_col6" class="data row3 col6" >0.0339</td>
#     </tr>
#     <tr>
#       <th id="T_60e8d_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_60e8d_row4_col0" class="data row4 col0" >0.7831</td>
#       <td id="T_60e8d_row4_col1" class="data row4 col1" >0.7060</td>
#       <td id="T_60e8d_row4_col2" class="data row4 col2" >0.7831</td>
#       <td id="T_60e8d_row4_col3" class="data row4 col3" >0.7705</td>
#       <td id="T_60e8d_row4_col4" class="data row4 col4" >0.7763</td>
#       <td id="T_60e8d_row4_col5" class="data row4 col5" >0.1800</td>
#       <td id="T_60e8d_row4_col6" class="data row4 col6" >0.1808</td>
#     </tr>
#     <tr>
#       <th id="T_60e8d_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_60e8d_row5_col0" class="data row5 col0" >0.8554</td>
#       <td id="T_60e8d_row5_col1" class="data row5 col1" >0.7557</td>
#       <td id="T_60e8d_row5_col2" class="data row5 col2" >0.8554</td>
#       <td id="T_60e8d_row5_col3" class="data row5 col3" >0.8478</td>
#       <td id="T_60e8d_row5_col4" class="data row5 col4" >0.8509</td>
#       <td id="T_60e8d_row5_col5" class="data row5 col5" >0.4533</td>
#       <td id="T_60e8d_row5_col6" class="data row5 col6" >0.4552</td>
#     </tr>
#     <tr>
#       <th id="T_60e8d_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_60e8d_row6_col0" class="data row6 col0" >0.6265</td>
#       <td id="T_60e8d_row6_col1" class="data row6 col1" >0.5233</td>
#       <td id="T_60e8d_row6_col2" class="data row6 col2" >0.6265</td>
#       <td id="T_60e8d_row6_col3" class="data row6 col3" >0.6865</td>
#       <td id="T_60e8d_row6_col4" class="data row6 col4" >0.6539</td>
#       <td id="T_60e8d_row6_col5" class="data row6 col5" >-0.1105</td>
#       <td id="T_60e8d_row6_col6" class="data row6 col6" >-0.1141</td>
#     </tr>
#     <tr>
#       <th id="T_60e8d_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_60e8d_row7_col0" class="data row7 col0" >0.8434</td>
#       <td id="T_60e8d_row7_col1" class="data row7 col1" >0.7950</td>
#       <td id="T_60e8d_row7_col2" class="data row7 col2" >0.8434</td>
#       <td id="T_60e8d_row7_col3" class="data row7 col3" >0.8390</td>
#       <td id="T_60e8d_row7_col4" class="data row7 col4" >0.8410</td>
#       <td id="T_60e8d_row7_col5" class="data row7 col5" >0.4251</td>
#       <td id="T_60e8d_row7_col6" class="data row7 col6" >0.4256</td>
#     </tr>
#     <tr>
#       <th id="T_60e8d_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_60e8d_row8_col0" class="data row8 col0" >0.7349</td>
#       <td id="T_60e8d_row8_col1" class="data row8 col1" >0.6760</td>
#       <td id="T_60e8d_row8_col2" class="data row8 col2" >0.7349</td>
#       <td id="T_60e8d_row8_col3" class="data row8 col3" >0.7494</td>
#       <td id="T_60e8d_row8_col4" class="data row8 col4" >0.7418</td>
#       <td id="T_60e8d_row8_col5" class="data row8 col5" >0.1058</td>
#       <td id="T_60e8d_row8_col6" class="data row8 col6" >0.1061</td>
#     </tr>
#     <tr>
#       <th id="T_60e8d_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_60e8d_row9_col0" class="data row9 col0" >0.7349</td>
#       <td id="T_60e8d_row9_col1" class="data row9 col1" >0.6211</td>
#       <td id="T_60e8d_row9_col2" class="data row9 col2" >0.7349</td>
#       <td id="T_60e8d_row9_col3" class="data row9 col3" >0.7631</td>
#       <td id="T_60e8d_row9_col4" class="data row9 col4" >0.7475</td>
#       <td id="T_60e8d_row9_col5" class="data row9 col5" >0.1515</td>
#       <td id="T_60e8d_row9_col6" class="data row9 col6" >0.1533</td>
#     </tr>
#     <tr>
#       <th id="T_60e8d_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_60e8d_row10_col0" class="data row10 col0" >0.7525</td>
#       <td id="T_60e8d_row10_col1" class="data row10 col1" >0.6601</td>
#       <td id="T_60e8d_row10_col2" class="data row10 col2" >0.7525</td>
#       <td id="T_60e8d_row10_col3" class="data row10 col3" >0.7634</td>
#       <td id="T_60e8d_row10_col4" class="data row10 col4" >0.7561</td>
#       <td id="T_60e8d_row10_col5" class="data row10 col5" >0.1574</td>
#       <td id="T_60e8d_row10_col6" class="data row10 col6" >0.1585</td>
#     </tr>
#     <tr>
#       <th id="T_60e8d_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_60e8d_row11_col0" class="data row11 col0" >0.0720</td>
#       <td id="T_60e8d_row11_col1" class="data row11 col1" >0.0810</td>
#       <td id="T_60e8d_row11_col2" class="data row11 col2" >0.0720</td>
#       <td id="T_60e8d_row11_col3" class="data row11 col3" >0.0491</td>
#       <td id="T_60e8d_row11_

# %%
# Création du modèle d'arbre

model_dt = create_model('dt') # Création du modèle Decision Tree
# Out:
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                  15:26:53
# Status     . . . . . . . . . . . . . . . . . .          Fitting 10 Folds
# Estimator  . . . . . . . . . . . . . . . . . .  Decision Tree Classifier
# <style type="text/css">
# #T_54568_row10_col0, #T_54568_row10_col1, #T_54568_row10_col2, #T_54568_row10_col3, #T_54568_row10_col4, #T_54568_row10_col5, #T_54568_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_54568">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_54568_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_54568_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_54568_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_54568_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_54568_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_54568_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_54568_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_54568_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_54568_row0_col0" class="data row0 col0" >0.7024</td>
#       <td id="T_54568_row0_col1" class="data row0 col1" >0.5357</td>
#       <td id="T_54568_row0_col2" class="data row0 col2" >0.7024</td>
#       <td id="T_54568_row0_col3" class="data row0 col3" >0.7402</td>
#       <td id="T_54568_row0_col4" class="data row0 col4" >0.7194</td>
#       <td id="T_54568_row0_col5" class="data row0 col5" >0.0625</td>
#       <td id="T_54568_row0_col6" class="data row0 col6" >0.0636</td>
#     </tr>
#     <tr>
#       <th id="T_54568_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_54568_row1_col0" class="data row1 col0" >0.7381</td>
#       <td id="T_54568_row1_col1" class="data row1 col1" >0.5797</td>
#       <td id="T_54568_row1_col2" class="data row1 col2" >0.7381</td>
#       <td id="T_54568_row1_col3" class="data row1 col3" >0.7513</td>
#       <td id="T_54568_row1_col4" class="data row1 col4" >0.7444</td>
#       <td id="T_54568_row1_col5" class="data row1 col5" >0.1515</td>
#       <td id="T_54568_row1_col6" class="data row1 col6" >0.1520</td>
#     </tr>
#     <tr>
#       <th id="T_54568_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_54568_row2_col0" class="data row2 col0" >0.6747</td>
#       <td id="T_54568_row2_col1" class="data row2 col1" >0.4343</td>
#       <td id="T_54568_row2_col2" class="data row2 col2" >0.6747</td>
#       <td id="T_54568_row2_col3" class="data row2 col3" >0.6836</td>
#       <td id="T_54568_row2_col4" class="data row2 col4" >0.6791</td>
#       <td id="T_54568_row2_col5" class="data row2 col5" >-0.1278</td>
#       <td id="T_54568_row2_col6" class="data row2 col6" >-0.1279</td>
#     </tr>
#     <tr>
#       <th id="T_54568_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_54568_row3_col0" class="data row3 col0" >0.7229</td>
#       <td id="T_54568_row3_col1" class="data row3 col1" >0.6341</td>
#       <td id="T_54568_row3_col2" class="data row3 col2" >0.7229</td>
#       <td id="T_54568_row3_col3" class="data row3 col3" >0.7857</td>
#       <td id="T_54568_row3_col4" class="data row3 col4" >0.7469</td>
#       <td id="T_54568_row3_col5" class="data row3 col5" >0.2134</td>
#       <td id="T_54568_row3_col6" class="data row3 col6" >0.2243</td>
#     </tr>
#     <tr>
#       <th id="T_54568_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_54568_row4_col0" class="data row4 col0" >0.7229</td>
#       <td id="T_54568_row4_col1" class="data row4 col1" >0.5771</td>
#       <td id="T_54568_row4_col2" class="data row4 col2" >0.7229</td>
#       <td id="T_54568_row4_col3" class="data row4 col3" >0.7588</td>
#       <td id="T_54568_row4_col4" class="data row4 col4" >0.7387</td>
#       <td id="T_54568_row4_col5" class="data row4 col5" >0.1350</td>
#       <td id="T_54568_row4_col6" class="data row4 col6" >0.1375</td>
#     </tr>
#     <tr>
#       <th id="T_54568_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_54568_row5_col0" class="data row5 col0" >0.7831</td>
#       <td id="T_54568_row5_col1" class="data row5 col1" >0.5849</td>
#       <td id="T_54568_row5_col2" class="data row5 col2" >0.7831</td>
#       <td id="T_54568_row5_col3" class="data row5 col3" >0.7705</td>
#       <td id="T_54568_row5_col4" class="data row5 col4" >0.7763</td>
#       <td id="T_54568_row5_col5" class="data row5 col5" >0.1800</td>
#       <td id="T_54568_row5_col6" class="data row5 col6" >0.1808</td>
#     </tr>
#     <tr>
#       <th id="T_54568_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_54568_row6_col0" class="data row6 col0" >0.7229</td>
#       <td id="T_54568_row6_col1" class="data row6 col1" >0.6056</td>
#       <td id="T_54568_row6_col2" class="data row6 col2" >0.7229</td>
#       <td id="T_54568_row6_col3" class="data row6 col3" >0.7723</td>
#       <td id="T_54568_row6_col4" class="data row6 col4" >0.7432</td>
#       <td id="T_54568_row6_col5" class="data row6 col5" >0.1761</td>
#       <td id="T_54568_row6_col6" class="data row6 col6" >0.1819</td>
#     </tr>
#     <tr>
#       <th id="T_54568_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_54568_row7_col0" class="data row7 col0" >0.7711</td>
#       <td id="T_54568_row7_col1" class="data row7 col1" >0.6061</td>
#       <td id="T_54568_row7_col2" class="data row7 col2" >0.7711</td>
#       <td id="T_54568_row7_col3" class="data row7 col3" >0.7775</td>
#       <td id="T_54568_row7_col4" class="data row7 col4" >0.7742</td>
#       <td id="T_54568_row7_col5" class="data row7 col5" >0.2063</td>
#       <td id="T_54568_row7_col6" class="data row7 col6" >0.2065</td>
#     </tr>
#     <tr>
#       <th id="T_54568_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_54568_row8_col0" class="data row8 col0" >0.7711</td>
#       <td id="T_54568_row8_col1" class="data row8 col1" >0.6915</td>
#       <td id="T_54568_row8_col2" class="data row8 col2" >0.7711</td>
#       <td id="T_54568_row8_col3" class="data row8 col3" >0.8151</td>
#       <td id="T_54568_row8_col4" class="data row8 col4" >0.7879</td>
#       <td id="T_54568_row8_col5" class="data row8 col5" >0.3194</td>
#       <td id="T_54568_row8_col6" class="data row8 col6" >0.3299</td>
#     </tr>
#     <tr>
#       <th id="T_54568_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_54568_row9_col0" class="data row9 col0" >0.6627</td>
#       <td id="T_54568_row9_col1" class="data row9 col1" >0.5409</td>
#       <td id="T_54568_row9_col2" class="data row9 col2" >0.6627</td>
#       <td id="T_54568_row9_col3" class="data row9 col3" >0.7397</td>
#       <td id="T_54568_row9_col4" class="data row9 col4" >0.6939</td>
#       <td id="T_54568_row9_col5" class="data row9 col5" >0.0637</td>
#       <td id="T_54568_row9_col6" class="data row9 col6" >0.0675</td>
#     </tr>
#     <tr>
#       <th id="T_54568_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_54568_row10_col0" class="data row10 col0" >0.7272</td>
#       <td id="T_54568_row10_col1" class="data row10 col1" >0.5790</td>
#       <td id="T_54568_row10_col2" class="data row10 col2" >0.7272</td>
#       <td id="T_54568_row10_col3" class="data row10 col3" >0.7595</td>
#       <td id="T_54568_row10_col4" class="data row10 col4" >0.7404</td>
#       <td id="T_54568_row10_col5" class="data row10 col5" >0.1380</td>
#       <td id="T_54568_row10_col6" class="data row10 col6" >0.1416</td>
#     </tr>
#     <tr>
#       <th id="T_54568_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_54568_row11_col0" class="data row11 col0" >0.0383</td>
#       <td id="T_54568_row11_col1" class="data row11 col1" >0.0644</td>
#       <td id="T_54568_row11_col2" class="data row11 col2" >0.0383</td>
#       <td id="T_54568_row11_col3" class="data row11 col3" >0.0331</td>
#       <td id="T_54568_row11_co

# %% [markdown]
# ### C) Optimisation des hyperparamètres

# %%
# Optimisation du modèle RandomForest pour une meilleure performance

tuned_rf = tune_model(model_rf) # Optimisation du modèle RandomForest
# Out:
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                   15:46:55
# Status     . . . . . . . . . . . . . . . . . .  Searching Hyperparameters
# Estimator  . . . . . . . . . . . . . . . . . .   Random Forest Classifier
# Processing:   0%|          | 0/7 [00:00<?, ?it/s]
# Fitting 10 folds for each of 10 candidates, totalling 100 fits
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[27], line 3
#       1 # Optimisation du modèle RandomForest pour une meilleure performance
# ----> 3 tuned_rf = tune_model(model_rf) # Optimisation du modèle RandomForest
#
# File c:\Users\ASUS\anaconda3\Lib\site-packages\pycaret\utils\generic.py:964, in check_if_global_is_not_none.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     962     if globals_d[name] is None:
#     963         raise ValueError(message)
# --> 964 return func(*args, **kwargs)
#
# File c:\Users\ASUS\anaconda3\Lib\site-packages\pycaret\classification\functional.py:1208, in tune_model(estimator, fold, round, n_iter, custom_grid, optimize, custom_scorer, search_library, search_algorithm, early_stopping, early_stopping_max_iters, choose_better, fit_kwargs, groups, return_tuner, verbose, tuner_verbose, return_train_score, **kwargs)
#    1017 @check_if_global_is_not_none(globals(), _CURRENT_EXPERIMENT_DECORATOR_DICT)
#    1018 def tune_model(
#    1019     estimator,
#    (...)
#    1037     **kwargs,
#    1038 ) -> Any:
#    1039     """
#    1040     This function tunes the hyperparameters of a given estimator. The output of
#    1041     this function is a score grid with CV scores by fold of the best selected
#    (...)
#    1205
#    1206     """
# -> 1208     return _CURRENT_EXPERIMENT.tune_model(
#    1209         estimator=estimator,
#    1210         fold=fold,
#    1211         round=round,
#    1212         n_iter=n_iter,
#    1213         custom_grid=custom_grid,
#    1214         optimize=optimize,
#    1215         custom_scorer=custom_scorer,
#    1216         search_library=search_library,
#    1217         search_algorithm=search_algorithm,
#    1218         early_stopping=early_stopping,
#    1219         early_stopping_max_iters=early_stopping_max_iters,
#    1220         choose_better=choose_better,
#    1221         fit_kwargs=fit_kwargs,
#    1222         groups=groups,
#    1223         return_tuner=return_tuner,
#    1224         verbose=verbose,
#    1225         tuner_verbose=tuner_verbose,
#    1226         return_train_score=return_train_score,
#    1227         **kwargs,
#    1228     )
#
# File c:\Users\ASUS\anaconda3\Lib\site-packages\pycaret\classification\oop.py:1558, in ClassificationExperiment.tune_model(self, estimator, fold, round, n_iter, custom_grid, optimize, custom_scorer, search_library, search_algorithm, early_stopping, early_stopping_max_iters, choose_better, fit_kwargs, groups, return_tuner, verbose, tuner_verbose, return_train_score, **kwargs)
#    1367 def tune_model(
#    1368     self,
#    1369     estimator,
#    (...)
#    1387     **kwargs,
#    1388 ) -> Any:
#    1389     """
#    1390     This function tunes the hyperparameters of a given estimator. The output of
#    1391     this function is a score grid with CV scores by fold of the best selected
#    (...)
#    1555
#    1556     """
# -> 1558     return super().tune_model(
#    1559         estimator=estimator,
#    1560         fold=fold,
#    1561         round=round,
#    1562         n_iter=n_iter,
#    1563         custom_grid=custom_grid,
#    1564         optimize=optimize,
#    1565         custom_scorer=custom_scorer,
#    1566         search_library=search_library,
#    1567         search_algorithm=search_algorithm,
#    1568         early_stopping=early_stopping,
#    1569         early_stopping_max_iters=early_stopping_max_iters,
#    1570         choose_better=choose_better,
#    1571         fit_kwargs=fit_kwargs,
#    1572         groups=groups,
#    1573         return_tuner=return_tuner,
#    1574         verbose=verbose,
#    1575         tuner_verbose=tuner_verbose,
#    1576         return_train_score=return_train_score,
#    1577         **kwargs,
#    1578     )
#
# File c:\Users\ASUS\anaconda3\Lib\site-packages\pycaret\internal\pycaret_experiment\supervised_experiment.py:2680, in _SupervisedExperiment.tune_model(self, estimator, fold, round, n_iter, custom_grid, optimize, custom_scorer, search_library, search_algorithm, early_stopping, early_stopping_max_iters, choose_better, fit_kwargs, groups, return_tuner, verbose, tuner_verbose, return_train_score, **kwargs)
#    2672     with patch(
#    2673         "sklearn.model_selection._search.sample_without_replacement",
#    2674         pycaret.internal.patches.sklearn._mp_sample_without_replacement,
#    2675     ):
#    2676         with patch(
#    2677             "sklearn.model_selection._search.ParameterGrid.__getitem__",
#    2678             pycaret.internal.patches.sklearn._mp_ParameterGrid_getitem,
#    2679         ):
# -> 2680             model_grid.fit(data_X, data_y, groups=groups, **fit_kwargs)
#    2681 else:
#    2682     model_grid.fit(data_X, data_y, groups=groups, **fit_kwargs)
#
# File c:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:1474, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1467     estimator._validate_params()
#    1469 with config_context(
#    1470     skip_parameter_validation=(
#    1471         prefer_skip_nested_validation or global_skip_validation
#    1472     )
#    1473 ):
# -> 1474     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\model_selection\_search.py:970, in BaseSearchCV.fit(self, X, y, **params)
#     964     results = self._format_results(
#     965         all_candidate_params, n_splits, all_out, all_more_results
#     966     )
#     968     return results
# --> 970 self._run_search(evaluate_candidates)
#     972 # multimetric is determined here because in the case of a callable
#     973 # self.scoring the return type is only known after calling
#     974 first_test_score = all_out[0]["test_scores"]
#
# File c:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\model_selection\_search.py:1914, in RandomizedSearchCV._run_search(self, evaluate_candidates)
#    1912 def _run_search(self, evaluate_candidates):
#    1913     """Search n_iter candidates from param_distributions"""
# -> 1914     evaluate_candidates(
#    1915         ParameterSampler(
#    1916             self.param_distributions, self.n_iter, random_state=self.random_state
#    1917         )
#    1918     )
#
# File c:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\model_selection\_search.py:916, in BaseSearchCV.fit.<locals>.evaluate_candidates(candidate_params, cv, more_results)
#     908 if self.verbose > 0:
#     909     print(
#     910         "Fitting {0} folds for each of {1} candidates,"
#     911         " totalling {2} fits".format(
#     912             n_splits, n_candidates, n_candidates * n_splits
#     913         )
#     914     )
# --> 916 out = parallel(
#     917     delayed(_fit_and_score)(
#     918         clone(base_estimator),
#     919         X,
#     920         y,
#     921         train=train,
#     922         test=test,
#     923         parameters=parameters,
#     924         split_progress=(split_idx, n_splits),
#     925         candidate_progress=(cand_idx, n_candidates),
#     926         **fit_and_score_kwargs,
#     927     )
#     928     for (cand_idx, parameters), (split_idx, (train, test)) in product(
#     929         enumerate(candidate_params),
#     930         enumerate(cv.split(X, y, **routed_params.splitter.split)),
#     931     )
#     932 )
#     934 if len(out) < 1:
#     935     raise ValueError(
#     936         "No fits were performed. "
#     937         "Was the CV iterator empty? "
#     938         "Were there no candidates?"
#     939     )
#
# File c:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\utils\parallel.py:67, in Parallel.__call__(self, iterable)
#      62 config = get_config()
#      63 iterable_with_config = (
#      64     (_with_config(delayed_func, config), args, kwargs)
#      65     for delayed_func, args, kwargs in iterable
#      66 )
# ---> 67 return super().__call__(iterable_with_config)
#
# File c:\Users\ASUS\anaconda3\Lib\site-packages\joblib\parallel.py:1098, in Parallel.__call__(self, iterable)
#    1095     self._iterating = False
#    1097 with self._backend.retrieval_context():
# -> 1098     self.retrieve()
#    1099 # Make sure that we get a last message telling us we are done
#    1100 elapsed_time = time.time() - self._start_time
#
# File c:\Users\ASUS\anaconda3\Lib\site-packages\joblib\parallel.py:975, in Parallel.retrieve(self)
#     973 try:
#     974     if getattr(self._backend, 'supports_timeout', False):
# --> 975         self._output.extend(job.get(timeout=self.timeout))
#     976     else:
#     977         self._output.extend(job.get())
#
# File c:\Users\ASUS\anaconda3\Lib\site-packages\joblib\_parallel_backends.py:567, in LokyBackend.wrap_future_result(future, timeout)
#     564 """Wrapper for Future.result to implement the same behaviour as
#     565 AsyncResults.get from multiprocessing."""
#     566 try:
# --> 567     return future.result(timeout=timeout)
#     568 except CfTimeoutError as e:
#     569     raise TimeoutError from e
#
# File c:\Users\ASUS\anaconda3\Lib\concurrent\futures\_base.py:451, in Future.result(self, timeout)
#     448 elif self._state == FINISHED:
#     449     return self.__get_result()
# --> 451 self._condition.wait(timeout)
#     453 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#     454     raise CancelledError()
#
# File c:\Users\ASUS\anaconda3\Lib\threading.py:320, in Condition.wait(self, timeout)
#     318 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     319     if timeout is None:
# --> 320         waiter.acquire()
#     321         gotit = True
#     322     else:
#
# KeyboardInterrupt:

# %%
# Optimisation du modèle Gradient Boosting

tuned_gbc = tune_model(model_gbc) # Optimisation du modèle Gradient Boosting
# Out:
# <style type="text/css">
# #T_78cb1_row10_col0, #T_78cb1_row10_col1, #T_78cb1_row10_col2, #T_78cb1_row10_col3, #T_78cb1_row10_col4, #T_78cb1_row10_col5, #T_78cb1_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_78cb1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_78cb1_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_78cb1_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_78cb1_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_78cb1_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_78cb1_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_78cb1_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_78cb1_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_78cb1_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_78cb1_row0_col0" class="data row0 col0" >0.7500</td>
#       <td id="T_78cb1_row0_col1" class="data row0 col1" >0.6673</td>
#       <td id="T_78cb1_row0_col2" class="data row0 col2" >0.7500</td>
#       <td id="T_78cb1_row0_col3" class="data row0 col3" >0.7427</td>
#       <td id="T_78cb1_row0_col4" class="data row0 col4" >0.7463</td>
#       <td id="T_78cb1_row0_col5" class="data row0 col5" >0.0735</td>
#       <td id="T_78cb1_row0_col6" class="data row0 col6" >0.0736</td>
#     </tr>
#     <tr>
#       <th id="T_78cb1_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_78cb1_row1_col0" class="data row1 col0" >0.7976</td>
#       <td id="T_78cb1_row1_col1" class="data row1 col1" >0.7053</td>
#       <td id="T_78cb1_row1_col2" class="data row1 col2" >0.7976</td>
#       <td id="T_78cb1_row1_col3" class="data row1 col3" >0.7587</td>
#       <td id="T_78cb1_row1_col4" class="data row1 col4" >0.7717</td>
#       <td id="T_78cb1_row1_col5" class="data row1 col5" >0.1560</td>
#       <td id="T_78cb1_row1_col6" class="data row1 col6" >0.1664</td>
#     </tr>
#     <tr>
#       <th id="T_78cb1_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_78cb1_row2_col0" class="data row2 col0" >0.8193</td>
#       <td id="T_78cb1_row2_col1" class="data row2 col1" >0.6936</td>
#       <td id="T_78cb1_row2_col2" class="data row2 col2" >0.8193</td>
#       <td id="T_78cb1_row2_col3" class="data row2 col3" >0.7833</td>
#       <td id="T_78cb1_row2_col4" class="data row2 col4" >0.7935</td>
#       <td id="T_78cb1_row2_col5" class="data row2 col5" >0.1952</td>
#       <td id="T_78cb1_row2_col6" class="data row2 col6" >0.2106</td>
#     </tr>
#     <tr>
#       <th id="T_78cb1_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_78cb1_row3_col0" class="data row3 col0" >0.7108</td>
#       <td id="T_78cb1_row3_col1" class="data row3 col1" >0.7277</td>
#       <td id="T_78cb1_row3_col2" class="data row3 col2" >0.7108</td>
#       <td id="T_78cb1_row3_col3" class="data row3 col3" >0.7409</td>
#       <td id="T_78cb1_row3_col4" class="data row3 col4" >0.7246</td>
#       <td id="T_78cb1_row3_col5" class="data row3 col5" >0.0743</td>
#       <td id="T_78cb1_row3_col6" class="data row3 col6" >0.0753</td>
#     </tr>
#     <tr>
#       <th id="T_78cb1_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_78cb1_row4_col0" class="data row4 col0" >0.8193</td>
#       <td id="T_78cb1_row4_col1" class="data row4 col1" >0.7505</td>
#       <td id="T_78cb1_row4_col2" class="data row4 col2" >0.8193</td>
#       <td id="T_78cb1_row4_col3" class="data row4 col3" >0.7940</td>
#       <td id="T_78cb1_row4_col4" class="data row4 col4" >0.8028</td>
#       <td id="T_78cb1_row4_col5" class="data row4 col5" >0.2486</td>
#       <td id="T_78cb1_row4_col6" class="data row4 col6" >0.2568</td>
#     </tr>
#     <tr>
#       <th id="T_78cb1_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_78cb1_row5_col0" class="data row5 col0" >0.8916</td>
#       <td id="T_78cb1_row5_col1" class="data row5 col1" >0.7754</td>
#       <td id="T_78cb1_row5_col2" class="data row5 col2" >0.8916</td>
#       <td id="T_78cb1_row5_col3" class="data row5 col3" >0.8839</td>
#       <td id="T_78cb1_row5_col4" class="data row5 col4" >0.8817</td>
#       <td id="T_78cb1_row5_col5" class="data row5 col5" >0.5492</td>
#       <td id="T_78cb1_row5_col6" class="data row5 col6" >0.5673</td>
#     </tr>
#     <tr>
#       <th id="T_78cb1_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_78cb1_row6_col0" class="data row6 col0" >0.7349</td>
#       <td id="T_78cb1_row6_col1" class="data row6 col1" >0.6636</td>
#       <td id="T_78cb1_row6_col2" class="data row6 col2" >0.7349</td>
#       <td id="T_78cb1_row6_col3" class="data row6 col3" >0.7349</td>
#       <td id="T_78cb1_row6_col4" class="data row6 col4" >0.7349</td>
#       <td id="T_78cb1_row6_col5" class="data row6 col5" >0.0549</td>
#       <td id="T_78cb1_row6_col6" class="data row6 col6" >0.0549</td>
#     </tr>
#     <tr>
#       <th id="T_78cb1_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_78cb1_row7_col0" class="data row7 col0" >0.8313</td>
#       <td id="T_78cb1_row7_col1" class="data row7 col1" >0.7484</td>
#       <td id="T_78cb1_row7_col2" class="data row7 col2" >0.8313</td>
#       <td id="T_78cb1_row7_col3" class="data row7 col3" >0.8048</td>
#       <td id="T_78cb1_row7_col4" class="data row7 col4" >0.8118</td>
#       <td id="T_78cb1_row7_col5" class="data row7 col5" >0.2747</td>
#       <td id="T_78cb1_row7_col6" class="data row7 col6" >0.2890</td>
#     </tr>
#     <tr>
#       <th id="T_78cb1_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_78cb1_row8_col0" class="data row8 col0" >0.8072</td>
#       <td id="T_78cb1_row8_col1" class="data row8 col1" >0.7474</td>
#       <td id="T_78cb1_row8_col2" class="data row8 col2" >0.8072</td>
#       <td id="T_78cb1_row8_col3" class="data row8 col3" >0.7962</td>
#       <td id="T_78cb1_row8_col4" class="data row8 col4" >0.8012</td>
#       <td id="T_78cb1_row8_col5" class="data row8 col5" >0.2711</td>
#       <td id="T_78cb1_row8_col6" class="data row8 col6" >0.2723</td>
#     </tr>
#     <tr>
#       <th id="T_78cb1_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_78cb1_row9_col0" class="data row9 col0" >0.7590</td>
#       <td id="T_78cb1_row9_col1" class="data row9 col1" >0.6708</td>
#       <td id="T_78cb1_row9_col2" class="data row9 col2" >0.7590</td>
#       <td id="T_78cb1_row9_col3" class="data row9 col3" >0.7852</td>
#       <td id="T_78cb1_row9_col4" class="data row9 col4" >0.7705</td>
#       <td id="T_78cb1_row9_col5" class="data row9 col5" >0.2286</td>
#       <td id="T_78cb1_row9_col6" class="data row9 col6" >0.2314</td>
#     </tr>
#     <tr>
#       <th id="T_78cb1_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_78cb1_row10_col0" class="data row10 col0" >0.7921</td>
#       <td id="T_78cb1_row10_col1" class="data row10 col1" >0.7150</td>
#       <td id="T_78cb1_row10_col2" class="data row10 col2" >0.7921</td>
#       <td id="T_78cb1_row10_col3" class="data row10 col3" >0.7825</td>
#       <td id="T_78cb1_row10_col4" class="data row10 col4" >0.7839</td>
#       <td id="T_78cb1_row10_col5" class="data row10 col5" >0.2126</td>
#       <td id="T_78cb1_row10_col6" class="data row10 col6" >0.2197</td>
#     </tr>
#     <tr>
#       <th id="T_78cb1_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_78cb1_row11_col0" class="data row11 col0" >0.0509</td>
#       <td id="T_78cb1_row11_col1" class="data row11 col1" >0.0383</td>
#       <td id="T_78cb1_row11_col2" class="data row11 col2" >0.0509</td>
#       <td id="T_78cb1_row11_col3" class="data row11 col3" >0.0415</td>
#       <td id="T_78cb1_row11_col4
# Fitting 10 folds for each of 10 candidates, totalling 100 fits

# %%
# Optimisation du modèle Ada Boosting

tuned_ada = tune_model(model_ada) # Optimisation du modèle Ada Boosting
# Out:
#
#
# Initiated  . . . . . . . . . . . . . . . . . .              15:28:53
# Status     . . . . . . . . . . . . . . . . . .  Loading Dependencies
# Estimator  . . . . . . . . . . . . . . . . . .     Compiling Library
# <style type="text/css">
# #T_94fe1_row10_col0, #T_94fe1_row10_col1, #T_94fe1_row10_col2, #T_94fe1_row10_col3, #T_94fe1_row10_col4, #T_94fe1_row10_col5, #T_94fe1_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_94fe1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_94fe1_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_94fe1_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_94fe1_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_94fe1_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_94fe1_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_94fe1_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_94fe1_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_94fe1_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_94fe1_row0_col0" class="data row0 col0" >0.7262</td>
#       <td id="T_94fe1_row0_col1" class="data row0 col1" >0.5929</td>
#       <td id="T_94fe1_row0_col2" class="data row0 col2" >0.7262</td>
#       <td id="T_94fe1_row0_col3" class="data row0 col3" >0.7618</td>
#       <td id="T_94fe1_row0_col4" class="data row0 col4" >0.7419</td>
#       <td id="T_94fe1_row0_col5" class="data row0 col5" >0.1375</td>
#       <td id="T_94fe1_row0_col6" class="data row0 col6" >0.1400</td>
#     </tr>
#     <tr>
#       <th id="T_94fe1_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_94fe1_row1_col0" class="data row1 col0" >0.7619</td>
#       <td id="T_94fe1_row1_col1" class="data row1 col1" >0.7459</td>
#       <td id="T_94fe1_row1_col2" class="data row1 col2" >0.7619</td>
#       <td id="T_94fe1_row1_col3" class="data row1 col3" >0.7491</td>
#       <td id="T_94fe1_row1_col4" class="data row1 col4" >0.7551</td>
#       <td id="T_94fe1_row1_col5" class="data row1 col5" >0.1437</td>
#       <td id="T_94fe1_row1_col6" class="data row1 col6" >0.1443</td>
#     </tr>
#     <tr>
#       <th id="T_94fe1_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_94fe1_row2_col0" class="data row2 col0" >0.7831</td>
#       <td id="T_94fe1_row2_col1" class="data row2 col1" >0.7681</td>
#       <td id="T_94fe1_row2_col2" class="data row2 col2" >0.7831</td>
#       <td id="T_94fe1_row2_col3" class="data row2 col3" >0.7953</td>
#       <td id="T_94fe1_row2_col4" class="data row2 col4" >0.7888</td>
#       <td id="T_94fe1_row2_col5" class="data row2 col5" >0.2684</td>
#       <td id="T_94fe1_row2_col6" class="data row2 col6" >0.2693</td>
#     </tr>
#     <tr>
#       <th id="T_94fe1_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_94fe1_row3_col0" class="data row3 col0" >0.7229</td>
#       <td id="T_94fe1_row3_col1" class="data row3 col1" >0.7340</td>
#       <td id="T_94fe1_row3_col2" class="data row3 col2" >0.7229</td>
#       <td id="T_94fe1_row3_col3" class="data row3 col3" >0.7723</td>
#       <td id="T_94fe1_row3_col4" class="data row3 col4" >0.7432</td>
#       <td id="T_94fe1_row3_col5" class="data row3 col5" >0.1761</td>
#       <td id="T_94fe1_row3_col6" class="data row3 col6" >0.1819</td>
#     </tr>
#     <tr>
#       <th id="T_94fe1_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_94fe1_row4_col0" class="data row4 col0" >0.7711</td>
#       <td id="T_94fe1_row4_col1" class="data row4 col1" >0.7070</td>
#       <td id="T_94fe1_row4_col2" class="data row4 col2" >0.7711</td>
#       <td id="T_94fe1_row4_col3" class="data row4 col3" >0.8025</td>
#       <td id="T_94fe1_row4_col4" class="data row4 col4" >0.7841</td>
#       <td id="T_94fe1_row4_col5" class="data row4 col5" >0.2855</td>
#       <td id="T_94fe1_row4_col6" class="data row4 col6" >0.2906</td>
#     </tr>
#     <tr>
#       <th id="T_94fe1_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_94fe1_row5_col0" class="data row5 col0" >0.8313</td>
#       <td id="T_94fe1_row5_col1" class="data row5 col1" >0.7536</td>
#       <td id="T_94fe1_row5_col2" class="data row5 col2" >0.8313</td>
#       <td id="T_94fe1_row5_col3" class="data row5 col3" >0.8313</td>
#       <td id="T_94fe1_row5_col4" class="data row5 col4" >0.8313</td>
#       <td id="T_94fe1_row5_col5" class="data row5 col5" >0.3986</td>
#       <td id="T_94fe1_row5_col6" class="data row5 col6" >0.3986</td>
#     </tr>
#     <tr>
#       <th id="T_94fe1_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_94fe1_row6_col0" class="data row6 col0" >0.6386</td>
#       <td id="T_94fe1_row6_col1" class="data row6 col1" >0.6159</td>
#       <td id="T_94fe1_row6_col2" class="data row6 col2" >0.6386</td>
#       <td id="T_94fe1_row6_col3" class="data row6 col3" >0.7044</td>
#       <td id="T_94fe1_row6_col4" class="data row6 col4" >0.6676</td>
#       <td id="T_94fe1_row6_col5" class="data row6 col5" >-0.0497</td>
#       <td id="T_94fe1_row6_col6" class="data row6 col6" >-0.0518</td>
#     </tr>
#     <tr>
#       <th id="T_94fe1_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_94fe1_row7_col0" class="data row7 col0" >0.7831</td>
#       <td id="T_94fe1_row7_col1" class="data row7 col1" >0.7743</td>
#       <td id="T_94fe1_row7_col2" class="data row7 col2" >0.7831</td>
#       <td id="T_94fe1_row7_col3" class="data row7 col3" >0.7831</td>
#       <td id="T_94fe1_row7_col4" class="data row7 col4" >0.7831</td>
#       <td id="T_94fe1_row7_col5" class="data row7 col5" >0.2267</td>
#       <td id="T_94fe1_row7_col6" class="data row7 col6" >0.2267</td>
#     </tr>
#     <tr>
#       <th id="T_94fe1_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_94fe1_row8_col0" class="data row8 col0" >0.7470</td>
#       <td id="T_94fe1_row8_col1" class="data row8 col1" >0.6843</td>
#       <td id="T_94fe1_row8_col2" class="data row8 col2" >0.7470</td>
#       <td id="T_94fe1_row8_col3" class="data row8 col3" >0.7676</td>
#       <td id="T_94fe1_row8_col4" class="data row8 col4" >0.7564</td>
#       <td id="T_94fe1_row8_col5" class="data row8 col5" >0.1688</td>
#       <td id="T_94fe1_row8_col6" class="data row8 col6" >0.1700</td>
#     </tr>
#     <tr>
#       <th id="T_94fe1_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_94fe1_row9_col0" class="data row9 col0" >0.6747</td>
#       <td id="T_94fe1_row9_col1" class="data row9 col1" >0.5932</td>
#       <td id="T_94fe1_row9_col2" class="data row9 col2" >0.6747</td>
#       <td id="T_94fe1_row9_col3" class="data row9 col3" >0.7433</td>
#       <td id="T_94fe1_row9_col4" class="data row9 col4" >0.7029</td>
#       <td id="T_94fe1_row9_col5" class="data row9 col5" >0.0766</td>
#       <td id="T_94fe1_row9_col6" class="data row9 col6" >0.0805</td>
#     </tr>
#     <tr>
#       <th id="T_94fe1_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_94fe1_row10_col0" class="data row10 col0" >0.7440</td>
#       <td id="T_94fe1_row10_col1" class="data row10 col1" >0.6969</td>
#       <td id="T_94fe1_row10_col2" class="data row10 col2" >0.7440</td>
#       <td id="T_94fe1_row10_col3" class="data row10 col3" >0.7711</td>
#       <td id="T_94fe1_row10_col4" class="data row10 col4" >0.7554</td>
#       <td id="T_94fe1_row10_col5" class="data row10 col5" >0.1832</td>
#       <td id="T_94fe1_row10_col6" class="data row10 col6" >0.1850</td>
#     </tr>
#     <tr>
#       <th id="T_94fe1_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_94fe1_row11_col0" class="data row11 col0" >0.0533</td>
#       <td id="T_94fe1_row11_col1" class="data row11 col1" >0.0682</td>
#       <td id="T_94fe1_row11_col2" class="data row11 col2" >0.0533</td>
#       <td id="T_94fe1_row11_col3" class="data row11 col3" >0.0334</td>
#       <td id="T_94fe1_row11_co
# Fitting 10 folds for each of 10 candidates, totalling 100 fits
# Original model was better than the tuned model, hence it will be returned. NOTE: The display metrics are for the tuned model (not the original one).

# %%
# Optimisation du modèle Decision Tree

tuned_dt = tune_model(model_dt) # Optimisation du modèle Decision Tree
# Out:
# Fitting 10 folds for each of 10 candidates, totalling 100 fits

# %% [markdown]
# ### D) Comparaison des modèles optimisés

# %%
# Comparaison des modèles optimisés
 
compare_models() # Comparaison des modèles optimisés
# Out:
# DummyClassifier(constant=None, random_state=123, strategy='prior')

# %%
# Prédiction des données de test pour obtenir une probabilité de succès avec le modèle RandomForest

predictions = predict_model(tuned_rf, data=donnees) # Prédiction des données de test pour obtenir une probabilité de succès avec le modèle RandomFores
# Out:
# <style type="text/css">
# </style>
# <table id="T_0e556">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0e556_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_0e556_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_0e556_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_0e556_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_0e556_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_0e556_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_0e556_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_0e556_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0e556_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0e556_row0_col0" class="data row0 col0" >Random Forest Classifier</td>
#       <td id="T_0e556_row0_col1" class="data row0 col1" >0.8301</td>
#       <td id="T_0e556_row0_col2" class="data row0 col2" >0.5000</td>
#       <td id="T_0e556_row0_col3" class="data row0 col3" >0.8301</td>
#       <td id="T_0e556_row0_col4" class="data row0 col4" >0.6891</td>
#       <td id="T_0e556_row0_col5" class="data row0 col5" >0.7530</td>
#       <td id="T_0e556_row0_col6" class="data row0 col6" >0.0000</td>
#       <td id="T_0e556_row0_col7" class="data row0 col7" >0.0000</td>
#     </tr>
#   </tbody>
# </table>
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\utils\_encode.py:225, in _encode(values, uniques, check_unknown)
#     224 try:
# --> 225     return _map_to_integer(values, uniques)
#     226 except KeyError as e:
#
# File c:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\utils\_encode.py:165, in _map_to_integer(values, uniques)
#     164 table = _nandict({val: i for i, val in enumerate(uniques)})
# --> 165 return np.array([table[v] for v in values])
#
# File c:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\utils\_encode.py:165, in <listcomp>(.0)
#     164 table = _nandict({val: i for i, val in enumerate(uniques)})
# --> 165 return np.array([table[v] for v in values])
#
# File c:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\utils\_encode.py:159, in _nandict.__missing__(self, key)
#     158     return self.nan_value
# --> 159 raise KeyError(key)
#
# KeyError: 0
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[28], line 3
#       1 # Prédiction des données de test pour obtenir une probabilité de succès avec le modèle RandomForest
# ----> 3 predictions = predict_model(tuned_rf, data=donnees) # Prédiction des données de test pour obtenir une probabilité de succès avec le modèle RandomFores
#
# File c:\Users\ASUS\anaconda3\Lib\site-packages\pycaret\classification\functional.py:2172, in predict_model(estimator, data, probability_threshold, encoded_labels, raw_score, round, verbose)
#    2169 if experiment is None:
#    2170     experiment = _EXPERIMENT_CLASS()
# -> 2172 return experiment.predict_model(
#    2173     estimator=estimator,
#    2174     data=data,
#    2175     probability_threshold=probability_threshold,
#    2176     encoded_labels=encoded_labels,
#    2177     raw_score=raw_score,
#    2178     round=round,
#    2179     verbose=verbose,
#    2180 )
#
# File c:\Users\ASUS\anaconda3\Lib\site-packages\pycaret\classification\oop.py:2824, in ClassificationExperiment.predict_model(self, estimator, data, probability_threshold, encoded_labels, raw_score, round, verbose)
#    2752 def predict_model(
#    2753     self,
#    2754     estimator,
#    (...)
#    2760     verbose: bool = True,
#    2761 ) -> pd.DataFrame:
#    2762     """
#    2763     This function predicts ``Label`` and ``Score`` (probability of predicted
#    2764     class) using a trained model. When ``data`` is None, it predicts label and
#    (...)
#    2821
#    2822     """
# -> 2824     return super().predict_model(
#    2825         estimator=estimator,
#    2826         data=data,
#    2827         probability_threshold=probability_threshold,
#    2828         encoded_labels=encoded_labels,
#    2829         raw_score=raw_score,
#    2830         round=round,
#    2831         verbose=verbose,
#    2832     )
#
# File c:\Users\ASUS\anaconda3\Lib\site-packages\pycaret\internal\pycaret_experiment\supervised_experiment.py:5056, in _SupervisedExperiment.predict_model(self, estimator, data, probability_threshold, encoded_labels, raw_score, round, verbose, ml_usecase, preprocess)
#    5054 if not raw_score:
#    5055     if label_encoder:
# -> 5056         pred = label_encoder.transform(pred)
#    5058     score = pd.DataFrame(
#    5059         data=[s[pred[i]] for i, s in enumerate(score)],
#    5060         index=X_test_.index,
#    5061         columns=[SCORE_COLUMN],
#    5062     )
#    5063 else:
#
# File c:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\preprocessing\_label.py:137, in LabelEncoder.transform(self, y)
#     134 if _num_samples(y) == 0:
#     135     return np.array([])
# --> 137 return _encode(y, uniques=self.classes_)
#
# File c:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\utils\_encode.py:227, in _encode(values, uniques, check_unknown)
#     225         return _map_to_integer(values, uniques)
#     226     except KeyError as e:
# --> 227         raise ValueError(f"y contains previously unseen labels: {str(e)}")
#     228 else:
#     229     if check_unknown:
#
# ValueError: y contains previously unseen labels: 0
