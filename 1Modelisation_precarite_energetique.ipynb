# %% [markdown]
# # I. Modélisation statistique

# %%
# !pip install s3fs
# !pip install pandas
# !pip install scikit-learn==1.2.2
# !pip install imbalanced-learn
# Out:
# Requirement already satisfied: s3fs in c:\users\asus\anaconda3\lib\site-packages (2023.4.0)
# Requirement already satisfied: aiobotocore~=2.5.0 in c:\users\asus\anaconda3\lib\site-packages (from s3fs) (2.5.0)
# Requirement already satisfied: fsspec==2023.4.0 in c:\users\asus\anaconda3\lib\site-packages (from s3fs) (2023.4.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in c:\users\asus\anaconda3\lib\site-packages (from s3fs) (3.8.5)
# Requirement already satisfied: botocore<1.29.77,>=1.29.76 in c:\users\asus\anaconda3\lib\site-packages (from aiobotocore~=2.5.0->s3fs) (1.29.76)
# Requirement already satisfied: wrapt>=1.10.10 in c:\users\asus\anaconda3\lib\site-packages (from aiobotocore~=2.5.0->s3fs) (1.14.1)
# Requirement already satisfied: aioitertools>=0.5.1 in c:\users\asus\anaconda3\lib\site-packages (from aiobotocore~=2.5.0->s3fs) (0.7.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\asus\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (22.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in c:\users\asus\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (2.0.4)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\asus\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (6.0.2)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in c:\users\asus\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\asus\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (1.8.1)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\asus\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (1.3.3)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\asus\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (1.2.0)
# Requirement already satisfied: typing_extensions>=3.7 in c:\users\asus\anaconda3\lib\site-packages (from aioitertools>=0.5.1->aiobotocore~=2.5.0->s3fs) (4.7.1)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in c:\users\asus\anaconda3\lib\site-packages (from botocore<1.29.77,>=1.29.76->aiobotocore~=2.5.0->s3fs) (0.10.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in c:\users\asus\appdata\roaming\python\python311\site-packages (from botocore<1.29.77,>=1.29.76->aiobotocore~=2.5.0->s3fs) (2.8.2)
# Requirement already satisfied: urllib3<1.27,>=1.25.4 in c:\users\asus\anaconda3\lib\site-packages (from botocore<1.29.77,>=1.29.76->aiobotocore~=2.5.0->s3fs) (1.26.16)
# Requirement already satisfied: idna>=2.0 in c:\users\asus\anaconda3\lib\site-packages (from yarl<2.0,>=1.0->aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (3.4)
# Requirement already satisfied: six>=1.5 in c:\users\asus\appdata\roaming\python\python311\site-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.29.77,>=1.29.76->aiobotocore~=2.5.0->s3fs) (1.16.0)
# Requirement already satisfied: pandas in c:\users\asus\anaconda3\lib\site-packages (2.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\asus\appdata\roaming\python\python311\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\asus\anaconda3\lib\site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\asus\anaconda3\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\asus\anaconda3\lib\site-packages (from pandas) (1.24.3)
# Requirement already satisfied: six>=1.5 in c:\users\asus\appdata\roaming\python\python311\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: scikit-learn==1.2.2 in c:\users\asus\anaconda3\lib\site-packages (1.2.2)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\asus\anaconda3\lib\site-packages (from scikit-learn==1.2.2) (1.24.3)
# Requirement already satisfied: scipy>=1.3.2 in c:\users\asus\anaconda3\lib\site-packages (from scikit-learn==1.2.2) (1.11.1)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\asus\anaconda3\lib\site-packages (from scikit-learn==1.2.2) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\asus\anaconda3\lib\site-packages (from scikit-learn==1.2.2) (2.2.0)
# Requirement already satisfied: imbalanced-learn in c:\users\asus\anaconda3\lib\site-packages (0.12.2)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\asus\anaconda3\lib\site-packages (from imbalanced-learn) (1.24.3)
# Requirement already satisfied: scipy>=1.5.0 in c:\users\asus\anaconda3\lib\site-packages (from imbalanced-learn) (1.11.1)
# Requirement already satisfied: scikit-learn>=1.0.2 in c:\users\asus\anaconda3\lib\site-packages (from imbalanced-learn) (1.2.2)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\asus\anaconda3\lib\site-packages (from imbalanced-learn) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\asus\anaconda3\lib\site-packages (from imbalanced-learn) (2.2.0)

# %%
# !pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\asus\anaconda3\lib\site-packages (3.7.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\asus\anaconda3\lib\site-packages (from matplotlib) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\asus\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\asus\anaconda3\lib\site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\asus\anaconda3\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: numpy>=1.20 in c:\users\asus\anaconda3\lib\site-packages (from matplotlib) (1.24.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\asus\appdata\roaming\python\python311\site-packages (from matplotlib) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\asus\anaconda3\lib\site-packages (from matplotlib) (10.0.1)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in c:\users\asus\anaconda3\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\asus\appdata\roaming\python\python311\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\asus\appdata\roaming\python\python311\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %% [markdown]
# ## I.1. Chargement et préparation des données

# %% [markdown]
# ### A) Importation des données

# %%
import pandas as pd

# Importation des données avec code_insee en index
donnees = pd.read_csv("data/bdd_finale.csv", sep=',', encoding='utf-8', index_col=0)
donnees.head()
# Out:
#             beneficiaire_trans_eco  moyenne_conso_agri_hab  \
# code_insee
# 22001                            0                2.994071
# 22002                            0                1.283886
# 22003                            0                0.000000
# 22004                            0                0.200325
# 22005                            0                0.121358
#
#             moyenne_conso_indus_hab  moyenne_conso_tertiaire_hab  \
# code_insee
# 22001                      0.000503                     0.631181
# 22002                      0.032120                     0.173206
# 22003                      0.000000                     0.524098
# 22004                      0.675332                     1.267791
# 22005                      0.082905                     1.151104
#
#             moyenne_conso_residentiel_hab  moyenne_conso_totale_hab  \
# code_insee
# 22001                            3.688905                  7.378017
# 22002                            3.248865                  4.775226
# 22003                            2.908468                  3.472740
# 22004                            3.034877                  5.203150
# 22005                            3.532942                  4.926877
#
#             emissions_ges  nb_actes_france_renov  friche  ecoquartiers  ...  \
# code_insee                                                              ...
# 22001               14871                     88       2             0  ...
# 22002                8621                     38       0             0  ...
# 22003                3028                     49       0             0  ...
# 22004               29130                     46       6             0  ...
# 22005                4136                     10       3             0  ...
#
#             CSP_maire  com_variation_encours_dette_ha_pct part_inactifs  \
# code_insee
# 22001              12                                18.9     12.751678
# 22002              54                               -39.3     11.062718
# 22003              56                                99.8     14.239130
# 22004              33                               -34.1     17.234927
# 22005              77                               -14.5     14.188533
#
#             part_actifs  dependance_eco  abstention_municipales  \
# code_insee
# 22001         47.147651             107                    17.4
# 22002         50.522648              96                    53.8
# 22003         48.804348             113                    53.7
# 22004         40.540541             126                    44.8
# 22005         42.371234             140                    22.9
#
#             taux_creation_ent  total_entreprises  part_licencies_sportifs  \
# code_insee
# 22001                    15.0                 20                23.825503
# 22002                    12.1                 33                30.836237
# 22003                    36.7                 30                35.760870
# 22004                    12.6                238                24.282744
# 22005                    18.8                 64                27.891156
#
#             part_jeunes_sans_diplome
# code_insee
# 22001                            9.1
# 22002                            4.0
# 22003                            0.0
# 22004                           12.4
# 22005                            2.6
#
# [5 rows x 31 columns]

# %% [markdown]
# ### B) Formatage des données

# %% [markdown]
# Nous allons pouvoir observer le type des données que nous avons. Cela va nous permettre de déterminer si on a besoin de modifier certaines variables pour qu'elles soient bien en variables catégorielles.

# %%
donnees.dtypes
# Out:
# beneficiaire_trans_eco                  int64
# moyenne_conso_agri_hab                float64
# moyenne_conso_indus_hab               float64
# moyenne_conso_tertiaire_hab           float64
# moyenne_conso_residentiel_hab         float64
# moyenne_conso_totale_hab              float64
# emissions_ges                           int64
# nb_actes_france_renov                   int64
# friche                                  int64
# ecoquartiers                            int64
# part_residences_secondaires           float64
# beneficiaire_prog                       int64
# climat                                 object
# gridens7                                int64
# superf_choro                          float64
# departement                             int64
# gare_tgv                                int64
# part_trajets_voiture                  float64
# med_disp                                int64
# an                                      int64
# p_pop                                   int64
# CSP_maire                               int64
# com_variation_encours_dette_ha_pct    float64
# part_inactifs                         float64
# part_actifs                           float64
# dependance_eco                          int64
# abstention_municipales                float64
# taux_creation_ent                     float64
# total_entreprises                       int64
# part_licencies_sportifs               float64
# part_jeunes_sans_diplome              float64
# dtype: object

# %%
# Conversion des variables en variables catégorielles
donnees["beneficiaire_trans_eco"] = donnees["beneficiaire_trans_eco"].astype('category')
donnees["ecoquartiers"] = donnees["ecoquartiers"].astype('category')
donnees["beneficiaire_prog"] = donnees["beneficiaire_prog"].astype('category')
donnees["gridens7"] = donnees["gridens7"].astype('category')
donnees["departement"] = donnees["departement"].astype('category')
donnees["gare_tgv"] = donnees["gare_tgv"].astype('category')
donnees["CSP_maire"] = donnees["CSP_maire"].astype('category')


# Cas de la variable climat 
donnees = pd.get_dummies(donnees, columns = ["climat"]) # On crée des variables binaires pour la variable climat car on a des chaînes de caractères

# %%
donnees.dtypes
# Out:
# beneficiaire_trans_eco                category
# moyenne_conso_agri_hab                 float64
# moyenne_conso_indus_hab                float64
# moyenne_conso_tertiaire_hab            float64
# moyenne_conso_residentiel_hab          float64
# moyenne_conso_totale_hab               float64
# emissions_ges                            int64
# nb_actes_france_renov                    int64
# friche                                   int64
# ecoquartiers                          category
# part_residences_secondaires            float64
# beneficiaire_prog                     category
# gridens7                              category
# superf_choro                           float64
# departement                           category
# gare_tgv                              category
# part_trajets_voiture                   float64
# med_disp                                 int64
# an                                       int64
# p_pop                                    int64
# CSP_maire                             category
# com_variation_encours_dette_ha_pct     float64
# part_inactifs                          float64
# part_actifs                            float64
# dependance_eco                           int64
# abstention_municipales                 float64
# taux_creation_ent                      float64
# total_entreprises                        int64
# part_licencies_sportifs                float64
# part_jeunes_sans_diplome               float64
# climat_Autre                              bool
# climat_Estuaire                           bool
# climat_Mer                                bool
# dtype: object

# %% [markdown]
# Nous allons observer si on a des données manquantes dans notre jeu de données.

# %%
donnees.isna().sum()
# Out:
# beneficiaire_trans_eco                0
# moyenne_conso_agri_hab                0
# moyenne_conso_indus_hab               0
# moyenne_conso_tertiaire_hab           0
# moyenne_conso_residentiel_hab         0
# moyenne_conso_totale_hab              0
# emissions_ges                         0
# nb_actes_france_renov                 0
# friche                                0
# ecoquartiers                          0
# part_residences_secondaires           0
# beneficiaire_prog                     0
# gridens7                              0
# superf_choro                          0
# departement                           0
# gare_tgv                              0
# part_trajets_voiture                  0
# med_disp                              0
# an                                    0
# p_pop                                 0
# CSP_maire                             0
# com_variation_encours_dette_ha_pct    0
# part_inactifs                         0
# part_actifs                           0
# dependance_eco                        0
# abstention_municipales                0
# taux_creation_ent                     0
# total_entreprises                     0
# part_licencies_sportifs               0
# part_jeunes_sans_diplome              0
# climat_Autre                          0
# climat_Estuaire                       0
# climat_Mer                            0
# dtype: int64

# %% [markdown]
# ### C) Séparation de la variable à expliquer et des variables explicatives

# %%
# Définir X et y pour avoir les variables explicatives et la variable à expliquer beneficiaire_trans_eco
X = donnees.drop(columns=['beneficiaire_trans_eco'])

# Variable à expliquer : beneficiaire_trans_eco
y = donnees["beneficiaire_trans_eco"]

# %%
import numpy as np

# Convertir les listes en tableaux numpy
X = np.array(X)
y = np.array(y)

# %%
print("Dimensions de X:", X.shape)
print("Dimensions de y:", y.shape)
# Out:
# Dimensions de X: (1207, 32)
# Dimensions de y: (1207,)

# %%
np.unique(y)
# Out:
# array([0, 1], dtype=int64)

# %% [markdown]
# ## I.2. Modélisation

# %% [markdown]
# ### A) Comparaison de modèles à l'aide de PyCaret

# %%
# !pip install pycaret
# Out:
# Requirement already satisfied: pycaret in c:\users\asus\anaconda3\lib\site-packages (3.3.2)
# Requirement already satisfied: ipython>=5.5.0 in c:\users\asus\appdata\roaming\python\python311\site-packages (from pycaret) (8.16.1)
# Requirement already satisfied: ipywidgets>=7.6.5 in c:\users\asus\anaconda3\lib\site-packages (from pycaret) (8.0.4)
# Requirement already satisfied: tqdm>=4.62.0 in c:\users\asus\anaconda3\lib\site-packages (from pycaret) (4.65.0)
# Requirement already satisfied: numpy<1.27,>=1.21 in c:\users\asus\anaconda3\lib\site-packages (from pycaret) (1.24.3)
# Requirement already satisfied: pandas<2.2.0 in c:\users\asus\anaconda3\lib\site-packages (from pycaret) (2.0.3)
# Requirement already satisfied: jinja2>=3 in c:\users\asus\anaconda3\lib\site-packages (from pycaret) (3.1.2)
# Requirement already satisfied: scipy<=1.11.4,>=1.6.1 in c:\users\asus\anaconda3\lib\site-packages (from pycaret) (1.11.1)
# Requirement already satisfied: joblib<1.4,>=1.2.0 in c:\users\asus\anaconda3\lib\site-packages (from pycaret) (1.2.0)
# Collecting scikit-learn>1.4.0 (from pycaret)
#   Obtaining dependency information for scikit-learn>1.4.0 from https://files.pythonhosted.org/packages/5d/55/0403bf2031250ac982c8053397889fbc5a3a2b3798b913dae4f51c3af6a4/scikit_learn-1.5.1-cp311-cp311-win_amd64.whl.metadata
#   Downloading scikit_learn-1.5.1-cp311-cp311-win_amd64.whl.metadata (12 kB)
# Requirement already satisfied: pyod>=1.1.3 in c:\users\asus\anaconda3\lib\site-packages (from pycaret) (1.1.3)
# Requirement already satisfied: imbalanced-learn>=0.12.0 in c:\users\asus\anaconda3\lib\site-packages (from pycaret) (0.12.2)
# Requirement already satisfied: category-encoders>=2.4.0 in c:\users\asus\anaconda3\lib\site-packages (from pycaret) (2.6.3)
# Requirement already satisfied: lightgbm>=3.0.0 in c:\users\asus\anaconda3\lib\site-packages (from pycaret) (4.3.0)
# Requirement already satisfied: numba>=0.55.0 in c:\users\asus\anaconda3\lib\site-packages (from pycaret) (0.57.1)
# Requirement already satisfied: requests>=2.27.1 in c:\users\asus\anaconda3\lib\site-packages (from pycaret) (2.31.0)
# Requirement already satisfied: psutil>=5.9.0 in c:\users\asus\appdata\roaming\python\python311\site-packages (from pycaret) (5.9.6)
# Requirement already satisfied: markupsafe>=2.0.1 in c:\users\asus\anaconda3\lib\site-packages (from pycaret) (2.1.1)
# Requirement already satisfied: importlib-metadata>=4.12.0 in c:\users\asus\anaconda3\lib\site-packages (from pycaret) (6.0.0)
# Requirement already satisfied: nbformat>=4.2.0 in c:\users\asus\anaconda3\lib\site-packages (from pycaret) (5.9.2)
# Requirement already satisfied: cloudpickle in c:\users\asus\anaconda3\lib\site-packages (from pycaret) (2.2.1)
# Requirement already satisfied: deprecation>=2.1.0 in c:\users\asus\anaconda3\lib\site-packages (from pycaret) (2.1.0)
# Requirement already satisfied: xxhash in c:\users\asus\anaconda3\lib\site-packages (from pycaret) (2.0.2)
# Requirement already satisfied: matplotlib<3.8.0 in c:\users\asus\anaconda3\lib\site-packages (from pycaret) (3.7.2)
# Requirement already satisfied: scikit-plot>=0.3.7 in c:\users\asus\anaconda3\lib\site-packages (from pycaret) (0.3.7)
# Requirement already satisfied: yellowbrick>=1.4 in c:\users\asus\anaconda3\lib\site-packages (from pycaret) (1.5)
# Requirement already satisfied: plotly>=5.14.0 in c:\users\asus\anaconda3\lib\site-packages (from pycaret) (5.19.0)
# Requirement already satisfied: kaleido>=0.2.1 in c:\users\asus\anaconda3\lib\site-packages (from pycaret) (0.2.1)
# Requirement already satisfied: schemdraw==0.15 in c:\users\asus\anaconda3\lib\site-packages (from pycaret) (0.15)
# Requirement already satisfied: plotly-resampler>=0.8.3.1 in c:\users\asus\anaconda3\lib\site-packages (from pycaret) (0.10.0)
# Requirement already satisfied: statsmodels>=0.12.1 in c:\users\asus\anaconda3\lib\site-packages (from pycaret) (0.14.0)
# Requirement already satisfied: sktime==0.26.0 in c:\users\asus\anaconda3\lib\site-packages (from pycaret) (0.26.0)
# Requirement already satisfied: tbats>=1.1.3 in c:\users\asus\anaconda3\lib\site-packages (from pycaret) (1.1.3)
# Requirement already satisfied: pmdarima>=2.0.4 in c:\users\asus\anaconda3\lib\site-packages (from pycaret) (2.0.4)
# Requirement already satisfied: packaging in c:\users\asus\appdata\roaming\python\python311\site-packages (from sktime==0.26.0->pycaret) (23.2)
# Requirement already satisfied: scikit-base<0.8.0 in c:\users\asus\anaconda3\lib\site-packages (from sktime==0.26.0->pycaret) (0.7.8)
#   Obtaining dependency information for scikit-learn>1.4.0 from https://files.pythonhosted.org/packages/79/3d/02d5d3ed359498fec3abdf65407d3c07e3b8765af17464969055aaec5171/scikit_learn-1.4.2-cp311-cp311-win_amd64.whl.metadata
#   Using cached scikit_learn-1.4.2-cp311-cp311-win_amd64.whl.metadata (11 kB)
# Requirement already satisfied: patsy>=0.5.1 in c:\users\asus\anaconda3\lib\site-packages (from category-encoders>=2.4.0->pycaret) (0.5.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\asus\anaconda3\lib\site-packages (from imbalanced-learn>=0.12.0->pycaret) (2.2.0)
# Requirement already satisfied: zipp>=0.5 in c:\users\asus\anaconda3\lib\site-packages (from importlib-metadata>=4.12.0->pycaret) (3.11.0)
# Requirement already satisfied: backcall in c:\users\asus\appdata\roaming\python\python311\site-packages (from ipython>=5.5.0->pycaret) (0.2.0)
# Requirement already satisfied: decorator in c:\users\asus\appdata\roaming\python\python311\site-packages (from ipython>=5.5.0->pycaret) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\asus\appdata\roaming\python\python311\site-packages (from ipython>=5.5.0->pycaret) (0.19.1)
# Requirement already satisfied: matplotlib-inline in c:\users\asus\appdata\roaming\python\python311\site-packages (from ipython>=5.5.0->pycaret) (0.1.6)
# Requirement already satisfied: pickleshare in c:\users\asus\appdata\roaming\python\python311\site-packages (from ipython>=5.5.0->pycaret) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in c:\users\asus\appdata\roaming\python\python311\site-packages (from ipython>=5.5.0->pycaret) (3.0.39)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\asus\appdata\roaming\python\python311\site-packages (from ipython>=5.5.0->pycaret) (2.16.1)
# Requirement already satisfied: stack-data in c:\users\asus\appdata\roaming\python\python311\site-packages (from ipython>=5.5.0->pycaret) (0.6.3)
# Requirement already satisfied: traitlets>=5 in c:\users\asus\anaconda3\lib\site-packages (from ipython>=5.5.0->pycaret) (5.7.1)
# Requirement already satisfied: colorama in c:\users\asus\appdata\roaming\python\python311\site-packages (from ipython>=5.5.0->pycaret) (0.4.6)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\users\asus\appdata\roaming\python\python311\site-packages (from ipywidgets>=7.6.5->pycaret) (6.25.2)
# Requirement already satisfied: widgetsnbextension~=4.0 in c:\users\asus\anaconda3\lib\site-packages (from ipywidgets>=7.6.5->pycaret) (4.0.5)
# Requirement already satisfied: jupyterlab-widgets~=3.0 in c:\users\asus\anaconda3\lib\site-packages (from ipywidgets>=7.6.5->pycaret) (3.0.5)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\asus\anaconda3\lib\site-packages (from matplotlib<3.8.0->pycaret) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\asus\anaconda3\lib\site-packages (from matplotlib<3.8.0->pycaret) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\asus\anaconda3\lib\site-packages (from matplotlib<3.8.0->pycaret) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\asus\anaconda3\lib\site-packages (from matplotlib<3.8.0->pycaret) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\asus\anaconda3\lib\site-packages (from matplotlib<3.8.0->pycaret) (10.0.1)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in c:\users\asus\anaconda3\lib\site-packages (from matplotlib<3.8.0->pycaret) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\asus\appdata\roaming\python\python311\site-packages (from matplotlib<3.8.0->pycaret) (2.8.2)
# Requirement already satisfied: fastjsonschema in c:\users\asus\anaconda3\lib\site-packages (from nbformat>=4.2.0->pycaret) (2.16.2)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\asus\anaconda3\lib\site-packages (from nbformat>=4.2.0->pycaret) (4.17.3)
# Requirement already satisfied: jupyter-core in c:\users\asus\appdata\roaming\python\python311\site-packages (from nbformat>=4.2.0->pycaret) (5.4.0)
# Requirement already satisfied: llvmlite<0.41,>=0.40.0dev0 in c:\users\asus\anaconda3\lib\site-packages (from numba>=0.55.0->pycaret) (0.40.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\asus\anaconda3\lib\site-packages (from pandas<2.2.0->pycaret) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\asus\anaconda3\lib\site-packages (from pandas<2.2.0->pycaret) (2023.3)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\asus\anaconda3\lib\site-packages (from plotly>=5.14.0->pycaret) (8.2.2)
# Requirement already satisfied: dash>=2.9.0 in c:\users\asus\anaconda3\lib\site-packages (from plotly-resampler>=0.8.3.1->pycaret) (2.17.0)
# Requirement already satisfied: orjson<4.0.0,>=3.8.0 in c:\users\asus\anaconda3\lib\site-packages (from plotly-resampler>=0.8.3.1->pycaret) (3.10.3)
# Requirement already satisfied: tsdownsample>=0.1.3 in c:\users\asus\anaconda3\lib\site-packages (from plotly-resampler>=0.8.3.1->pycaret) (0.1.3)
# Requirement already satisfied: Cython!=0.29.18,!=0.29.31,>=0.29 in c:\users\asus\anaconda3\lib\site-packages (from pmdarima>=2.0.4->pycaret) (3.0.10)
# Requirement already satisfied: urllib3 in c:\users\asus\anaconda3\lib\site-packages (from pmdarima>=2.0.4->pycaret) (1.26.16)
# Requirement already satisfied: setuptools!=50.0.0,>=38.6.0 in c:\users\asus\anaconda3\lib\site-packages (from pmdarima>=2.0.4->pycaret) (68.0.0)
# Requirement already satisfied: six in c:\users\asus\appdata\roaming\python\python311\site-packages (from pyod>=1.1.3->pycaret) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\asus\anaconda3\lib\site-packages (from requests>=2.27.1->pycaret) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\asus\anaconda3\lib\site-packages (from requests>=2.27.1->pycaret) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\asus\anaconda3\lib\site-packages (from requests>=2.27.1->pycaret) (2024.2.2)
# Requirement already satisfied: Flask<3.1,>=1.0.4 in c:\users\asus\anaconda3\lib\site-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (2.2.2)
# Requirement already satisfied: Werkzeug<3.1 in c:\users\asus\anaconda3\lib\site-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (2.2.3)
# Requirement already satisfied: dash-html-components==2.0.0 in c:\users\asus\anaconda3\lib\site-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (2.0.0)
# Requirement already satisfied: dash-core-components==2.0.0 in c:\users\asus\anaconda3\lib\site-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (2.0.0)
# Requirement already satisfied: dash-table==5.0.0 in c:\users\asus\anaconda3\lib\site-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (5.0.0)
# Requirement already satisfied: typing-extensions>=4.1.1 in c:\users\asus\anaconda3\lib\site-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (4.7.1)
# Requirement already satisfied: retrying in c:\users\asus\anaconda3\lib\site-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (1.3.4)
# Requirement already satisfied: nest-asyncio in c:\users\asus\appdata\roaming\python\python311\site-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (1.5.8)
# Requirement already satisfied: comm>=0.1.1 in c:\users\asus\appdata\roaming\python\python311\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret) (0.1.4)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\asus\appdata\roaming\python\python311\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret) (1.8.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\asus\appdata\roaming\python\python311\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret) (8.4.0)
# Requirement already satisfied: pyzmq>=20 in c:\users\asus\appdata\roaming\python\python311\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret) (25.1.1)
# Requirement already satisfied: tornado>=6.1 in c:\users\asus\appdata\roaming\python\python311\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret) (6.3.3)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in c:\users\asus\appdata\roaming\python\python311\site-packages (from jedi>=0.16->ipython>=5.5.0->pycaret) (0.8.3)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\asus\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret) (22.1.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\asus\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret) (0.18.0)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\asus\appdata\roaming\python\python311\site-packages (from jupyter-core->nbformat>=4.2.0->pycaret) (3.11.0)
# Requirement already satisfied: pywin32>=300 in c:\users\asus\appdata\roaming\python\python311\site-packages (from jupyter-core->nbformat>=4.2.0->pycaret) (306)
# Requirement already satisfied: wcwidth in c:\users\asus\appdata\roaming\python\python311\site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=5.5.0->pycaret) (0.2.8)
# Requirement already satisfied: executing>=1.2.0 in c:\users\asus\appdata\roaming\python\python311\site-packages (from stack-data->ipython>=5.5.0->pycaret) (2.0.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\asus\appdata\roaming\python\python311\site-packages (from stack-data->ipython>=5.5.0->pycaret) (2.4.0)
# Requirement already satisfied: pure-eval in c:\users\asus\appdata\roaming\python\python311\site-packages (from stack-data->ipython>=5.5.0->pycaret) (0.2.2)
# Requirement already satisfied: itsdangerous>=2.0 in c:\users\asus\anaconda3\lib\site-packages (from Flask<3.1,>=1.0.4->dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (2.0.1)
# Requirement already satisfied: click>=8.0 in c:\users\asus\anaconda3\lib\site-packages (from Flask<3.1,>=1.0.4->dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (8.0.4)
# Using cached scikit_learn-1.4.2-cp311-cp311-win_amd64.whl (10.6 MB)
# Installing collected packages: scikit-learn
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.2.2
#     Uninstalling scikit-learn-1.2.2:
#       Successfully uninstalled scikit-learn-1.2.2
# ERROR: Could not install packages due to an OSError: [WinError 5] Accès refusé: 'C:\\Users\\ASUS\\anaconda3\\Lib\\site-packages\\sklearn\\~libs\\msvcp140.dll'
# Consider using the `--user` option or check the permissions.

# %%
# On place la variable à expliquer en dernier
# Liste des noms de colonnes dans l'ordre souhaité
noms_colonnes = list(donnees.columns)
noms_colonnes.remove("beneficiaire_trans_eco")
noms_colonnes.append("beneficiaire_trans_eco")

# Réindexer le DataFrame avec les nouvelles colonnes
donnees = donnees.reindex(columns=noms_colonnes)
donnees.head()
# Out:
#             moyenne_conso_agri_hab  moyenne_conso_indus_hab  \
# code_insee
# 22001                     2.994071                 0.000503
# 22002                     1.283886                 0.032120
# 22003                     0.000000                 0.000000
# 22004                     0.200325                 0.675332
# 22005                     0.121358                 0.082905
#
#             moyenne_conso_tertiaire_hab  moyenne_conso_residentiel_hab  \
# code_insee
# 22001                          0.631181                       3.688905
# 22002                          0.173206                       3.248865
# 22003                          0.524098                       2.908468
# 22004                          1.267791                       3.034877
# 22005                          1.151104                       3.532942
#
#             moyenne_conso_totale_hab  emissions_ges  nb_actes_france_renov  \
# code_insee
# 22001                       7.378017          14871                     88
# 22002                       4.775226           8621                     38
# 22003                       3.472740           3028                     49
# 22004                       5.203150          29130                     46
# 22005                       4.926877           4136                     10
#
#             friche ecoquartiers  part_residences_secondaires  ...  \
# code_insee                                                    ...
# 22001            2            0                         12.0  ...
# 22002            0            0                          2.0  ...
# 22003            0            0                          3.4  ...
# 22004            6            0                          5.5  ...
# 22005            3            0                         16.8  ...
#
#            dependance_eco abstention_municipales  taux_creation_ent  \
# code_insee
# 22001                 107                   17.4               15.0
# 22002                  96                   53.8               12.1
# 22003                 113                   53.7               36.7
# 22004                 126                   44.8               12.6
# 22005                 140                   22.9               18.8
#
#            total_entreprises part_licencies_sportifs  \
# code_insee
# 22001                     20               23.825503
# 22002                     33               30.836237
# 22003                     30               35.760870
# 22004                    238               24.282744
# 22005                     64               27.891156
#
#             part_jeunes_sans_diplome  climat_Autre  climat_Estuaire  \
# code_insee
# 22001                            9.1          True            False
# 22002                            4.0          True            False
# 22003                            0.0          True            False
# 22004                           12.4          True            False
# 22005                            2.6          True            False
#
#             climat_Mer beneficiaire_trans_eco
# code_insee
# 22001            False                      0
# 22002            False                      0
# 22003            False                      0
# 22004            False                      0
# 22005            False                      0
#
# [5 rows x 33 columns]

# %%
# !pip install pycaret scikit-learn==0.23.2
# Out:
# Requirement already satisfied: pycaret in c:\users\asus\anaconda3\lib\site-packages (3.3.2)
# Collecting scikit-learn==0.23.2
#   Using cached scikit-learn-0.23.2.tar.gz (7.2 MB)
#   Installing build dependencies: started
#   Installing build dependencies: still running...
#   Installing build dependencies: still running...
#   Installing build dependencies: finished with status 'error'
#   error: subprocess-exited-with-error
#
#   × pip subprocess to install build dependencies did not run successfully.
#   │ exit code: 1
#   ╰─> [126 lines of output]
#       Ignoring numpy: markers 'python_version == "3.6" and platform_system != "AIX" and platform_python_implementation == "CPython"' don't match your environment
#       Ignoring numpy: markers 'python_version == "3.6" and platform_system != "AIX" and platform_python_implementation != "CPython"' don't match your environment
#       Ignoring numpy: markers 'python_version == "3.7" and platform_system != "AIX"' don't match your environment
#       Ignoring numpy: markers 'python_version == "3.6" and platform_system == "AIX"' don't match your environment
#       Ignoring numpy: markers 'python_version == "3.7" and platform_system == "AIX"' don't match your environment
#       Ignoring numpy: markers 'python_version >= "3.8" and platform_system == "AIX"' don't match your environment
#       Collecting setuptools
#         Obtaining dependency information for setuptools from https://files.pythonhosted.org/packages/6e/ec/06715d912351edc453e37f93f3fc80dcffd5ca0e70386c87529aca296f05/setuptools-72.2.0-py3-none-any.whl.metadata
#         Downloading setuptools-72.2.0-py3-none-any.whl.metadata (6.6 kB)
#       Collecting wheel
#         Obtaining dependency information for wheel from https://files.pythonhosted.org/packages/1b/d1/9babe2ccaecff775992753d8686970b1e2755d21c8a63be73aba7a4e7d77/wheel-0.44.0-py3-none-any.whl.metadata
#         Downloading wheel-0.44.0-py3-none-any.whl.metadata (2.3 kB)
#       Collecting Cython>=0.28.5
#         Obtaining dependency information for Cython>=0.28.5 from https://files.pythonhosted.org/packages/fd/10/236fcc0306f85a2db1b8bc147aea714b66a2f27bac4d9e09e5b2c5d5dcca/Cython-3.0.11-cp311-cp311-win_amd64.whl.metadata
#         Downloading Cython-3.0.11-cp311-cp311-win_amd64.whl.metadata (3.2 kB)
#       Collecting numpy==1.17.3
#         Using cached numpy-1.17.3.zip (6.4 MB)
#         Preparing metadata (setup.py): started
#         Preparing metadata (setup.py): finished with status 'done'
#       Collecting scipy>=0.19.1
#         Obtaining dependency information for scipy>=0.19.1 from https://files.pythonhosted.org/packages/91/1d/0484130df7e33e044da88a091827d6441b77f907075bf7bbe145857d6590/scipy-1.14.0-cp311-cp311-win_amd64.whl.metadata
#         Downloading scipy-1.14.0-cp311-cp311-win_amd64.whl.metadata (60 kB)
#            ---------------------------------------- 0.0/60.8 kB ? eta -:--:--
#            ------------ ------------------------- 20.5/60.8 kB 217.9 kB/s eta 0:00:01
#            ------------------------- ------------ 41.0/60.8 kB 326.8 kB/s eta 0:00:01
#            -------------------------------------- 60.8/60.8 kB 404.2 kB/s eta 0:00:00
#       INFO: pip is looking at multiple versions of scipy to determine which version is compatible with other requirements. This could take a while.
#         Obtaining dependency information for scipy>=0.19.1 from https://files.pythonhosted.org/packages/4a/48/4513a1a5623a23e95f94abd675ed91cfb19989c58e9f6f7d03990f6caf3d/scipy-1.13.1-cp311-cp311-win_amd64.whl.metadata
#         Using cached scipy-1.13.1-cp311-cp311-win_amd64.whl.metadata (60 kB)
#         Obtaining dependency information for scipy>=0.19.1 from https://files.pythonhosted.org/packages/d4/a1/d4adf25b6d2bef8d0ad1682829dcfcba97f3f96bb5b6f137bc3e41003cc7/scipy-1.13.0-cp311-cp311-win_amd64.whl.metadata
#         Using cached scipy-1.13.0-cp311-cp311-win_amd64.whl.metadata (60 kB)
#         Obtaining dependency information for scipy>=0.19.1 from https://files.pythonhosted.org/packages/9a/25/5b30cb3efc9566f0ebeaeca1976150316353c17031ad7868ef46de5ab8dc/scipy-1.12.0-cp311-cp311-win_amd64.whl.metadata
#         Using cached scipy-1.12.0-cp311-cp311-win_amd64.whl.metadata (60 kB)
#         Obtaining dependency information for scipy>=0.19.1 from https://files.pythonhosted.org/packages/43/d0/f3cd75b62e1b90f48dbf091261b2fc7ceec14a700e308c50f6a69c83d337/scipy-1.11.4-cp311-cp311-win_amd64.whl.metadata
#         Using cached scipy-1.11.4-cp311-cp311-win_amd64.whl.metadata (60 kB)
#         Obtaining dependency information for scipy>=0.19.1 from https://files.pythonhosted.org/packages/81/d7/d2537d51efb692d0c411e64267ba349e7668d40f5bc73cefe78ccd650dcd/scipy-1.11.3-cp311-cp311-win_amd64.whl.metadata
#         Using cached scipy-1.11.3-cp311-cp311-win_amd64.whl.metadata (60 kB)
#         Obtaining dependency information for scipy>=0.19.1 from https://files.pythonhosted.org/packages/06/15/e73734f9170b66c6a84a0bd7e03586e87e77404e2eb8e34749fc49fa43f7/scipy-1.11.2-cp311-cp311-win_amd64.whl.metadata
#         Using cached scipy-1.11.2-cp311-cp311-win_amd64.whl.metadata (59 kB)
#         Obtaining dependency information for scipy>=0.19.1 from https://files.pythonhosted.org/packages/04/b8/947f40706ee2e316fd1a191688f690c4c2b351c2d043fe9deb9b7940e36e/scipy-1.11.1-cp311-cp311-win_amd64.whl.metadata
#         Using cached scipy-1.11.1-cp311-cp311-win_amd64.whl.metadata (59 kB)
#       INFO: pip is still looking at multiple versions of scipy to determine which version is compatible with other requirements. This could take a while.
#         Obtaining dependency information for scipy>=0.19.1 from https://files.pythonhosted.org/packages/65/76/903324159e4a3566e518c558aeb21571d642f781d842d8dd0fd9c6b0645a/scipy-1.10.1-cp311-cp311-win_amd64.whl.metadata
#         Using cached scipy-1.10.1-cp311-cp311-win_amd64.whl.metadata (58 kB)
#         Obtaining dependency information for scipy>=0.19.1 from https://files.pythonhosted.org/packages/c3/c4/8efe05b8ee86c7276448ef54f71ddb194416b881bc7a0d3c353279eea6aa/scipy-1.10.0-cp311-cp311-win_amd64.whl.metadata
#         Using cached scipy-1.10.0-cp311-cp311-win_amd64.whl.metadata (58 kB)
#         Obtaining dependency information for scipy>=0.19.1 from https://files.pythonhosted.org/packages/42/81/0a64d2204c3b261380ac96c6d61f018528108b62c0e21e6153a58cebf4f6/scipy-1.9.3-cp311-cp311-win_amd64.whl.metadata
#         Using cached scipy-1.9.3-cp311-cp311-win_amd64.whl.metadata (58 kB)
#         Obtaining dependency information for scipy>=0.19.1 from https://files.pythonhosted.org/packages/3c/86/1fa36885e5e69bba07e284429a2b4eed020426792b5ea9edcd0feeee73d7/scipy-1.9.2-cp311-cp311-win_amd64.whl.metadata
#         Using cached scipy-1.9.2-cp311-cp311-win_amd64.whl.metadata (58 kB)
#         Using cached scipy-1.9.1.tar.gz (42.0 MB)
#         Installing build dependencies: started
#         Installing build dependencies: still running...
#         Installing build dependencies: finished with status 'done'
#         Getting requirements to build wheel: started
#         Getting requirements to build wheel: finished with status 'error'
#         error: subprocess-exited-with-error
#
#         × Getting requirements to build wheel did not run successfully.
#         │ exit code: 1
#         ╰─> [55 lines of output]
#             + meson setup --native-file=C:\Users\ASUS\AppData\Local\Temp\pip-install-cof21ph1\scipy_3655f70d844e40e49dfb98736fbaf1e3\.mesonpy-native-file.ini -Ddebug=false -Doptimization=2 --prefix=C:\Users\ASUS\anaconda3 C:\Users\ASUS\AppData\Local\Temp\pip-install-cof21ph1\scipy_3655f70d844e40e49dfb98736fbaf1e3 C:\Users\ASUS\AppData\Local\Temp\pip-install-cof21ph1\scipy_3655f70d844e40e49dfb98736fbaf1e3\.mesonpy-43pgm_u9\build
#             The Meson build system
#             Version: 0.62.2
#             Source dir: C:\Users\ASUS\AppData\Local\Temp\pip-install-cof21ph1\scipy_3655f70d844e40e49dfb98736fbaf1e3
#             Build dir: C:\Users\ASUS\AppData\Local\Temp\pip-install-cof21ph1\scipy_3655f70d844e40e49dfb98736fbaf1e3\.mesonpy-43pgm_u9\build
#             Build type: native build
#             Project name: SciPy
#             Project version: 1.9.1
#             WARNING: Failed to activate VS environment: Could not find C:\Program Files (x86)\Microsoft Visual Studio\Installer\vswhere.exe
#
#             ..\..\meson.build:1:0: ERROR: Unknown compiler(s): [['icl'], ['cl'], ['cc'], ['gcc'], ['clang'], ['clang-cl'], ['pgcc']]
#             The following exception(s) were encountered:
#             Running "icl " gave "[WinError 2] Le fichier spécifié est introuvable"
#             Running "cl /?" gave "[WinError 2] Le fichier spécifié est introuvable"
#             Running "cc --version" gave "[WinError 2] Le fichier spécifié est introuvable"
#             Running "gcc --version" gave "[WinError 2] Le fichier spécifié est introuvable"
#             Running "clang --version" gave "[WinError 2] Le fichier spécifié est introuvable"
#             Running "clang-cl /?" gave "[WinError 2] Le fichier spécifié est introuvable"
#             Running "pgcc --version" gave "[WinError 2] Le fichier spécifié est introuvable"
#
#             A full log can be found at C:\Users\ASUS\AppData\Local\Temp\pip-install-cof21ph1\scipy_3655f70d844e40e49dfb98736fbaf1e3\.mesonpy-43pgm_u9\build\meson-logs\meson-log.txt
#             Traceback (most recent call last):
#               File "C:\Users\ASUS\anaconda3\Lib\site-packages\pip\_vendor\pyproject_hooks\_in_process\_in_process.py", line 353, in <module>
#                 main()
#               File "C:\Users\ASUS\anaconda3\Lib\site-packages\pip\_vendor\pyproject_hooks\_in_process\_in_process.py", line 335, in main
#                 json_out['return_val'] = hook(**hook_input['kwargs'])
#                                          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#               File "C:\Users\ASUS\anaconda3\Lib\site-packages\pip\_vendor\pyproject_hooks\_in_process\_in_process.py", line 118, in get_requires_for_build_wheel
#                 return hook(config_settings)
#                        ^^^^^^^^^^^^^^^^^^^^^
#               File "C:\Users\ASUS\AppData\Local\Temp\pip-build-env-qsg_iz3i\overlay\Lib\site-packages\mesonpy\__init__.py", line 969, in get_requires_for_build_wheel
#                 with _project(config_settings) as project:
#               File "C:\Users\ASUS\anaconda3\Lib\contextlib.py", line 137, in __enter__
#                 return next(self.gen)
#                        ^^^^^^^^^^^^^^
#               File "C:\Users\ASUS\AppData\Local\Temp\pip-build-env-qsg_iz3i\overlay\Lib\site-packages\mesonpy\__init__.py", line 948, in _project
#                 with Project.with_temp_working_dir(
#               File "C:\Users\ASUS\anaconda3\Lib\contextlib.py", line 137, in __enter__
#                 return next(self.gen)
#                        ^^^^^^^^^^^^^^
#               File "C:\Users\ASUS\AppData\Local\Temp\pip-build-env-qsg_iz3i\overlay\Lib\site-packages\mesonpy\__init__.py", line 777, in with_temp_working_dir
#                 yield cls(source_dir, tmpdir, build_dir)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#               File "C:\Users\ASUS\AppData\Local\Temp\pip-build-env-qsg_iz3i\overlay\Lib\site-packages\mesonpy\__init__.py", line 682, in __init__
#                 self._configure(reconfigure=bool(build_dir) and not native_file_mismatch)
#               File "C:\Users\ASUS\AppData\Local\Temp\pip-build-env-qsg_iz3i\overlay\Lib\site-packages\mesonpy\__init__.py", line 713, in _configure
#                 self._meson(
#               File "C:\Users\ASUS\AppData\Local\Temp\pip-build-env-qsg_iz3i\overlay\Lib\site-packages\mesonpy\__init__.py", line 696, in _meson
#                 return self._proc('meson', *args)
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^
#               File "C:\Users\ASUS\AppData\Local\Temp\pip-build-env-qsg_iz3i\overlay\Lib\site-packages\mesonpy\__init__.py", line 691, in _proc
#                 subprocess.check_call(list(args))
#               File "C:\Users\ASUS\anaconda3\Lib\subprocess.py", line 413, in check_call
#                 raise CalledProcessError(retcode, cmd)
#             subprocess.CalledProcessError: Command '['meson', 'setup', '--native-file=C:\\Users\\ASUS\\AppData\\Local\\Temp\\pip-install-cof21ph1\\scipy_3655f70d844e40e49dfb98736fbaf1e3\\.mesonpy-native-file.ini', '-Ddebug=false', '-Doptimization=2', '--prefix=C:\\Users\\ASUS\\anaconda3', 'C:\\Users\\ASUS\\AppData\\Local\\Temp\\pip-install-cof21ph1\\scipy_3655f70d844e40e49dfb98736fbaf1e3', 'C:\\Users\\ASUS\\AppData\\Local\\Temp\\pip-install-cof21ph1\\scipy_3655f70d844e40e49dfb98736fbaf1e3\\.mesonpy-43pgm_u9\\build']' returned non-zero exit status 1.
#             [end of output]
#
#         note: This error originates from a subprocess, and is likely not a problem with pip.
#       error: subprocess-exited-with-error
#
#       × Getting requirements to build wheel did not run successfully.
#       │ exit code: 1
#       ╰─> See above for output.
#
#       note: This error originates from a subprocess, and is likely not a problem with pip.
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: subprocess-exited-with-error
#
# × pip subprocess to install build dependencies did not run successfully.
# │ exit code: 1
# ╰─> See above for output.
#
# note: This error originates from a subprocess, and is likely not a problem with pip.

# %%
from pycaret.classification import *
import mlflow

# Conversion des variables catégorielles en string
for col in donnees.select_dtypes(['category']).columns:
    donnees[col] = donnees[col].astype(str)


# Initialisation de l'environnement PyCaret
clf = setup(data = donnees, 
            target = "beneficiaire_trans_eco", 
            session_id=123,   
            fix_imbalance=True, 
            fix_imbalance_method='smote') # fix_imbalance_method='smote' pour la sur-échantillonnage des données
# Out:
# <style type="text/css">
# #T_38a9d_row10_col1, #T_38a9d_row16_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_38a9d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_38a9d_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_38a9d_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_38a9d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_38a9d_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_38a9d_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_38a9d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_38a9d_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_38a9d_row1_col1" class="data row1 col1" >beneficiaire_trans_eco</td>
#     </tr>
#     <tr>
#       <th id="T_38a9d_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_38a9d_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_38a9d_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_38a9d_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_38a9d_row3_col0" class="data row3 col0" >Target mapping</td>
#       <td id="T_38a9d_row3_col1" class="data row3 col1" >0: 0, 1: 1</td>
#     </tr>
#     <tr>
#       <th id="T_38a9d_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_38a9d_row4_col0" class="data row4 col0" >Original data shape</td>
#       <td id="T_38a9d_row4_col1" class="data row4 col1" >(1207, 33)</td>
#     </tr>
#     <tr>
#       <th id="T_38a9d_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_38a9d_row5_col0" class="data row5 col0" >Transformed data shape</td>
#       <td id="T_38a9d_row5_col1" class="data row5 col1" >(1767, 42)</td>
#     </tr>
#     <tr>
#       <th id="T_38a9d_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_38a9d_row6_col0" class="data row6 col0" >Transformed train set shape</td>
#       <td id="T_38a9d_row6_col1" class="data row6 col1" >(1404, 42)</td>
#     </tr>
#     <tr>
#       <th id="T_38a9d_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_38a9d_row7_col0" class="data row7 col0" >Transformed test set shape</td>
#       <td id="T_38a9d_row7_col1" class="data row7 col1" >(363, 42)</td>
#     </tr>
#     <tr>
#       <th id="T_38a9d_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_38a9d_row8_col0" class="data row8 col0" >Numeric features</td>
#       <td id="T_38a9d_row8_col1" class="data row8 col1" >23</td>
#     </tr>
#     <tr>
#       <th id="T_38a9d_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_38a9d_row9_col0" class="data row9 col0" >Categorical features</td>
#       <td id="T_38a9d_row9_col1" class="data row9 col1" >6</td>
#     </tr>
#     <tr>
#       <th id="T_38a9d_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_38a9d_row10_col0" class="data row10 col0" >Preprocess</td>
#       <td id="T_38a9d_row10_col1" class="data row10 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_38a9d_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_38a9d_row11_col0" class="data row11 col0" >Imputation type</td>
#       <td id="T_38a9d_row11_col1" class="data row11 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_38a9d_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_38a9d_row12_col0" class="data row12 col0" >Numeric imputation</td>
#       <td id="T_38a9d_row12_col1" class="data row12 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_38a9d_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_38a9d_row13_col0" class="data row13 col0" >Categorical imputation</td>
#       <td id="T_38a9d_row13_col1" class="data row13 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_38a9d_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_38a9d_row14_col0" class="data row14 col0" >Maximum one-hot encoding</td>
#       <td id="T_38a9d_row14_col1" class="data row14 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_38a9d_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_38a9d_row15_col0" class="data row15 col0" >Encoding method</td>
#       <td id="T_38a9d_row15_col1" class="data row15 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_38a9d_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_38a9d_row16_col0" class="data row16 col0" >Fix imbalance</td>
#       <td id="T_38a9d_row16_col1" class="data row16 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_38a9d_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_38a9d_row17_col0" class="data row17 col0" >Fix imbalance method</td>
#       <td id="T_38a9d_row17_col1" class="data row17 col1" >smote</td>
#     </tr>
#     <tr>
#       <th id="T_38a9d_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_38a9d_row18_col0" class="data row18 col0" >Fold Generator</td>
#       <td id="T_38a9d_row18_col1" class="data row18 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_38a9d_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_38a9d_row19_col0" class="data row19 col0" >Fold Number</td>
#       <td id="T_38a9d_row19_col1" class="data row19 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_38a9d_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_38a9d_row20_col0" class="data row20 col0" >CPU Jobs</td>
#       <td id="T_38a9d_row20_col1" class="data row20 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_38a9d_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_38a9d_row21_col0" class="data row21 col0" >Use GPU</td>
#       <td id="T_38a9d_row21_col1" class="data row21 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_38a9d_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_38a9d_row22_col0" class="data row22 col0" >Log Experiment</td>
#       <td id="T_38a9d_row22_col1" class="data row22 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_38a9d_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_38a9d_row23_col0" class="data row23 col0" >Experiment Name</td>
#       <td id="T_38a9d_row23_col1" class="data row23 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_38a9d_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_38a9d_row24_col0" class="data row24 col0" >USI</td>
#       <td id="T_38a9d_row24_col1" class="data row24 col1" >af75</td>
#     </tr>
#   </tbody>
# </table>

# %%
best_model = compare_models()# Comparaison des modèles
# Out:
# <style type="text/css">
# #T_f5afd th {
#   text-align: left;
# }
# #T_f5afd_row0_col0, #T_f5afd_row0_col2, #T_f5afd_row0_col4, #T_f5afd_row0_col5, #T_f5afd_row0_col6, #T_f5afd_row0_col7, #T_f5afd_row1_col0, #T_f5afd_row1_col1, #T_f5afd_row1_col2, #T_f5afd_row1_col3, #T_f5afd_row1_col4, #T_f5afd_row1_col5, #T_f5afd_row1_col6, #T_f5afd_row1_col7, #T_f5afd_row2_col0, #T_f5afd_row2_col1, #T_f5afd_row2_col2, #T_f5afd_row2_col3, #T_f5afd_row2_col4, #T_f5afd_row2_col5, #T_f5afd_row2_col6, #T_f5afd_row2_col7, #T_f5afd_row3_col0, #T_f5afd_row3_col1, #T_f5afd_row3_col3, #T_f5afd_row3_col4, #T_f5afd_row3_col5, #T_f5afd_row3_col6, #T_f5afd_row3_col7, #T_f5afd_row4_col0, #T_f5afd_row4_col1, #T_f5afd_row4_col2, #T_f5afd_row4_col3, #T_f5afd_row4_col4, #T_f5afd_row4_col6, #T_f5afd_row4_col7, #T_f5afd_row5_col0, #T_f5afd_row5_col1, #T_f5afd_row5_col2, #T_f5afd_row5_col3, #T_f5afd_row5_col4, #T_f5afd_row5_col5, #T_f5afd_row5_col6, #T_f5afd_row5_col7, #T_f5afd_row6_col0, #T_f5afd_row6_col1, #T_f5afd_row6_col2, #T_f5afd_row6_col3, #T_f5afd_row6_col4, #T_f5afd_row6_col5, #T_f5afd_row6_col6, #T_f5afd_row6_col7, #T_f5afd_row7_col0, #T_f5afd_row7_col1, #T_f5afd_row7_col2, #T_f5afd_row7_col3, #T_f5afd_row7_col4, #T_f5afd_row7_col5, #T_f5afd_row7_col6, #T_f5afd_row7_col7, #T_f5afd_row8_col0, #T_f5afd_row8_col1, #T_f5afd_row8_col2, #T_f5afd_row8_col3, #T_f5afd_row8_col4, #T_f5afd_row8_col5, #T_f5afd_row8_col6, #T_f5afd_row8_col7, #T_f5afd_row9_col0, #T_f5afd_row9_col1, #T_f5afd_row9_col2, #T_f5afd_row9_col3, #T_f5afd_row9_col4, #T_f5afd_row9_col5, #T_f5afd_row9_col6, #T_f5afd_row9_col7, #T_f5afd_row10_col0, #T_f5afd_row10_col1, #T_f5afd_row10_col2, #T_f5afd_row10_col3, #T_f5afd_row10_col5, #T_f5afd_row11_col0, #T_f5afd_row11_col1, #T_f5afd_row11_col2, #T_f5afd_row11_col3, #T_f5afd_row11_col4, #T_f5afd_row11_col5, #T_f5afd_row11_col6, #T_f5afd_row11_col7, #T_f5afd_row12_col0, #T_f5afd_row12_col1, #T_f5afd_row12_col2, #T_f5afd_row12_col3, #T_f5afd_row12_col4, #T_f5afd_row12_col5, #T_f5afd_row12_col6, #T_f5afd_row12_col7, #T_f5afd_row13_col0, #T_f5afd_row13_col1, #T_f5afd_row13_col2, #T_f5afd_row13_col3, #T_f5afd_row13_col4, #T_f5afd_row13_col5, #T_f5afd_row13_col6, #T_f5afd_row13_col7 {
#   text-align: left;
# }
# #T_f5afd_row0_col1, #T_f5afd_row0_col3, #T_f5afd_row3_col2, #T_f5afd_row4_col5, #T_f5afd_row10_col4, #T_f5afd_row10_col6, #T_f5afd_row10_col7 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_f5afd_row0_col8, #T_f5afd_row1_col8, #T_f5afd_row2_col8, #T_f5afd_row3_col8, #T_f5afd_row4_col8, #T_f5afd_row5_col8, #T_f5afd_row6_col8, #T_f5afd_row7_col8, #T_f5afd_row8_col8, #T_f5afd_row9_col8, #T_f5afd_row10_col8, #T_f5afd_row11_col8, #T_f5afd_row12_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_f5afd_row13_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_f5afd">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f5afd_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_f5afd_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_f5afd_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_f5afd_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_f5afd_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_f5afd_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_f5afd_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_f5afd_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_f5afd_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f5afd_level0_row0" class="row_heading level0 row0" >dummy</th>
#       <td id="T_f5afd_row0_col0" class="data row0 col0" >Dummy Classifier</td>
#       <td id="T_f5afd_row0_col1" class="data row0 col1" >0.8318</td>
#       <td id="T_f5afd_row0_col2" class="data row0 col2" >0.5000</td>
#       <td id="T_f5afd_row0_col3" class="data row0 col3" >0.8318</td>
#       <td id="T_f5afd_row0_col4" class="data row0 col4" >0.6919</td>
#       <td id="T_f5afd_row0_col5" class="data row0 col5" >0.7554</td>
#       <td id="T_f5afd_row0_col6" class="data row0 col6" >0.0000</td>
#       <td id="T_f5afd_row0_col7" class="data row0 col7" >0.0000</td>
#       <td id="T_f5afd_row0_col8" class="data row0 col8" >2.7090</td>
#     </tr>
#     <tr>
#       <th id="T_f5afd_level0_row1" class="row_heading level0 row1" >et</th>
#       <td id="T_f5afd_row1_col0" class="data row1 col0" >Extra Trees Classifier</td>
#       <td id="T_f5afd_row1_col1" class="data row1 col1" >0.8081</td>
#       <td id="T_f5afd_row1_col2" class="data row1 col2" >0.6588</td>
#       <td id="T_f5afd_row1_col3" class="data row1 col3" >0.8081</td>
#       <td id="T_f5afd_row1_col4" class="data row1 col4" >0.7385</td>
#       <td id="T_f5afd_row1_col5" class="data row1 col5" >0.7646</td>
#       <td id="T_f5afd_row1_col6" class="data row1 col6" >0.0633</td>
#       <td id="T_f5afd_row1_col7" class="data row1 col7" >0.0661</td>
#       <td id="T_f5afd_row1_col8" class="data row1 col8" >0.4760</td>
#     </tr>
#     <tr>
#       <th id="T_f5afd_level0_row2" class="row_heading level0 row2" >qda</th>
#       <td id="T_f5afd_row2_col0" class="data row2 col0" >Quadratic Discriminant Analysis</td>
#       <td id="T_f5afd_row2_col1" class="data row2 col1" >0.8046</td>
#       <td id="T_f5afd_row2_col2" class="data row2 col2" >0.5439</td>
#       <td id="T_f5afd_row2_col3" class="data row2 col3" >0.8046</td>
#       <td id="T_f5afd_row2_col4" class="data row2 col4" >0.7103</td>
#       <td id="T_f5afd_row2_col5" class="data row2 col5" >0.7458</td>
#       <td id="T_f5afd_row2_col6" class="data row2 col6" >0.0146</td>
#       <td id="T_f5afd_row2_col7" class="data row2 col7" >0.0161</td>
#       <td id="T_f5afd_row2_col8" class="data row2 col8" >0.2530</td>
#     </tr>
#     <tr>
#       <th id="T_f5afd_level0_row3" class="row_heading level0 row3" >rf</th>
#       <td id="T_f5afd_row3_col0" class="data row3 col0" >Random Forest Classifier</td>
#       <td id="T_f5afd_row3_col1" class="data row3 col1" >0.7914</td>
#       <td id="T_f5afd_row3_col2" class="data row3 col2" >0.6817</td>
#       <td id="T_f5afd_row3_col3" class="data row3 col3" >0.7914</td>
#       <td id="T_f5afd_row3_col4" class="data row3 col4" >0.7433</td>
#       <td id="T_f5afd_row3_col5" class="data row3 col5" >0.7615</td>
#       <td id="T_f5afd_row3_col6" class="data row3 col6" >0.0719</td>
#       <td id="T_f5afd_row3_col7" class="data row3 col7" >0.0773</td>
#       <td id="T_f5afd_row3_col8" class="data row3 col8" >0.8590</td>
#     </tr>
#     <tr>
#       <th id="T_f5afd_level0_row4" class="row_heading level0 row4" >gbc</th>
#       <td id="T_f5afd_row4_col0" class="data row4 col0" >Gradient Boosting Classifier</td>
#       <td id="T_f5afd_row4_col1" class="data row4 col1" >0.7856</td>
#       <td id="T_f5afd_row4_col2" class="data row4 col2" >0.6464</td>
#       <td id="T_f5afd_row4_col3" class="data row4 col3" >0.7856</td>
#       <td id="T_f5afd_row4_col4" class="data row4 col4" >0.7555</td>
#       <td id="T_f5afd_row4_col5" class="data row4 col5" >0.7667</td>
#       <td id="T_f5afd_row4_col6" class="data row4 col6" >0.1153</td>
#       <td id="T_f5afd_row4_col7" class="data row4 col7" >0.1207</td>
#       <td id="T_f5afd_row4_col8" class="data row4 col8" >1.3180</td>
#     </tr>
#     <tr>
#       <th id="T_f5afd_level0_row5" class="row_heading level0 row5" >lightgbm</th>
#       <td id="T_f5afd_row5_col0" class="data row5 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_f5afd_row5_col1" class="data row5 col1" >0.7844</td>
#       <td id="T_f5afd_row5_col2" class="data row5 col2" >0.6386</td>
#       <td id="T_f5afd_row5_col3" class="data row5 col3" >0.7844</td>
#       <td id="T_f5afd_row5_col4" class="data row5 col4" >0.7411</td>
#       <td id="T_f5afd_row5_col5" class="data row5 col5" >0.7521</td>
#       <td id="T_f5afd_row5_col6" class="data row5 col6" >0.0364</td>
#       <td id="T_f5afd_row5_col7" class="data row5 col7" >0.0494<

# %% [markdown]
# ### B) Création du modèle

# %%
# Création du modèle afin de prédire une probabilité de succès

model_rf = create_model('rf') # Création du modèle RandomForest
# Out:
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                  18:19:02
# Status     . . . . . . . . . . . . . . . . . .          Fitting 10 Folds
# Estimator  . . . . . . . . . . . . . . . . . .  Random Forest Classifier
# <style type="text/css">
# #T_197b9_row10_col0, #T_197b9_row10_col1, #T_197b9_row10_col2, #T_197b9_row10_col3, #T_197b9_row10_col4, #T_197b9_row10_col5, #T_197b9_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_197b9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_197b9_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_197b9_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_197b9_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_197b9_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_197b9_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_197b9_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_197b9_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_197b9_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_197b9_row0_col0" class="data row0 col0" >0.8235</td>
#       <td id="T_197b9_row0_col1" class="data row0 col1" >0.7309</td>
#       <td id="T_197b9_row0_col2" class="data row0 col2" >0.8235</td>
#       <td id="T_197b9_row0_col3" class="data row0 col3" >0.7986</td>
#       <td id="T_197b9_row0_col4" class="data row0 col4" >0.8073</td>
#       <td id="T_197b9_row0_col5" class="data row0 col5" >0.2513</td>
#       <td id="T_197b9_row0_col6" class="data row0 col6" >0.2595</td>
#     </tr>
#     <tr>
#       <th id="T_197b9_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_197b9_row1_col0" class="data row1 col0" >0.8235</td>
#       <td id="T_197b9_row1_col1" class="data row1 col1" >0.7686</td>
#       <td id="T_197b9_row1_col2" class="data row1 col2" >0.8235</td>
#       <td id="T_197b9_row1_col3" class="data row1 col3" >0.7759</td>
#       <td id="T_197b9_row1_col4" class="data row1 col4" >0.7870</td>
#       <td id="T_197b9_row1_col5" class="data row1 col5" >0.1356</td>
#       <td id="T_197b9_row1_col6" class="data row1 col6" >0.1586</td>
#     </tr>
#     <tr>
#       <th id="T_197b9_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_197b9_row2_col0" class="data row2 col0" >0.7882</td>
#       <td id="T_197b9_row2_col1" class="data row2 col1" >0.6495</td>
#       <td id="T_197b9_row2_col2" class="data row2 col2" >0.7882</td>
#       <td id="T_197b9_row2_col3" class="data row2 col3" >0.7367</td>
#       <td id="T_197b9_row2_col4" class="data row2 col4" >0.7555</td>
#       <td id="T_197b9_row2_col5" class="data row2 col5" >0.0783</td>
#       <td id="T_197b9_row2_col6" class="data row2 col6" >0.0858</td>
#     </tr>
#     <tr>
#       <th id="T_197b9_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_197b9_row3_col0" class="data row3 col0" >0.7529</td>
#       <td id="T_197b9_row3_col1" class="data row3 col1" >0.5200</td>
#       <td id="T_197b9_row3_col2" class="data row3 col2" >0.7529</td>
#       <td id="T_197b9_row3_col3" class="data row3 col3" >0.6959</td>
#       <td id="T_197b9_row3_col4" class="data row3 col4" >0.7212</td>
#       <td id="T_197b9_row3_col5" class="data row3 col5" >-0.0408</td>
#       <td id="T_197b9_row3_col6" class="data row3 col6" >-0.0435</td>
#     </tr>
#     <tr>
#       <th id="T_197b9_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_197b9_row4_col0" class="data row4 col0" >0.8095</td>
#       <td id="T_197b9_row4_col1" class="data row4 col1" >0.7454</td>
#       <td id="T_197b9_row4_col2" class="data row4 col2" >0.8095</td>
#       <td id="T_197b9_row4_col3" class="data row4 col3" >0.7607</td>
#       <td id="T_197b9_row4_col4" class="data row4 col4" >0.7766</td>
#       <td id="T_197b9_row4_col5" class="data row4 col5" >0.1111</td>
#       <td id="T_197b9_row4_col6" class="data row4 col6" >0.1240</td>
#     </tr>
#     <tr>
#       <th id="T_197b9_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_197b9_row5_col0" class="data row5 col0" >0.7738</td>
#       <td id="T_197b9_row5_col1" class="data row5 col1" >0.6561</td>
#       <td id="T_197b9_row5_col2" class="data row5 col2" >0.7738</td>
#       <td id="T_197b9_row5_col3" class="data row5 col3" >0.6857</td>
#       <td id="T_197b9_row5_col4" class="data row5 col4" >0.7271</td>
#       <td id="T_197b9_row5_col5" class="data row5 col5" >-0.0962</td>
#       <td id="T_197b9_row5_col6" class="data row5 col6" >-0.1125</td>
#     </tr>
#     <tr>
#       <th id="T_197b9_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_197b9_row6_col0" class="data row6 col0" >0.7976</td>
#       <td id="T_197b9_row6_col1" class="data row6 col1" >0.6291</td>
#       <td id="T_197b9_row6_col2" class="data row6 col2" >0.7976</td>
#       <td id="T_197b9_row6_col3" class="data row6 col3" >0.7667</td>
#       <td id="T_197b9_row6_col4" class="data row6 col4" >0.7791</td>
#       <td id="T_197b9_row6_col5" class="data row6 col5" >0.1500</td>
#       <td id="T_197b9_row6_col6" class="data row6 col6" >0.1549</td>
#     </tr>
#     <tr>
#       <th id="T_197b9_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_197b9_row7_col0" class="data row7 col0" >0.7381</td>
#       <td id="T_197b9_row7_col1" class="data row7 col1" >0.6765</td>
#       <td id="T_197b9_row7_col2" class="data row7 col2" >0.7381</td>
#       <td id="T_197b9_row7_col3" class="data row7 col3" >0.7222</td>
#       <td id="T_197b9_row7_col4" class="data row7 col4" >0.7299</td>
#       <td id="T_197b9_row7_col5" class="data row7 col5" >0.0000</td>
#       <td id="T_197b9_row7_col6" class="data row7 col6" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_197b9_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_197b9_row8_col0" class="data row8 col0" >0.8095</td>
#       <td id="T_197b9_row8_col1" class="data row8 col1" >0.7571</td>
#       <td id="T_197b9_row8_col2" class="data row8 col2" >0.8095</td>
#       <td id="T_197b9_row8_col3" class="data row8 col3" >0.7396</td>
#       <td id="T_197b9_row8_col4" class="data row8 col4" >0.7630</td>
#       <td id="T_197b9_row8_col5" class="data row8 col5" >0.0400</td>
#       <td id="T_197b9_row8_col6" class="data row8 col6" >0.0500</td>
#     </tr>
#     <tr>
#       <th id="T_197b9_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_197b9_row9_col0" class="data row9 col0" >0.7976</td>
#       <td id="T_197b9_row9_col1" class="data row9 col1" >0.6837</td>
#       <td id="T_197b9_row9_col2" class="data row9 col2" >0.7976</td>
#       <td id="T_197b9_row9_col3" class="data row9 col3" >0.7511</td>
#       <td id="T_197b9_row9_col4" class="data row9 col4" >0.7687</td>
#       <td id="T_197b9_row9_col5" class="data row9 col5" >0.0893</td>
#       <td id="T_197b9_row9_col6" class="data row9 col6" >0.0963</td>
#     </tr>
#     <tr>
#       <th id="T_197b9_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_197b9_row10_col0" class="data row10 col0" >0.7914</td>
#       <td id="T_197b9_row10_col1" class="data row10 col1" >0.6817</td>
#       <td id="T_197b9_row10_col2" class="data row10 col2" >0.7914</td>
#       <td id="T_197b9_row10_col3" class="data row10 col3" >0.7433</td>
#       <td id="T_197b9_row10_col4" class="data row10 col4" >0.7615</td>
#       <td id="T_197b9_row10_col5" class="data row10 col5" >0.0719</td>
#       <td id="T_197b9_row10_col6" class="data row10 col6" >0.0773</td>
#     </tr>
#     <tr>
#       <th id="T_197b9_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_197b9_row11_col0" class="data row11 col0" >0.0273</td>
#       <td id="T_197b9_row11_col1" class="data row11 col1" >0.0710</td>
#       <td id="T_197b9_row11_col2" class="data row11 col2" >0.0273</td>
#       <td id="T_197b9_row11_col3" class="data row11 col3" >0.0333</td>
#       <td id="T_197b9_row11_

# %%
# Création modèle gradient boosting

model_gbc = create_model('gbc') # Création du modèle Gradient Boosting
# Out:
#
#
# Initiated  . . . . . . . . . . . . . . . . . .              18:19:30
# Status     . . . . . . . . . . . . . . . . . .  Loading Dependencies
# Estimator  . . . . . . . . . . . . . . . . . .     Compiling Library
# <style type="text/css">
# #T_7e5cb_row10_col0, #T_7e5cb_row10_col1, #T_7e5cb_row10_col2, #T_7e5cb_row10_col3, #T_7e5cb_row10_col4, #T_7e5cb_row10_col5, #T_7e5cb_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_7e5cb">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7e5cb_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_7e5cb_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_7e5cb_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_7e5cb_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_7e5cb_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_7e5cb_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_7e5cb_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7e5cb_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7e5cb_row0_col0" class="data row0 col0" >0.8471</td>
#       <td id="T_7e5cb_row0_col1" class="data row0 col1" >0.7797</td>
#       <td id="T_7e5cb_row0_col2" class="data row0 col2" >0.8471</td>
#       <td id="T_7e5cb_row0_col3" class="data row0 col3" >0.8348</td>
#       <td id="T_7e5cb_row0_col4" class="data row0 col4" >0.8395</td>
#       <td id="T_7e5cb_row0_col5" class="data row0 col5" >0.3919</td>
#       <td id="T_7e5cb_row0_col6" class="data row0 col6" >0.3958</td>
#     </tr>
#     <tr>
#       <th id="T_7e5cb_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_7e5cb_row1_col0" class="data row1 col0" >0.7765</td>
#       <td id="T_7e5cb_row1_col1" class="data row1 col1" >0.7414</td>
#       <td id="T_7e5cb_row1_col2" class="data row1 col2" >0.7765</td>
#       <td id="T_7e5cb_row1_col3" class="data row1 col3" >0.7400</td>
#       <td id="T_7e5cb_row1_col4" class="data row1 col4" >0.7560</td>
#       <td id="T_7e5cb_row1_col5" class="data row1 col5" >0.0517</td>
#       <td id="T_7e5cb_row1_col6" class="data row1 col6" >0.0534</td>
#     </tr>
#     <tr>
#       <th id="T_7e5cb_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_7e5cb_row2_col0" class="data row2 col0" >0.7765</td>
#       <td id="T_7e5cb_row2_col1" class="data row2 col1" >0.5781</td>
#       <td id="T_7e5cb_row2_col2" class="data row2 col2" >0.7765</td>
#       <td id="T_7e5cb_row2_col3" class="data row2 col3" >0.7583</td>
#       <td id="T_7e5cb_row2_col4" class="data row2 col4" >0.7664</td>
#       <td id="T_7e5cb_row2_col5" class="data row2 col5" >0.1654</td>
#       <td id="T_7e5cb_row2_col6" class="data row2 col6" >0.1668</td>
#     </tr>
#     <tr>
#       <th id="T_7e5cb_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_7e5cb_row3_col0" class="data row3 col0" >0.7176</td>
#       <td id="T_7e5cb_row3_col1" class="data row3 col1" >0.5543</td>
#       <td id="T_7e5cb_row3_col2" class="data row3 col2" >0.7176</td>
#       <td id="T_7e5cb_row3_col3" class="data row3 col3" >0.6838</td>
#       <td id="T_7e5cb_row3_col4" class="data row3 col4" >0.6998</td>
#       <td id="T_7e5cb_row3_col5" class="data row3 col5" >-0.0851</td>
#       <td id="T_7e5cb_row3_col6" class="data row3 col6" >-0.0865</td>
#     </tr>
#     <tr>
#       <th id="T_7e5cb_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_7e5cb_row4_col0" class="data row4 col0" >0.7857</td>
#       <td id="T_7e5cb_row4_col1" class="data row4 col1" >0.6071</td>
#       <td id="T_7e5cb_row4_col2" class="data row4 col2" >0.7857</td>
#       <td id="T_7e5cb_row4_col3" class="data row4 col3" >0.7595</td>
#       <td id="T_7e5cb_row4_col4" class="data row4 col4" >0.7708</td>
#       <td id="T_7e5cb_row4_col5" class="data row4 col5" >0.1290</td>
#       <td id="T_7e5cb_row4_col6" class="data row4 col6" >0.1315</td>
#     </tr>
#     <tr>
#       <th id="T_7e5cb_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_7e5cb_row5_col0" class="data row5 col0" >0.7976</td>
#       <td id="T_7e5cb_row5_col1" class="data row5 col1" >0.5949</td>
#       <td id="T_7e5cb_row5_col2" class="data row5 col2" >0.7976</td>
#       <td id="T_7e5cb_row5_col3" class="data row5 col3" >0.7295</td>
#       <td id="T_7e5cb_row5_col4" class="data row5 col4" >0.7558</td>
#       <td id="T_7e5cb_row5_col5" class="data row5 col5" >0.0192</td>
#       <td id="T_7e5cb_row5_col6" class="data row5 col6" >0.0225</td>
#     </tr>
#     <tr>
#       <th id="T_7e5cb_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_7e5cb_row6_col0" class="data row6 col0" >0.7738</td>
#       <td id="T_7e5cb_row6_col1" class="data row6 col1" >0.5102</td>
#       <td id="T_7e5cb_row6_col2" class="data row6 col2" >0.7738</td>
#       <td id="T_7e5cb_row6_col3" class="data row6 col3" >0.7532</td>
#       <td id="T_7e5cb_row6_col4" class="data row6 col4" >0.7626</td>
#       <td id="T_7e5cb_row6_col5" class="data row6 col5" >0.1094</td>
#       <td id="T_7e5cb_row6_col6" class="data row6 col6" >0.1105</td>
#     </tr>
#     <tr>
#       <th id="T_7e5cb_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_7e5cb_row7_col0" class="data row7 col0" >0.7738</td>
#       <td id="T_7e5cb_row7_col1" class="data row7 col1" >0.6837</td>
#       <td id="T_7e5cb_row7_col2" class="data row7 col2" >0.7738</td>
#       <td id="T_7e5cb_row7_col3" class="data row7 col3" >0.7672</td>
#       <td id="T_7e5cb_row7_col4" class="data row7 col4" >0.7704</td>
#       <td id="T_7e5cb_row7_col5" class="data row7 col5" >0.1618</td>
#       <td id="T_7e5cb_row7_col6" class="data row7 col6" >0.1619</td>
#     </tr>
#     <tr>
#       <th id="T_7e5cb_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_7e5cb_row8_col0" class="data row8 col0" >0.8333</td>
#       <td id="T_7e5cb_row8_col1" class="data row8 col1" >0.7990</td>
#       <td id="T_7e5cb_row8_col2" class="data row8 col2" >0.8333</td>
#       <td id="T_7e5cb_row8_col3" class="data row8 col3" >0.7917</td>
#       <td id="T_7e5cb_row8_col4" class="data row8 col4" >0.7926</td>
#       <td id="T_7e5cb_row8_col5" class="data row8 col5" >0.1600</td>
#       <td id="T_7e5cb_row8_col6" class="data row8 col6" >0.2000</td>
#     </tr>
#     <tr>
#       <th id="T_7e5cb_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_7e5cb_row9_col0" class="data row9 col0" >0.7738</td>
#       <td id="T_7e5cb_row9_col1" class="data row9 col1" >0.6153</td>
#       <td id="T_7e5cb_row9_col2" class="data row9 col2" >0.7738</td>
#       <td id="T_7e5cb_row9_col3" class="data row9 col3" >0.7370</td>
#       <td id="T_7e5cb_row9_col4" class="data row9 col4" >0.7531</td>
#       <td id="T_7e5cb_row9_col5" class="data row9 col5" >0.0500</td>
#       <td id="T_7e5cb_row9_col6" class="data row9 col6" >0.0516</td>
#     </tr>
#     <tr>
#       <th id="T_7e5cb_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_7e5cb_row10_col0" class="data row10 col0" >0.7856</td>
#       <td id="T_7e5cb_row10_col1" class="data row10 col1" >0.6464</td>
#       <td id="T_7e5cb_row10_col2" class="data row10 col2" >0.7856</td>
#       <td id="T_7e5cb_row10_col3" class="data row10 col3" >0.7555</td>
#       <td id="T_7e5cb_row10_col4" class="data row10 col4" >0.7667</td>
#       <td id="T_7e5cb_row10_col5" class="data row10 col5" >0.1153</td>
#       <td id="T_7e5cb_row10_col6" class="data row10 col6" >0.1207</td>
#     </tr>
#     <tr>
#       <th id="T_7e5cb_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_7e5cb_row11_col0" class="data row11 col0" >0.0338</td>
#       <td id="T_7e5cb_row11_col1" class="data row11 col1" >0.0940</td>
#       <td id="T_7e5cb_row11_col2" class="data row11 col2" >0.0338</td>
#       <td id="T_7e5cb_row11_col3" class="data row11 col3" >0.0376</td>
#       <td id="T_7e5cb_row11_co

# %%
# Création modèle ada boosting

model_ada = create_model('ada') # Création du modèle Ada Boosting
# Out:
#
#
# Initiated  . . . . . . . . . . . . . . . . . .              18:19:49
# Status     . . . . . . . . . . . . . . . . . .  Loading Dependencies
# Estimator  . . . . . . . . . . . . . . . . . .     Compiling Library
# <style type="text/css">
# #T_07398_row10_col0, #T_07398_row10_col1, #T_07398_row10_col2, #T_07398_row10_col3, #T_07398_row10_col4, #T_07398_row10_col5, #T_07398_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_07398">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_07398_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_07398_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_07398_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_07398_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_07398_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_07398_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_07398_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_07398_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_07398_row0_col0" class="data row0 col0" >0.8000</td>
#       <td id="T_07398_row0_col1" class="data row0 col1" >0.6821</td>
#       <td id="T_07398_row0_col2" class="data row0 col2" >0.8000</td>
#       <td id="T_07398_row0_col3" class="data row0 col3" >0.7823</td>
#       <td id="T_07398_row0_col4" class="data row0 col4" >0.7901</td>
#       <td id="T_07398_row0_col5" class="data row0 col5" >0.2047</td>
#       <td id="T_07398_row0_col6" class="data row0 col6" >0.2068</td>
#     </tr>
#     <tr>
#       <th id="T_07398_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_07398_row1_col0" class="data row1 col0" >0.7059</td>
#       <td id="T_07398_row1_col1" class="data row1 col1" >0.6841</td>
#       <td id="T_07398_row1_col2" class="data row1 col2" >0.7059</td>
#       <td id="T_07398_row1_col3" class="data row1 col3" >0.7292</td>
#       <td id="T_07398_row1_col4" class="data row1 col4" >0.7169</td>
#       <td id="T_07398_row1_col5" class="data row1 col5" >0.0157</td>
#       <td id="T_07398_row1_col6" class="data row1 col6" >0.0159</td>
#     </tr>
#     <tr>
#       <th id="T_07398_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_07398_row2_col0" class="data row2 col0" >0.7765</td>
#       <td id="T_07398_row2_col1" class="data row2 col1" >0.5886</td>
#       <td id="T_07398_row2_col2" class="data row2 col2" >0.7765</td>
#       <td id="T_07398_row2_col3" class="data row2 col3" >0.7447</td>
#       <td id="T_07398_row2_col4" class="data row2 col4" >0.7580</td>
#       <td id="T_07398_row2_col5" class="data row2 col5" >0.1151</td>
#       <td id="T_07398_row2_col6" class="data row2 col6" >0.1183</td>
#     </tr>
#     <tr>
#       <th id="T_07398_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_07398_row3_col0" class="data row3 col0" >0.7059</td>
#       <td id="T_07398_row3_col1" class="data row3 col1" >0.5076</td>
#       <td id="T_07398_row3_col2" class="data row3 col2" >0.7059</td>
#       <td id="T_07398_row3_col3" class="data row3 col3" >0.7134</td>
#       <td id="T_07398_row3_col4" class="data row3 col4" >0.7096</td>
#       <td id="T_07398_row3_col5" class="data row3 col5" >0.0139</td>
#       <td id="T_07398_row3_col6" class="data row3 col6" >0.0139</td>
#     </tr>
#     <tr>
#       <th id="T_07398_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_07398_row4_col0" class="data row4 col0" >0.7857</td>
#       <td id="T_07398_row4_col1" class="data row4 col1" >0.6796</td>
#       <td id="T_07398_row4_col2" class="data row4 col2" >0.7857</td>
#       <td id="T_07398_row4_col3" class="data row4 col3" >0.7857</td>
#       <td id="T_07398_row4_col4" class="data row4 col4" >0.7857</td>
#       <td id="T_07398_row4_col5" class="data row4 col5" >0.2286</td>
#       <td id="T_07398_row4_col6" class="data row4 col6" >0.2286</td>
#     </tr>
#     <tr>
#       <th id="T_07398_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_07398_row5_col0" class="data row5 col0" >0.7262</td>
#       <td id="T_07398_row5_col1" class="data row5 col1" >0.5582</td>
#       <td id="T_07398_row5_col2" class="data row5 col2" >0.7262</td>
#       <td id="T_07398_row5_col3" class="data row5 col3" >0.7181</td>
#       <td id="T_07398_row5_col4" class="data row5 col4" >0.7221</td>
#       <td id="T_07398_row5_col5" class="data row5 col5" >-0.0147</td>
#       <td id="T_07398_row5_col6" class="data row5 col6" >-0.0147</td>
#     </tr>
#     <tr>
#       <th id="T_07398_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_07398_row6_col0" class="data row6 col0" >0.7500</td>
#       <td id="T_07398_row6_col1" class="data row6 col1" >0.5388</td>
#       <td id="T_07398_row6_col2" class="data row6 col2" >0.7500</td>
#       <td id="T_07398_row6_col3" class="data row6 col3" >0.7427</td>
#       <td id="T_07398_row6_col4" class="data row6 col4" >0.7463</td>
#       <td id="T_07398_row6_col5" class="data row6 col5" >0.0735</td>
#       <td id="T_07398_row6_col6" class="data row6 col6" >0.0736</td>
#     </tr>
#     <tr>
#       <th id="T_07398_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_07398_row7_col0" class="data row7 col0" >0.6905</td>
#       <td id="T_07398_row7_col1" class="data row7 col1" >0.6418</td>
#       <td id="T_07398_row7_col2" class="data row7 col2" >0.6905</td>
#       <td id="T_07398_row7_col3" class="data row7 col3" >0.7222</td>
#       <td id="T_07398_row7_col4" class="data row7 col4" >0.7053</td>
#       <td id="T_07398_row7_col5" class="data row7 col5" >0.0000</td>
#       <td id="T_07398_row7_col6" class="data row7 col6" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_07398_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_07398_row8_col0" class="data row8 col0" >0.8452</td>
#       <td id="T_07398_row8_col1" class="data row8 col1" >0.6765</td>
#       <td id="T_07398_row8_col2" class="data row8 col2" >0.8452</td>
#       <td id="T_07398_row8_col3" class="data row8 col3" >0.8259</td>
#       <td id="T_07398_row8_col4" class="data row8 col4" >0.8311</td>
#       <td id="T_07398_row8_col5" class="data row8 col5" >0.3500</td>
#       <td id="T_07398_row8_col6" class="data row8 col6" >0.3615</td>
#     </tr>
#     <tr>
#       <th id="T_07398_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_07398_row9_col0" class="data row9 col0" >0.7143</td>
#       <td id="T_07398_row9_col1" class="data row9 col1" >0.5929</td>
#       <td id="T_07398_row9_col2" class="data row9 col2" >0.7143</td>
#       <td id="T_07398_row9_col3" class="data row9 col3" >0.6968</td>
#       <td id="T_07398_row9_col4" class="data row9 col4" >0.7053</td>
#       <td id="T_07398_row9_col5" class="data row9 col5" >-0.0909</td>
#       <td id="T_07398_row9_col6" class="data row9 col6" >-0.0913</td>
#     </tr>
#     <tr>
#       <th id="T_07398_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_07398_row10_col0" class="data row10 col0" >0.7500</td>
#       <td id="T_07398_row10_col1" class="data row10 col1" >0.6150</td>
#       <td id="T_07398_row10_col2" class="data row10 col2" >0.7500</td>
#       <td id="T_07398_row10_col3" class="data row10 col3" >0.7461</td>
#       <td id="T_07398_row10_col4" class="data row10 col4" >0.7470</td>
#       <td id="T_07398_row10_col5" class="data row10 col5" >0.0896</td>
#       <td id="T_07398_row10_col6" class="data row10 col6" >0.0913</td>
#     </tr>
#     <tr>
#       <th id="T_07398_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_07398_row11_col0" class="data row11 col0" >0.0478</td>
#       <td id="T_07398_row11_col1" class="data row11 col1" >0.0630</td>
#       <td id="T_07398_row11_col2" class="data row11 col2" >0.0478</td>
#       <td id="T_07398_row11_col3" class="data row11 col3" >0.0380</td>
#       <td id="T_07398_row11_

# %%
# Création du modèle d'arbre

model_dt = create_model('dt') # Création du modèle Decision Tree

# %% [markdown]
# ### C) Optimisation des hyperparamètres

# %%
# Optimisation du modèle RandomForest pour une meilleure performance

tuned_rf = tune_model(model_rf) # Optimisation du modèle RandomForest
# Out:
# <style type="text/css">
# #T_fb588_row10_col0, #T_fb588_row10_col1, #T_fb588_row10_col2, #T_fb588_row10_col3, #T_fb588_row10_col4, #T_fb588_row10_col5, #T_fb588_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_fb588">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fb588_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_fb588_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_fb588_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_fb588_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_fb588_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_fb588_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_fb588_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fb588_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_fb588_row0_col0" class="data row0 col0" >0.8353</td>
#       <td id="T_fb588_row0_col1" class="data row0 col1" >0.5000</td>
#       <td id="T_fb588_row0_col2" class="data row0 col2" >0.8353</td>
#       <td id="T_fb588_row0_col3" class="data row0 col3" >0.6977</td>
#       <td id="T_fb588_row0_col4" class="data row0 col4" >0.7603</td>
#       <td id="T_fb588_row0_col5" class="data row0 col5" >0.0000</td>
#       <td id="T_fb588_row0_col6" class="data row0 col6" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_fb588_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_fb588_row1_col0" class="data row1 col0" >0.8353</td>
#       <td id="T_fb588_row1_col1" class="data row1 col1" >0.5000</td>
#       <td id="T_fb588_row1_col2" class="data row1 col2" >0.8353</td>
#       <td id="T_fb588_row1_col3" class="data row1 col3" >0.6977</td>
#       <td id="T_fb588_row1_col4" class="data row1 col4" >0.7603</td>
#       <td id="T_fb588_row1_col5" class="data row1 col5" >0.0000</td>
#       <td id="T_fb588_row1_col6" class="data row1 col6" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_fb588_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_fb588_row2_col0" class="data row2 col0" >0.8235</td>
#       <td id="T_fb588_row2_col1" class="data row2 col1" >0.5000</td>
#       <td id="T_fb588_row2_col2" class="data row2 col2" >0.8235</td>
#       <td id="T_fb588_row2_col3" class="data row2 col3" >0.6782</td>
#       <td id="T_fb588_row2_col4" class="data row2 col4" >0.7438</td>
#       <td id="T_fb588_row2_col5" class="data row2 col5" >0.0000</td>
#       <td id="T_fb588_row2_col6" class="data row2 col6" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_fb588_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_fb588_row3_col0" class="data row3 col0" >0.8235</td>
#       <td id="T_fb588_row3_col1" class="data row3 col1" >0.5000</td>
#       <td id="T_fb588_row3_col2" class="data row3 col2" >0.8235</td>
#       <td id="T_fb588_row3_col3" class="data row3 col3" >0.6782</td>
#       <td id="T_fb588_row3_col4" class="data row3 col4" >0.7438</td>
#       <td id="T_fb588_row3_col5" class="data row3 col5" >0.0000</td>
#       <td id="T_fb588_row3_col6" class="data row3 col6" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_fb588_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_fb588_row4_col0" class="data row4 col0" >0.8333</td>
#       <td id="T_fb588_row4_col1" class="data row4 col1" >0.5000</td>
#       <td id="T_fb588_row4_col2" class="data row4 col2" >0.8333</td>
#       <td id="T_fb588_row4_col3" class="data row4 col3" >0.6944</td>
#       <td id="T_fb588_row4_col4" class="data row4 col4" >0.7576</td>
#       <td id="T_fb588_row4_col5" class="data row4 col5" >0.0000</td>
#       <td id="T_fb588_row4_col6" class="data row4 col6" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_fb588_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_fb588_row5_col0" class="data row5 col0" >0.8333</td>
#       <td id="T_fb588_row5_col1" class="data row5 col1" >0.5000</td>
#       <td id="T_fb588_row5_col2" class="data row5 col2" >0.8333</td>
#       <td id="T_fb588_row5_col3" class="data row5 col3" >0.6944</td>
#       <td id="T_fb588_row5_col4" class="data row5 col4" >0.7576</td>
#       <td id="T_fb588_row5_col5" class="data row5 col5" >0.0000</td>
#       <td id="T_fb588_row5_col6" class="data row5 col6" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_fb588_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_fb588_row6_col0" class="data row6 col0" >0.8333</td>
#       <td id="T_fb588_row6_col1" class="data row6 col1" >0.5000</td>
#       <td id="T_fb588_row6_col2" class="data row6 col2" >0.8333</td>
#       <td id="T_fb588_row6_col3" class="data row6 col3" >0.6944</td>
#       <td id="T_fb588_row6_col4" class="data row6 col4" >0.7576</td>
#       <td id="T_fb588_row6_col5" class="data row6 col5" >0.0000</td>
#       <td id="T_fb588_row6_col6" class="data row6 col6" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_fb588_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_fb588_row7_col0" class="data row7 col0" >0.8333</td>
#       <td id="T_fb588_row7_col1" class="data row7 col1" >0.5000</td>
#       <td id="T_fb588_row7_col2" class="data row7 col2" >0.8333</td>
#       <td id="T_fb588_row7_col3" class="data row7 col3" >0.6944</td>
#       <td id="T_fb588_row7_col4" class="data row7 col4" >0.7576</td>
#       <td id="T_fb588_row7_col5" class="data row7 col5" >0.0000</td>
#       <td id="T_fb588_row7_col6" class="data row7 col6" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_fb588_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_fb588_row8_col0" class="data row8 col0" >0.8333</td>
#       <td id="T_fb588_row8_col1" class="data row8 col1" >0.5000</td>
#       <td id="T_fb588_row8_col2" class="data row8 col2" >0.8333</td>
#       <td id="T_fb588_row8_col3" class="data row8 col3" >0.6944</td>
#       <td id="T_fb588_row8_col4" class="data row8 col4" >0.7576</td>
#       <td id="T_fb588_row8_col5" class="data row8 col5" >0.0000</td>
#       <td id="T_fb588_row8_col6" class="data row8 col6" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_fb588_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_fb588_row9_col0" class="data row9 col0" >0.8333</td>
#       <td id="T_fb588_row9_col1" class="data row9 col1" >0.5000</td>
#       <td id="T_fb588_row9_col2" class="data row9 col2" >0.8333</td>
#       <td id="T_fb588_row9_col3" class="data row9 col3" >0.6944</td>
#       <td id="T_fb588_row9_col4" class="data row9 col4" >0.7576</td>
#       <td id="T_fb588_row9_col5" class="data row9 col5" >0.0000</td>
#       <td id="T_fb588_row9_col6" class="data row9 col6" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_fb588_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_fb588_row10_col0" class="data row10 col0" >0.8318</td>
#       <td id="T_fb588_row10_col1" class="data row10 col1" >0.5000</td>
#       <td id="T_fb588_row10_col2" class="data row10 col2" >0.8318</td>
#       <td id="T_fb588_row10_col3" class="data row10 col3" >0.6919</td>
#       <td id="T_fb588_row10_col4" class="data row10 col4" >0.7554</td>
#       <td id="T_fb588_row10_col5" class="data row10 col5" >0.0000</td>
#       <td id="T_fb588_row10_col6" class="data row10 col6" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_fb588_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_fb588_row11_col0" class="data row11 col0" >0.0042</td>
#       <td id="T_fb588_row11_col1" class="data row11 col1" >0.0000</td>
#       <td id="T_fb588_row11_col2" class="data row11 col2" >0.0042</td>
#       <td id="T_fb588_row11_col3" class="data row11 col3" >0.0069</td>
#       <td id="T_fb588_row11_col4
# Fitting 10 folds for each of 10 candidates, totalling 100 fits

# %%
# Optimisation du modèle Gradient Boosting

tuned_gbc = tune_model(model_gbc) # Optimisation du modèle Gradient Boosting
# Out:
# <style type="text/css">
# #T_b0ace_row10_col0, #T_b0ace_row10_col1, #T_b0ace_row10_col2, #T_b0ace_row10_col3, #T_b0ace_row10_col4, #T_b0ace_row10_col5, #T_b0ace_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_b0ace">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b0ace_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_b0ace_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_b0ace_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_b0ace_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_b0ace_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_b0ace_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_b0ace_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b0ace_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b0ace_row0_col0" class="data row0 col0" >0.8000</td>
#       <td id="T_b0ace_row0_col1" class="data row0 col1" >0.7515</td>
#       <td id="T_b0ace_row0_col2" class="data row0 col2" >0.8000</td>
#       <td id="T_b0ace_row0_col3" class="data row0 col3" >0.7823</td>
#       <td id="T_b0ace_row0_col4" class="data row0 col4" >0.7901</td>
#       <td id="T_b0ace_row0_col5" class="data row0 col5" >0.2047</td>
#       <td id="T_b0ace_row0_col6" class="data row0 col6" >0.2068</td>
#     </tr>
#     <tr>
#       <th id="T_b0ace_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_b0ace_row1_col0" class="data row1 col0" >0.7412</td>
#       <td id="T_b0ace_row1_col1" class="data row1 col1" >0.7334</td>
#       <td id="T_b0ace_row1_col2" class="data row1 col2" >0.7412</td>
#       <td id="T_b0ace_row1_col3" class="data row1 col3" >0.7070</td>
#       <td id="T_b0ace_row1_col4" class="data row1 col4" >0.7232</td>
#       <td id="T_b0ace_row1_col5" class="data row1 col5" >-0.0625</td>
#       <td id="T_b0ace_row1_col6" class="data row1 col6" >-0.0637</td>
#     </tr>
#     <tr>
#       <th id="T_b0ace_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_b0ace_row2_col0" class="data row2 col0" >0.7294</td>
#       <td id="T_b0ace_row2_col1" class="data row2 col1" >0.5838</td>
#       <td id="T_b0ace_row2_col2" class="data row2 col2" >0.7294</td>
#       <td id="T_b0ace_row2_col3" class="data row2 col3" >0.6631</td>
#       <td id="T_b0ace_row2_col4" class="data row2 col4" >0.6947</td>
#       <td id="T_b0ace_row2_col5" class="data row2 col5" >-0.1399</td>
#       <td id="T_b0ace_row2_col6" class="data row2 col6" >-0.1492</td>
#     </tr>
#     <tr>
#       <th id="T_b0ace_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_b0ace_row3_col0" class="data row3 col0" >0.7647</td>
#       <td id="T_b0ace_row3_col1" class="data row3 col1" >0.5229</td>
#       <td id="T_b0ace_row3_col2" class="data row3 col2" >0.7647</td>
#       <td id="T_b0ace_row3_col3" class="data row3 col3" >0.7219</td>
#       <td id="T_b0ace_row3_col4" class="data row3 col4" >0.7401</td>
#       <td id="T_b0ace_row3_col5" class="data row3 col5" >0.0395</td>
#       <td id="T_b0ace_row3_col6" class="data row3 col6" >0.0413</td>
#     </tr>
#     <tr>
#       <th id="T_b0ace_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_b0ace_row4_col0" class="data row4 col0" >0.8571</td>
#       <td id="T_b0ace_row4_col1" class="data row4 col1" >0.6796</td>
#       <td id="T_b0ace_row4_col2" class="data row4 col2" >0.8571</td>
#       <td id="T_b0ace_row4_col3" class="data row4 col3" >0.8432</td>
#       <td id="T_b0ace_row4_col4" class="data row4 col4" >0.8472</td>
#       <td id="T_b0ace_row4_col5" class="data row4 col5" >0.4194</td>
#       <td id="T_b0ace_row4_col6" class="data row4 col6" >0.4274</td>
#     </tr>
#     <tr>
#       <th id="T_b0ace_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_b0ace_row5_col0" class="data row5 col0" >0.7976</td>
#       <td id="T_b0ace_row5_col1" class="data row5 col1" >0.6490</td>
#       <td id="T_b0ace_row5_col2" class="data row5 col2" >0.7976</td>
#       <td id="T_b0ace_row5_col3" class="data row5 col3" >0.7295</td>
#       <td id="T_b0ace_row5_col4" class="data row5 col4" >0.7558</td>
#       <td id="T_b0ace_row5_col5" class="data row5 col5" >0.0192</td>
#       <td id="T_b0ace_row5_col6" class="data row5 col6" >0.0225</td>
#     </tr>
#     <tr>
#       <th id="T_b0ace_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_b0ace_row6_col0" class="data row6 col0" >0.7976</td>
#       <td id="T_b0ace_row6_col1" class="data row6 col1" >0.5408</td>
#       <td id="T_b0ace_row6_col2" class="data row6 col2" >0.7976</td>
#       <td id="T_b0ace_row6_col3" class="data row6 col3" >0.7511</td>
#       <td id="T_b0ace_row6_col4" class="data row6 col4" >0.7687</td>
#       <td id="T_b0ace_row6_col5" class="data row6 col5" >0.0893</td>
#       <td id="T_b0ace_row6_col6" class="data row6 col6" >0.0963</td>
#     </tr>
#     <tr>
#       <th id="T_b0ace_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_b0ace_row7_col0" class="data row7 col0" >0.7738</td>
#       <td id="T_b0ace_row7_col1" class="data row7 col1" >0.6816</td>
#       <td id="T_b0ace_row7_col2" class="data row7 col2" >0.7738</td>
#       <td id="T_b0ace_row7_col3" class="data row7 col3" >0.7532</td>
#       <td id="T_b0ace_row7_col4" class="data row7 col4" >0.7626</td>
#       <td id="T_b0ace_row7_col5" class="data row7 col5" >0.1094</td>
#       <td id="T_b0ace_row7_col6" class="data row7 col6" >0.1105</td>
#     </tr>
#     <tr>
#       <th id="T_b0ace_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_b0ace_row8_col0" class="data row8 col0" >0.8095</td>
#       <td id="T_b0ace_row8_col1" class="data row8 col1" >0.8163</td>
#       <td id="T_b0ace_row8_col2" class="data row8 col2" >0.8095</td>
#       <td id="T_b0ace_row8_col3" class="data row8 col3" >0.7607</td>
#       <td id="T_b0ace_row8_col4" class="data row8 col4" >0.7766</td>
#       <td id="T_b0ace_row8_col5" class="data row8 col5" >0.1111</td>
#       <td id="T_b0ace_row8_col6" class="data row8 col6" >0.1240</td>
#     </tr>
#     <tr>
#       <th id="T_b0ace_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_b0ace_row9_col0" class="data row9 col0" >0.7976</td>
#       <td id="T_b0ace_row9_col1" class="data row9 col1" >0.6500</td>
#       <td id="T_b0ace_row9_col2" class="data row9 col2" >0.7976</td>
#       <td id="T_b0ace_row9_col3" class="data row9 col3" >0.7511</td>
#       <td id="T_b0ace_row9_col4" class="data row9 col4" >0.7687</td>
#       <td id="T_b0ace_row9_col5" class="data row9 col5" >0.0893</td>
#       <td id="T_b0ace_row9_col6" class="data row9 col6" >0.0963</td>
#     </tr>
#     <tr>
#       <th id="T_b0ace_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_b0ace_row10_col0" class="data row10 col0" >0.7869</td>
#       <td id="T_b0ace_row10_col1" class="data row10 col1" >0.6609</td>
#       <td id="T_b0ace_row10_col2" class="data row10 col2" >0.7869</td>
#       <td id="T_b0ace_row10_col3" class="data row10 col3" >0.7463</td>
#       <td id="T_b0ace_row10_col4" class="data row10 col4" >0.7628</td>
#       <td id="T_b0ace_row10_col5" class="data row10 col5" >0.0879</td>
#       <td id="T_b0ace_row10_col6" class="data row10 col6" >0.0912</td>
#     </tr>
#     <tr>
#       <th id="T_b0ace_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_b0ace_row11_col0" class="data row11 col0" >0.0347</td>
#       <td id="T_b0ace_row11_col1" class="data row11 col1" >0.0884</td>
#       <td id="T_b0ace_row11_col2" class="data row11 col2" >0.0347</td>
#       <td id="T_b0ace_row11_col3" class="data row11 col3" >0.0451</td>
#       <td id="T_b0ace_row11_
# Fitting 10 folds for each of 10 candidates, totalling 100 fits

# %%
# Optimisation du modèle Ada Boosting

tuned_ada = tune_model(model_ada) # Optimisation du modèle Ada Boosting
# Out:
# <style type="text/css">
# #T_a5fba_row10_col0, #T_a5fba_row10_col1, #T_a5fba_row10_col2, #T_a5fba_row10_col3, #T_a5fba_row10_col4, #T_a5fba_row10_col5, #T_a5fba_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_a5fba">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a5fba_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_a5fba_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_a5fba_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_a5fba_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_a5fba_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_a5fba_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_a5fba_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a5fba_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a5fba_row0_col0" class="data row0 col0" >0.7765</td>
#       <td id="T_a5fba_row0_col1" class="data row0 col1" >0.7082</td>
#       <td id="T_a5fba_row0_col2" class="data row0 col2" >0.7765</td>
#       <td id="T_a5fba_row0_col3" class="data row0 col3" >0.7952</td>
#       <td id="T_a5fba_row0_col4" class="data row0 col4" >0.7849</td>
#       <td id="T_a5fba_row0_col5" class="data row0 col5" >0.2520</td>
#       <td id="T_a5fba_row0_col6" class="data row0 col6" >0.2537</td>
#     </tr>
#     <tr>
#       <th id="T_a5fba_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a5fba_row1_col0" class="data row1 col0" >0.7529</td>
#       <td id="T_a5fba_row1_col1" class="data row1 col1" >0.6992</td>
#       <td id="T_a5fba_row1_col2" class="data row1 col2" >0.7529</td>
#       <td id="T_a5fba_row1_col3" class="data row1 col3" >0.7599</td>
#       <td id="T_a5fba_row1_col4" class="data row1 col4" >0.7563</td>
#       <td id="T_a5fba_row1_col5" class="data row1 col5" >0.1271</td>
#       <td id="T_a5fba_row1_col6" class="data row1 col6" >0.1272</td>
#     </tr>
#     <tr>
#       <th id="T_a5fba_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_a5fba_row2_col0" class="data row2 col0" >0.7176</td>
#       <td id="T_a5fba_row2_col1" class="data row2 col1" >0.5762</td>
#       <td id="T_a5fba_row2_col2" class="data row2 col2" >0.7176</td>
#       <td id="T_a5fba_row2_col3" class="data row2 col3" >0.7318</td>
#       <td id="T_a5fba_row2_col4" class="data row2 col4" >0.7244</td>
#       <td id="T_a5fba_row2_col5" class="data row2 col5" >0.0769</td>
#       <td id="T_a5fba_row2_col6" class="data row2 col6" >0.0772</td>
#     </tr>
#     <tr>
#       <th id="T_a5fba_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_a5fba_row3_col0" class="data row3 col0" >0.6588</td>
#       <td id="T_a5fba_row3_col1" class="data row3 col1" >0.5652</td>
#       <td id="T_a5fba_row3_col2" class="data row3 col2" >0.6588</td>
#       <td id="T_a5fba_row3_col3" class="data row3 col3" >0.7118</td>
#       <td id="T_a5fba_row3_col4" class="data row3 col4" >0.6821</td>
#       <td id="T_a5fba_row3_col5" class="data row3 col5" >0.0080</td>
#       <td id="T_a5fba_row3_col6" class="data row3 col6" >0.0083</td>
#     </tr>
#     <tr>
#       <th id="T_a5fba_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_a5fba_row4_col0" class="data row4 col0" >0.8214</td>
#       <td id="T_a5fba_row4_col1" class="data row4 col1" >0.7531</td>
#       <td id="T_a5fba_row4_col2" class="data row4 col2" >0.8214</td>
#       <td id="T_a5fba_row4_col3" class="data row4 col3" >0.7963</td>
#       <td id="T_a5fba_row4_col4" class="data row4 col4" >0.8051</td>
#       <td id="T_a5fba_row4_col5" class="data row4 col5" >0.2500</td>
#       <td id="T_a5fba_row4_col6" class="data row4 col6" >0.2582</td>
#     </tr>
#     <tr>
#       <th id="T_a5fba_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_a5fba_row5_col0" class="data row5 col0" >0.7619</td>
#       <td id="T_a5fba_row5_col1" class="data row5 col1" >0.6020</td>
#       <td id="T_a5fba_row5_col2" class="data row5 col2" >0.7619</td>
#       <td id="T_a5fba_row5_col3" class="data row5 col3" >0.7116</td>
#       <td id="T_a5fba_row5_col4" class="data row5 col4" >0.7343</td>
#       <td id="T_a5fba_row5_col5" class="data row5 col5" >-0.0345</td>
#       <td id="T_a5fba_row5_col6" class="data row5 col6" >-0.0363</td>
#     </tr>
#     <tr>
#       <th id="T_a5fba_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_a5fba_row6_col0" class="data row6 col0" >0.7381</td>
#       <td id="T_a5fba_row6_col1" class="data row6 col1" >0.5235</td>
#       <td id="T_a5fba_row6_col2" class="data row6 col2" >0.7381</td>
#       <td id="T_a5fba_row6_col3" class="data row6 col3" >0.7381</td>
#       <td id="T_a5fba_row6_col4" class="data row6 col4" >0.7381</td>
#       <td id="T_a5fba_row6_col5" class="data row6 col5" >0.0571</td>
#       <td id="T_a5fba_row6_col6" class="data row6 col6" >0.0571</td>
#     </tr>
#     <tr>
#       <th id="T_a5fba_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_a5fba_row7_col0" class="data row7 col0" >0.7143</td>
#       <td id="T_a5fba_row7_col1" class="data row7 col1" >0.6755</td>
#       <td id="T_a5fba_row7_col2" class="data row7 col2" >0.7143</td>
#       <td id="T_a5fba_row7_col3" class="data row7 col3" >0.7441</td>
#       <td id="T_a5fba_row7_col4" class="data row7 col4" >0.7279</td>
#       <td id="T_a5fba_row7_col5" class="data row7 col5" >0.0769</td>
#       <td id="T_a5fba_row7_col6" class="data row7 col6" >0.0778</td>
#     </tr>
#     <tr>
#       <th id="T_a5fba_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_a5fba_row8_col0" class="data row8 col0" >0.7857</td>
#       <td id="T_a5fba_row8_col1" class="data row8 col1" >0.7276</td>
#       <td id="T_a5fba_row8_col2" class="data row8 col2" >0.7857</td>
#       <td id="T_a5fba_row8_col3" class="data row8 col3" >0.7595</td>
#       <td id="T_a5fba_row8_col4" class="data row8 col4" >0.7708</td>
#       <td id="T_a5fba_row8_col5" class="data row8 col5" >0.1290</td>
#       <td id="T_a5fba_row8_col6" class="data row8 col6" >0.1315</td>
#     </tr>
#     <tr>
#       <th id="T_a5fba_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_a5fba_row9_col0" class="data row9 col0" >0.7857</td>
#       <td id="T_a5fba_row9_col1" class="data row9 col1" >0.6776</td>
#       <td id="T_a5fba_row9_col2" class="data row9 col2" >0.7857</td>
#       <td id="T_a5fba_row9_col3" class="data row9 col3" >0.7857</td>
#       <td id="T_a5fba_row9_col4" class="data row9 col4" >0.7857</td>
#       <td id="T_a5fba_row9_col5" class="data row9 col5" >0.2286</td>
#       <td id="T_a5fba_row9_col6" class="data row9 col6" >0.2286</td>
#     </tr>
#     <tr>
#       <th id="T_a5fba_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_a5fba_row10_col0" class="data row10 col0" >0.7513</td>
#       <td id="T_a5fba_row10_col1" class="data row10 col1" >0.6508</td>
#       <td id="T_a5fba_row10_col2" class="data row10 col2" >0.7513</td>
#       <td id="T_a5fba_row10_col3" class="data row10 col3" >0.7534</td>
#       <td id="T_a5fba_row10_col4" class="data row10 col4" >0.7510</td>
#       <td id="T_a5fba_row10_col5" class="data row10 col5" >0.1171</td>
#       <td id="T_a5fba_row10_col6" class="data row10 col6" >0.1183</td>
#     </tr>
#     <tr>
#       <th id="T_a5fba_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_a5fba_row11_col0" class="data row11 col0" >0.0439</td>
#       <td id="T_a5fba_row11_col1" class="data row11 col1" >0.0740</td>
#       <td id="T_a5fba_row11_col2" class="data row11 col2" >0.0439</td>
#       <td id="T_a5fba_row11_col3" class="data row11 col3" >0.0299</td>
#       <td id="T_a5fba_row11_co
# Fitting 10 folds for each of 10 candidates, totalling 100 fits

# %%
# Optimisation du modèle Decision Tree

tuned_dt = tune_model(model_dt) # Optimisation du modèle Decision Tree
# Out:
# <style type="text/css">
# #T_22e58_row10_col0, #T_22e58_row10_col1, #T_22e58_row10_col2, #T_22e58_row10_col3, #T_22e58_row10_col4, #T_22e58_row10_col5, #T_22e58_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_22e58">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_22e58_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_22e58_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_22e58_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_22e58_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_22e58_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_22e58_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_22e58_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_22e58_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_22e58_row0_col0" class="data row0 col0" >0.8353</td>
#       <td id="T_22e58_row0_col1" class="data row0 col1" >0.5000</td>
#       <td id="T_22e58_row0_col2" class="data row0 col2" >0.8353</td>
#       <td id="T_22e58_row0_col3" class="data row0 col3" >0.6977</td>
#       <td id="T_22e58_row0_col4" class="data row0 col4" >0.7603</td>
#       <td id="T_22e58_row0_col5" class="data row0 col5" >0.0000</td>
#       <td id="T_22e58_row0_col6" class="data row0 col6" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_22e58_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_22e58_row1_col0" class="data row1 col0" >0.8353</td>
#       <td id="T_22e58_row1_col1" class="data row1 col1" >0.5000</td>
#       <td id="T_22e58_row1_col2" class="data row1 col2" >0.8353</td>
#       <td id="T_22e58_row1_col3" class="data row1 col3" >0.6977</td>
#       <td id="T_22e58_row1_col4" class="data row1 col4" >0.7603</td>
#       <td id="T_22e58_row1_col5" class="data row1 col5" >0.0000</td>
#       <td id="T_22e58_row1_col6" class="data row1 col6" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_22e58_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_22e58_row2_col0" class="data row2 col0" >0.8235</td>
#       <td id="T_22e58_row2_col1" class="data row2 col1" >0.5000</td>
#       <td id="T_22e58_row2_col2" class="data row2 col2" >0.8235</td>
#       <td id="T_22e58_row2_col3" class="data row2 col3" >0.6782</td>
#       <td id="T_22e58_row2_col4" class="data row2 col4" >0.7438</td>
#       <td id="T_22e58_row2_col5" class="data row2 col5" >0.0000</td>
#       <td id="T_22e58_row2_col6" class="data row2 col6" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_22e58_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_22e58_row3_col0" class="data row3 col0" >0.8235</td>
#       <td id="T_22e58_row3_col1" class="data row3 col1" >0.5000</td>
#       <td id="T_22e58_row3_col2" class="data row3 col2" >0.8235</td>
#       <td id="T_22e58_row3_col3" class="data row3 col3" >0.6782</td>
#       <td id="T_22e58_row3_col4" class="data row3 col4" >0.7438</td>
#       <td id="T_22e58_row3_col5" class="data row3 col5" >0.0000</td>
#       <td id="T_22e58_row3_col6" class="data row3 col6" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_22e58_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_22e58_row4_col0" class="data row4 col0" >0.8333</td>
#       <td id="T_22e58_row4_col1" class="data row4 col1" >0.5000</td>
#       <td id="T_22e58_row4_col2" class="data row4 col2" >0.8333</td>
#       <td id="T_22e58_row4_col3" class="data row4 col3" >0.6944</td>
#       <td id="T_22e58_row4_col4" class="data row4 col4" >0.7576</td>
#       <td id="T_22e58_row4_col5" class="data row4 col5" >0.0000</td>
#       <td id="T_22e58_row4_col6" class="data row4 col6" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_22e58_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_22e58_row5_col0" class="data row5 col0" >0.8333</td>
#       <td id="T_22e58_row5_col1" class="data row5 col1" >0.5000</td>
#       <td id="T_22e58_row5_col2" class="data row5 col2" >0.8333</td>
#       <td id="T_22e58_row5_col3" class="data row5 col3" >0.6944</td>
#       <td id="T_22e58_row5_col4" class="data row5 col4" >0.7576</td>
#       <td id="T_22e58_row5_col5" class="data row5 col5" >0.0000</td>
#       <td id="T_22e58_row5_col6" class="data row5 col6" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_22e58_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_22e58_row6_col0" class="data row6 col0" >0.8333</td>
#       <td id="T_22e58_row6_col1" class="data row6 col1" >0.5000</td>
#       <td id="T_22e58_row6_col2" class="data row6 col2" >0.8333</td>
#       <td id="T_22e58_row6_col3" class="data row6 col3" >0.6944</td>
#       <td id="T_22e58_row6_col4" class="data row6 col4" >0.7576</td>
#       <td id="T_22e58_row6_col5" class="data row6 col5" >0.0000</td>
#       <td id="T_22e58_row6_col6" class="data row6 col6" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_22e58_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_22e58_row7_col0" class="data row7 col0" >0.8333</td>
#       <td id="T_22e58_row7_col1" class="data row7 col1" >0.5000</td>
#       <td id="T_22e58_row7_col2" class="data row7 col2" >0.8333</td>
#       <td id="T_22e58_row7_col3" class="data row7 col3" >0.6944</td>
#       <td id="T_22e58_row7_col4" class="data row7 col4" >0.7576</td>
#       <td id="T_22e58_row7_col5" class="data row7 col5" >0.0000</td>
#       <td id="T_22e58_row7_col6" class="data row7 col6" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_22e58_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_22e58_row8_col0" class="data row8 col0" >0.8333</td>
#       <td id="T_22e58_row8_col1" class="data row8 col1" >0.5000</td>
#       <td id="T_22e58_row8_col2" class="data row8 col2" >0.8333</td>
#       <td id="T_22e58_row8_col3" class="data row8 col3" >0.6944</td>
#       <td id="T_22e58_row8_col4" class="data row8 col4" >0.7576</td>
#       <td id="T_22e58_row8_col5" class="data row8 col5" >0.0000</td>
#       <td id="T_22e58_row8_col6" class="data row8 col6" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_22e58_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_22e58_row9_col0" class="data row9 col0" >0.8333</td>
#       <td id="T_22e58_row9_col1" class="data row9 col1" >0.5000</td>
#       <td id="T_22e58_row9_col2" class="data row9 col2" >0.8333</td>
#       <td id="T_22e58_row9_col3" class="data row9 col3" >0.6944</td>
#       <td id="T_22e58_row9_col4" class="data row9 col4" >0.7576</td>
#       <td id="T_22e58_row9_col5" class="data row9 col5" >0.0000</td>
#       <td id="T_22e58_row9_col6" class="data row9 col6" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_22e58_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_22e58_row10_col0" class="data row10 col0" >0.8318</td>
#       <td id="T_22e58_row10_col1" class="data row10 col1" >0.5000</td>
#       <td id="T_22e58_row10_col2" class="data row10 col2" >0.8318</td>
#       <td id="T_22e58_row10_col3" class="data row10 col3" >0.6919</td>
#       <td id="T_22e58_row10_col4" class="data row10 col4" >0.7554</td>
#       <td id="T_22e58_row10_col5" class="data row10 col5" >0.0000</td>
#       <td id="T_22e58_row10_col6" class="data row10 col6" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_22e58_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_22e58_row11_col0" class="data row11 col0" >0.0042</td>
#       <td id="T_22e58_row11_col1" class="data row11 col1" >0.0000</td>
#       <td id="T_22e58_row11_col2" class="data row11 col2" >0.0042</td>
#       <td id="T_22e58_row11_col3" class="data row11 col3" >0.0069</td>
#       <td id="T_22e58_row11_col4
# Fitting 10 folds for each of 10 candidates, totalling 100 fits

# %% [markdown]
# ### D) Comparaison des modèles optimisés

# %%
# Comparaison des modèles optimisés
 
compare_models() # Comparaison des modèles optimisés
# Out:
# <style type="text/css">
# #T_cce48 th {
#   text-align: left;
# }
# #T_cce48_row0_col0, #T_cce48_row0_col2, #T_cce48_row0_col4, #T_cce48_row0_col5, #T_cce48_row0_col6, #T_cce48_row0_col7, #T_cce48_row1_col0, #T_cce48_row1_col1, #T_cce48_row1_col2, #T_cce48_row1_col3, #T_cce48_row1_col4, #T_cce48_row1_col5, #T_cce48_row1_col6, #T_cce48_row1_col7, #T_cce48_row2_col0, #T_cce48_row2_col1, #T_cce48_row2_col2, #T_cce48_row2_col3, #T_cce48_row2_col4, #T_cce48_row2_col5, #T_cce48_row2_col6, #T_cce48_row2_col7, #T_cce48_row3_col0, #T_cce48_row3_col1, #T_cce48_row3_col3, #T_cce48_row3_col4, #T_cce48_row3_col5, #T_cce48_row3_col6, #T_cce48_row3_col7, #T_cce48_row4_col0, #T_cce48_row4_col1, #T_cce48_row4_col2, #T_cce48_row4_col3, #T_cce48_row4_col4, #T_cce48_row4_col6, #T_cce48_row4_col7, #T_cce48_row5_col0, #T_cce48_row5_col1, #T_cce48_row5_col2, #T_cce48_row5_col3, #T_cce48_row5_col4, #T_cce48_row5_col5, #T_cce48_row5_col6, #T_cce48_row5_col7, #T_cce48_row6_col0, #T_cce48_row6_col1, #T_cce48_row6_col2, #T_cce48_row6_col3, #T_cce48_row6_col4, #T_cce48_row6_col5, #T_cce48_row6_col6, #T_cce48_row6_col7, #T_cce48_row7_col0, #T_cce48_row7_col1, #T_cce48_row7_col2, #T_cce48_row7_col3, #T_cce48_row7_col4, #T_cce48_row7_col5, #T_cce48_row7_col6, #T_cce48_row7_col7, #T_cce48_row8_col0, #T_cce48_row8_col1, #T_cce48_row8_col2, #T_cce48_row8_col3, #T_cce48_row8_col4, #T_cce48_row8_col5, #T_cce48_row8_col6, #T_cce48_row8_col7, #T_cce48_row9_col0, #T_cce48_row9_col1, #T_cce48_row9_col2, #T_cce48_row9_col3, #T_cce48_row9_col4, #T_cce48_row9_col5, #T_cce48_row9_col6, #T_cce48_row9_col7, #T_cce48_row10_col0, #T_cce48_row10_col1, #T_cce48_row10_col2, #T_cce48_row10_col3, #T_cce48_row10_col5, #T_cce48_row11_col0, #T_cce48_row11_col1, #T_cce48_row11_col2, #T_cce48_row11_col3, #T_cce48_row11_col4, #T_cce48_row11_col5, #T_cce48_row11_col6, #T_cce48_row11_col7, #T_cce48_row12_col0, #T_cce48_row12_col1, #T_cce48_row12_col2, #T_cce48_row12_col3, #T_cce48_row12_col4, #T_cce48_row12_col5, #T_cce48_row12_col6, #T_cce48_row12_col7, #T_cce48_row13_col0, #T_cce48_row13_col1, #T_cce48_row13_col2, #T_cce48_row13_col3, #T_cce48_row13_col4, #T_cce48_row13_col5, #T_cce48_row13_col6, #T_cce48_row13_col7 {
#   text-align: left;
# }
# #T_cce48_row0_col1, #T_cce48_row0_col3, #T_cce48_row3_col2, #T_cce48_row4_col5, #T_cce48_row10_col4, #T_cce48_row10_col6, #T_cce48_row10_col7 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_cce48_row0_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# #T_cce48_row1_col8, #T_cce48_row2_col8, #T_cce48_row3_col8, #T_cce48_row4_col8, #T_cce48_row5_col8, #T_cce48_row6_col8, #T_cce48_row7_col8, #T_cce48_row8_col8, #T_cce48_row9_col8, #T_cce48_row10_col8, #T_cce48_row11_col8, #T_cce48_row12_col8, #T_cce48_row13_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_cce48">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cce48_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_cce48_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_cce48_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_cce48_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_cce48_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_cce48_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_cce48_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_cce48_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_cce48_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cce48_level0_row0" class="row_heading level0 row0" >dummy</th>
#       <td id="T_cce48_row0_col0" class="data row0 col0" >Dummy Classifier</td>
#       <td id="T_cce48_row0_col1" class="data row0 col1" >0.8318</td>
#       <td id="T_cce48_row0_col2" class="data row0 col2" >0.5000</td>
#       <td id="T_cce48_row0_col3" class="data row0 col3" >0.8318</td>
#       <td id="T_cce48_row0_col4" class="data row0 col4" >0.6919</td>
#       <td id="T_cce48_row0_col5" class="data row0 col5" >0.7554</td>
#       <td id="T_cce48_row0_col6" class="data row0 col6" >0.0000</td>
#       <td id="T_cce48_row0_col7" class="data row0 col7" >0.0000</td>
#       <td id="T_cce48_row0_col8" class="data row0 col8" >0.1830</td>
#     </tr>
#     <tr>
#       <th id="T_cce48_level0_row1" class="row_heading level0 row1" >et</th>
#       <td id="T_cce48_row1_col0" class="data row1 col0" >Extra Trees Classifier</td>
#       <td id="T_cce48_row1_col1" class="data row1 col1" >0.8081</td>
#       <td id="T_cce48_row1_col2" class="data row1 col2" >0.6588</td>
#       <td id="T_cce48_row1_col3" class="data row1 col3" >0.8081</td>
#       <td id="T_cce48_row1_col4" class="data row1 col4" >0.7385</td>
#       <td id="T_cce48_row1_col5" class="data row1 col5" >0.7646</td>
#       <td id="T_cce48_row1_col6" class="data row1 col6" >0.0633</td>
#       <td id="T_cce48_row1_col7" class="data row1 col7" >0.0661</td>
#       <td id="T_cce48_row1_col8" class="data row1 col8" >0.5430</td>
#     </tr>
#     <tr>
#       <th id="T_cce48_level0_row2" class="row_heading level0 row2" >qda</th>
#       <td id="T_cce48_row2_col0" class="data row2 col0" >Quadratic Discriminant Analysis</td>
#       <td id="T_cce48_row2_col1" class="data row2 col1" >0.8046</td>
#       <td id="T_cce48_row2_col2" class="data row2 col2" >0.5439</td>
#       <td id="T_cce48_row2_col3" class="data row2 col3" >0.8046</td>
#       <td id="T_cce48_row2_col4" class="data row2 col4" >0.7103</td>
#       <td id="T_cce48_row2_col5" class="data row2 col5" >0.7458</td>
#       <td id="T_cce48_row2_col6" class="data row2 col6" >0.0146</td>
#       <td id="T_cce48_row2_col7" class="data row2 col7" >0.0161</td>
#       <td id="T_cce48_row2_col8" class="data row2 col8" >0.2470</td>
#     </tr>
#     <tr>
#       <th id="T_cce48_level0_row3" class="row_heading level0 row3" >rf</th>
#       <td id="T_cce48_row3_col0" class="data row3 col0" >Random Forest Classifier</td>
#       <td id="T_cce48_row3_col1" class="data row3 col1" >0.7914</td>
#       <td id="T_cce48_row3_col2" class="data row3 col2" >0.6817</td>
#       <td id="T_cce48_row3_col3" class="data row3 col3" >0.7914</td>
#       <td id="T_cce48_row3_col4" class="data row3 col4" >0.7433</td>
#       <td id="T_cce48_row3_col5" class="data row3 col5" >0.7615</td>
#       <td id="T_cce48_row3_col6" class="data row3 col6" >0.0719</td>
#       <td id="T_cce48_row3_col7" class="data row3 col7" >0.0773</td>
#       <td id="T_cce48_row3_col8" class="data row3 col8" >0.6750</td>
#     </tr>
#     <tr>
#       <th id="T_cce48_level0_row4" class="row_heading level0 row4" >gbc</th>
#       <td id="T_cce48_row4_col0" class="data row4 col0" >Gradient Boosting Classifier</td>
#       <td id="T_cce48_row4_col1" class="data row4 col1" >0.7856</td>
#       <td id="T_cce48_row4_col2" class="data row4 col2" >0.6464</td>
#       <td id="T_cce48_row4_col3" class="data row4 col3" >0.7856</td>
#       <td id="T_cce48_row4_col4" class="data row4 col4" >0.7555</td>
#       <td id="T_cce48_row4_col5" class="data row4 col5" >0.7667</td>
#       <td id="T_cce48_row4_col6" class="data row4 col6" >0.1153</td>
#       <td id="T_cce48_row4_col7" class="data row4 col7" >0.1207</td>
#       <td id="T_cce48_row4_col8" class="data row4 col8" >1.3090</td>
#     </tr>
#     <tr>
#       <th id="T_cce48_level0_row5" class="row_heading level0 row5" >lightgbm</th>
#       <td id="T_cce48_row5_col0" class="data row5 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_cce48_row5_col1" class="data row5 col1" >0.7844</td>
#       <td id="T_cce48_row5_col2" class="data row5 col2" >0.6386</td>
#       <td id="T_cce48_row5_col3" class="data row5 col3" >0.7844</td>
#       <td id="T_cce48_row5_col4" class="data row5 col4" >0.7411</td>
#       <td id="T_cce48_row5_col5" class="data row5 col5" >0.7521</td>
#       <td id="T_cce48_row5_col6" class="data row5 col6" >0.0364</td>
#       <td id="T_cce48_row5_col7" class="data row5 col7" >0.0494<
# DummyClassifier(constant=None, random_state=123, strategy='prior')

# %%
# Paramètres du modèle de rf

print(tuned_rf)
print(tuned_gbc)
print(tuned_ada)
# Out:
# RandomForestClassifier(bootstrap=False, ccp_alpha=0.0, class_weight='balanced',
#                        criterion='gini', max_depth=2, max_features='log2',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.1, min_samples_leaf=3,
#                        min_samples_split=5, min_weight_fraction_leaf=0.0,
#                        monotonic_cst=None, n_estimators=10, n_jobs=-1,
#                        oob_score=False, random_state=123, verbose=0,
#                        warm_start=False)
# GradientBoostingClassifier(ccp_alpha=0.0, criterion='friedman_mse', init=None,
#                            learning_rate=0.15, loss='log_loss', max_depth=7,
#                            max_features=1.0, max_leaf_nodes=None,
#                            min_impurity_decrease=0.02, min_samples_leaf=5,
#                            min_samples_split=5, min_weight_fraction_leaf=0.0,
#                            n_estimators=230, n_iter_no_change=None,
#                            random_state=123, subsample=0.85, tol=0.0001,
#                            validation_fraction=0.1, verbose=0,
#                            warm_start=False)
# AdaBoostClassifier(algorithm='SAMME', estimator=None, learning_rate=0.4,
#                    n_estimators=230, random_state=123)

# %%
# Prédiction des données de test pour obtenir une probabilité de succès avec le modèle RandomForest

predictions = predict_model(tuned_rf, data=donnees) # Prédiction des données de test pour obtenir une probabilité de succès avec le modèle RandomFores
# Out:
# <style type="text/css">
# </style>
# <table id="T_765f3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_765f3_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_765f3_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_765f3_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_765f3_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_765f3_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_765f3_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_765f3_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_765f3_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_765f3_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_765f3_row0_col0" class="data row0 col0" >Random Forest Classifier</td>
#       <td id="T_765f3_row0_col1" class="data row0 col1" >0.8318</td>
#       <td id="T_765f3_row0_col2" class="data row0 col2" >0.5000</td>
#       <td id="T_765f3_row0_col3" class="data row0 col3" >0.8318</td>
#       <td id="T_765f3_row0_col4" class="data row0 col4" >0.6919</td>
#       <td id="T_765f3_row0_col5" class="data row0 col5" >0.7554</td>
#       <td id="T_765f3_row0_col6" class="data row0 col6" >0.0000</td>
#       <td id="T_765f3_row0_col7" class="data row0 col7" >0.0000</td>
#     </tr>
#   </tbody>
# </table>
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\utils\_encode.py:225, in _encode(values, uniques, check_unknown)
#     224 try:
# --> 225     return _map_to_integer(values, uniques)
#     226 except KeyError as e:
#
# File c:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\utils\_encode.py:165, in _map_to_integer(values, uniques)
#     164 table = _nandict({val: i for i, val in enumerate(uniques)})
# --> 165 return np.array([table[v] for v in values])
#
# File c:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\utils\_encode.py:165, in <listcomp>(.0)
#     164 table = _nandict({val: i for i, val in enumerate(uniques)})
# --> 165 return np.array([table[v] for v in values])
#
# File c:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\utils\_encode.py:159, in _nandict.__missing__(self, key)
#     158     return self.nan_value
# --> 159 raise KeyError(key)
#
# KeyError: 0
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[28], line 3
#       1 # Prédiction des données de test pour obtenir une probabilité de succès avec le modèle RandomForest
# ----> 3 predictions = predict_model(tuned_rf, data=donnees) # Prédiction des données de test pour obtenir une probabilité de succès avec le modèle RandomFores
#
# File c:\Users\ASUS\anaconda3\Lib\site-packages\pycaret\classification\functional.py:2172, in predict_model(estimator, data, probability_threshold, encoded_labels, raw_score, round, verbose)
#    2169 if experiment is None:
#    2170     experiment = _EXPERIMENT_CLASS()
# -> 2172 return experiment.predict_model(
#    2173     estimator=estimator,
#    2174     data=data,
#    2175     probability_threshold=probability_threshold,
#    2176     encoded_labels=encoded_labels,
#    2177     raw_score=raw_score,
#    2178     round=round,
#    2179     verbose=verbose,
#    2180 )
#
# File c:\Users\ASUS\anaconda3\Lib\site-packages\pycaret\classification\oop.py:2824, in ClassificationExperiment.predict_model(self, estimator, data, probability_threshold, encoded_labels, raw_score, round, verbose)
#    2752 def predict_model(
#    2753     self,
#    2754     estimator,
#    (...)
#    2760     verbose: bool = True,
#    2761 ) -> pd.DataFrame:
#    2762     """
#    2763     This function predicts ``Label`` and ``Score`` (probability of predicted
#    2764     class) using a trained model. When ``data`` is None, it predicts label and
#    (...)
#    2821
#    2822     """
# -> 2824     return super().predict_model(
#    2825         estimator=estimator,
#    2826         data=data,
#    2827         probability_threshold=probability_threshold,
#    2828         encoded_labels=encoded_labels,
#    2829         raw_score=raw_score,
#    2830         round=round,
#    2831         verbose=verbose,
#    2832     )
#
# File c:\Users\ASUS\anaconda3\Lib\site-packages\pycaret\internal\pycaret_experiment\supervised_experiment.py:5056, in _SupervisedExperiment.predict_model(self, estimator, data, probability_threshold, encoded_labels, raw_score, round, verbose, ml_usecase, preprocess)
#    5054 if not raw_score:
#    5055     if label_encoder:
# -> 5056         pred = label_encoder.transform(pred)
#    5058     score = pd.DataFrame(
#    5059         data=[s[pred[i]] for i, s in enumerate(score)],
#    5060         index=X_test_.index,
#    5061         columns=[SCORE_COLUMN],
#    5062     )
#    5063 else:
#
# File c:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\preprocessing\_label.py:137, in LabelEncoder.transform(self, y)
#     134 if _num_samples(y) == 0:
#     135     return np.array([])
# --> 137 return _encode(y, uniques=self.classes_)
#
# File c:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\utils\_encode.py:227, in _encode(values, uniques, check_unknown)
#     225         return _map_to_integer(values, uniques)
#     226     except KeyError as e:
# --> 227         raise ValueError(f"y contains previously unseen labels: {str(e)}")
#     228 else:
#     229     if check_unknown:
#
# ValueError: y contains previously unseen labels: 0
